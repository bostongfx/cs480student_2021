# %% [markdown]
# <a href="https://colab.research.google.com/github/aovladi/cs480student/blob/main/CS480_Assignment_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![CS480_w.png](data:image/png;base64,...)
# #Assignment 6

# %%
# In this assignment, we will train a U-Net classifer to detect mitochondria
# in electron microscopy images!

# %%
### IMPORTANT ###
#
# Activate GPU support: Runtime -> Change Runtime Type
# Hardware Accelerator: GPU
#
### IMPORTANT ###

# %%
# load numpy and matplotlib
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# load the unet tensorflow code
# !pip install git+https://github.com/jakeret/unet.git
# Out:
# Collecting git+https://github.com/jakeret/unet.git
#   Cloning https://github.com/jakeret/unet.git to /tmp/pip-req-build-39ihqsaa
#   Running command git clone -q https://github.com/jakeret/unet.git /tmp/pip-req-build-39ihqsaa
# Building wheels for collected packages: unet
#   Building wheel for unet (setup.py) ... done
#   Created wheel for unet: filename=unet-0.0.post0.dev81+gf557a51-py2.py3-none-any.whl size=25658 sha256=9b2bcaa492bf2f81bcd9bf0c245aafb4aefff3497d39af9c3790214c273d98cd
#   Stored in directory: /tmp/pip-ephem-wheel-cache-tnvduqkw/wheels/f5/38/c8/8f0a157cfd7616cc1a24811a52b9a669c0ee8fccc9f99d3cbc
# Successfully built unet
# Installing collected packages: unet
# Successfully installed unet-0.0.post0.dev81+gf557a51

# %%
# .. and use it!
# Note: There are a ton of U-Net implementations but this one is easier to use!
import unet

# %% [markdown]
# **Task 1**: Study the unet circle example and learn about mitochondria! [15 Points]

# %%
# The unet package allows to train a U-Net classifier with little code.
# As discussed in class, the U-Net can be used to label/segment/annotate images.

# %%
# TODO: Please study the Circles example 
# https://github.com/jakeret/unet/blob/master/notebooks/circles.ipynb

# %%
# TODO: ... and look how the (artificial) dataset is generated
# https://github.com/jakeret/unet/blob/master/src/unet/datasets/circles.py

# %%
# 1) Question
# TODO: Please describe what the U-Net is trained to do.
#
# TODO: YOUR ANSWER

# %% [markdown]
# Based on original image (img with circles) and a corresponding original mask, unet learns to predict correct mask based on a given image. In this particular example it learned to generate a mask, which shows all circles in the original image.

# %%
# 2) Question
# TODO: In circles.py, what does the following mean:
#     channels = 1
#     classes = 2
#
# TODO: YOUR ANSWER

# %% [markdown]
# channels: number of channels of the input tensors, channels = 1 <- only 1 channel, so probably a greyscale image;
#
# classes: number of classes for predicted mask. classes = 2 <- only 2 classes, i.e. I think either black or white pixel, as seen in a black/white mask.

# %%
# 3) Question
# TODO: What are mitochondria and what is their appearance in
# electron microscopy data?
# Hint: You can validate your answer in Task 4!
#
# TODO: YOUR ANSWER

# %% [markdown]
# **Task 2**: Setup a datagenerator for mitochondria images! [45 Points]

# %%
# TODO: 
# Download https://cs480.org/data/mito.npz to your computer.
# Then, please upload mito.npz using the file panel on the left.

# %%
# The code below is similar to the circles.py file from Task 1.
# We follow Tensorflow conventions to design a tf.data.Dataset for training
# the U-Net.
#
# TODO: Please add four different data augmentation methods in the code block
# below. (image normalization to 0..1, horizontal data flip, vertical data flip,
# rotation by 90 degrees)
#
# Hint: https://github.com/jakeret/unet/blob/master/src/unet/datasets/oxford_iiit_pet.py#L25

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow_datasets.core import DatasetInfo
from typing import Tuple, List

IMAGE_SIZE = (256, 256)
channels = 1
classes = 2

def load_data(count:int, splits:Tuple[float]=(0.7, 0.2, 0.1), **kwargs) -> List[tf.data.Dataset]:
    #return [tf.data.Dataset.from_tensor_slices(_build_samples(int(split * count), **kwargs))
    #        for split in splits]
    return [tf.data.Dataset.from_tensor_slices(_build_samples(round(split * count), **kwargs))
            for split in splits]

def _build_samples(sample_count:int, **kwargs) -> Tuple[np.array, np.array]:

    # here we load the mitochondria data
    loaded = np.load('mito.npz')
    loadedimages = loaded['arr_0'][0].copy()
    loadedmasks = loaded['arr_0'][1].copy()

    # now let's go to numpyland
    images = np.empty((sample_count, IMAGE_SIZE[0], IMAGE_SIZE[1], 1))
    labels = np.empty((sample_count, IMAGE_SIZE[0], IMAGE_SIZE[1], 2))
    for i in range(sample_count):
        image, mask = loadedimages[i], loadedmasks[i]

        image = image.reshape((IMAGE_SIZE[0], IMAGE_SIZE[1], 1)).astype(np.float)
        mask = mask.reshape((IMAGE_SIZE[0], IMAGE_SIZE[1], 1))

        #
        # TODO: Normalize the image to 0..1
        #
        # TODO: YOUR CODE
        image = tf.cast(image, tf.float32) / 255.0
        #
        # TODO: Use Tensorflow to flip the image horizontally
        #
        if tf.random.uniform(()) > 0.5:
            #
            # TODO: YOUR CODE
            #
          image = tf.image.flip_left_right(image)
          mask = tf.image.flip_left_right(mask)

        #
        # TODO: Use Tensorflow to flip the image vertically
        #
        if tf.random.uniform(()) > 0.5:
            #
            # TODO: YOUR CODE
            #
          image = tf.image.flip_up_down(image)
          mask = tf.image.flip_up_down(mask)

        #
        # TODO: Use Tensorflow to rotate the image 90 degrees
        #
        if tf.random.uniform(()) > 0.5:
            #
            # TODO: YOUR CODE
            #
          image = tf.image.rot90(image)
          mask = tf.image.rot90(mask)

        # augmentation done, let's store the image
        images[i] = image

        # here we split the mask to background and foreground
        fg = np.zeros((IMAGE_SIZE[0], IMAGE_SIZE[1], 1), dtype=np.bool)
        fg[mask == 255] = 1
        bg = np.zeros((IMAGE_SIZE[0], IMAGE_SIZE[1], 1), dtype=np.bool)
        bg[mask == 0] = 1
        
        labels[i, :, :, 0] = bg[:,:,0]
        labels[i, :, :, 1] = fg[:,:,0]

    return images, labels

# %% [markdown]
# **Task 3**: Let's train the U-Net! [25 Points]

# %%
#
# We can now create our training, validation, and testing data by calling
# our methods from Task 2.
#
train, val, test = load_data( 660, splits=(0.7, 0.2, 0.1) )

# %%
# 1) Question
# TODO: We have in total 660 images + 660 masks. Based on the code above,
# how many images are used for training alone?
#
# TODO: YOUR ANSWER 70% , should be 462 images, but actual length is 461 as seen here:
len(train)
# Out:
# 461

# %%
# here is why:

print(int(660*0.7) )

# does not return 462, but 461
# Out:
# 461

# %%
# round instead of int in _build_samples(int(split * count), **kwargs) should fix this problem
# so I adjusted the provided code

# %%
#
# Let's setup the U-Net!
#
LEARNING_RATE = 1e-3

unet_model = unet.build_model(channels=channels,
                              num_classes=classes,
                              layer_depth=5,
                              filters_root=64,
                              padding="same")

unet.finalize_model(unet_model, learning_rate=LEARNING_RATE)

# %%
#
# And, let's setup the trainer...
#
trainer = unet.Trainer(checkpoint_callback=False,
                       learning_rate_scheduler=unet.SchedulerType.WARMUP_LINEAR_DECAY,
                       warmup_proportion=0.1,
                       learning_rate=LEARNING_RATE)

# %%
#
# ...and train the U-Net for 50 epochs with a batch_size of 10!
#
# TODO: Please complete the code below.
# Hint: Don't forget to use training and validation data.
# Hint 2: This will take roughly 30 minutes!
#
trainer.fit(unet_model,
            #
            # TODO: YOUR CODE
            #
            #
            train,
            val,
            epochs=50,
            batch_size=10
            )
# Out:
# Epoch 1/50
# 47/47 [==============================] - 47s 950ms/step - loss: 0.6726 - categorical_crossentropy: 0.6726 - categorical_accuracy: 0.6169 - mean_iou: 0.2847 - dice_coefficient: 0.5183 - auc_1: 0.5428 - val_loss: 0.3968 - val_categorical_crossentropy: 0.3968 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3653 - val_dice_coefficient: 0.6806 - val_auc_1: 0.9841
# Epoch 2/50
# 47/47 [==============================] - 39s 837ms/step - loss: 0.2768 - categorical_crossentropy: 0.2768 - categorical_accuracy: 0.9210 - mean_iou: 0.4555 - dice_coefficient: 0.8618 - auc_1: 0.9452 - val_loss: 0.2914 - val_categorical_crossentropy: 0.2914 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4105 - val_dice_coefficient: 0.7671 - val_auc_1: 0.9849
# Epoch 3/50
# 47/47 [==============================] - 39s 842ms/step - loss: 0.2641 - categorical_crossentropy: 0.2641 - categorical_accuracy: 0.9210 - mean_iou: 0.4594 - dice_coefficient: 0.8692 - auc_1: 0.9502 - val_loss: 0.2480 - val_categorical_crossentropy: 0.2480 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4325 - val_dice_coefficient: 0.8080 - val_auc_1: 0.9838
# Epoch 4/50
# 47/47 [==============================] - 39s 836ms/step - loss: 0.2715 - categorical_crossentropy: 0.2715 - categorical_accuracy: 0.9210 - mean_iou: 0.4548 - dice_coefficient: 0.8575 - auc_1: 0.9477 - val_loss: 0.2539 - val_categorical_crossentropy: 0.2539 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4297 - val_dice_coefficient: 0.8010 - val_auc_1: 0.9840
# Epoch 5/50
# 47/47 [==============================] - 39s 840ms/step - loss: 0.2709 - categorical_crossentropy: 0.2709 - categorical_accuracy: 0.9210 - mean_iou: 0.4534 - dice_coefficient: 0.8520 - auc_1: 0.9485 - val_loss: 0.2289 - val_categorical_crossentropy: 0.2289 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4433 - val_dice_coefficient: 0.8263 - val_auc_1: 0.9838
# Epoch 6/50
# 47/47 [==============================] - 39s 837ms/step - loss: 0.2646 - categorical_crossentropy: 0.2646 - categorical_accuracy: 0.9210 - mean_iou: 0.4573 - dice_coefficient: 0.8585 - auc_1: 0.9510 - val_loss: 0.2380 - val_categorical_crossentropy: 0.2380 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4389 - val_dice_coefficient: 0.8153 - val_auc_1: 0.9843
# Epoch 7/50
# 47/47 [==============================] - 39s 840ms/step - loss: 0.2682 - categorical_crossentropy: 0.2682 - categorical_accuracy: 0.9210 - mean_iou: 0.4555 - dice_coefficient: 0.8532 - auc_1: 0.9499 - val_loss: 0.2099 - val_categorical_crossentropy: 0.2099 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4549 - val_dice_coefficient: 0.8451 - val_auc_1: 0.9846
# Epoch 8/50
# 47/47 [==============================] - 39s 838ms/step - loss: 0.2551 - categorical_crossentropy: 0.2551 - categorical_accuracy: 0.9210 - mean_iou: 0.4602 - dice_coefficient: 0.8584 - auc_1: 0.9541 - val_loss: 0.1946 - val_categorical_crossentropy: 0.1946 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4651 - val_dice_coefficient: 0.8609 - val_auc_1: 0.9848
# Epoch 9/50
# 47/47 [==============================] - 39s 838ms/step - loss: 0.2449 - categorical_crossentropy: 0.2449 - categorical_accuracy: 0.9210 - mean_iou: 0.4652 - dice_coefficient: 0.8622 - auc_1: 0.9587 - val_loss: 0.1990 - val_categorical_crossentropy: 0.1990 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4645 - val_dice_coefficient: 0.8510 - val_auc_1: 0.9853
# Epoch 10/50
# 47/47 [==============================] - 39s 835ms/step - loss: 0.2390 - categorical_crossentropy: 0.2390 - categorical_accuracy: 0.9210 - mean_iou: 0.4687 - dice_coefficient: 0.8625 - auc_1: 0.9621 - val_loss: 0.2001 - val_categorical_crossentropy: 0.2001 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4664 - val_dice_coefficient: 0.8472 - val_auc_1: 0.9854
# Epoch 11/50
# 47/47 [==============================] - 39s 839ms/step - loss: 0.2372 - categorical_crossentropy: 0.2372 - categorical_accuracy: 0.9210 - mean_iou: 0.4714 - dice_coefficient: 0.8624 - auc_1: 0.9635 - val_loss: 0.1965 - val_categorical_crossentropy: 0.1965 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4707 - val_dice_coefficient: 0.8497 - val_auc_1: 0.9856
# Epoch 12/50
# 47/47 [==============================] - 39s 839ms/step - loss: 0.2319 - categorical_crossentropy: 0.2319 - categorical_accuracy: 0.9210 - mean_iou: 0.4750 - dice_coefficient: 0.8632 - auc_1: 0.9657 - val_loss: 0.1925 - val_categorical_crossentropy: 0.1925 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4756 - val_dice_coefficient: 0.8527 - val_auc_1: 0.9857
# Epoch 13/50
# 47/47 [==============================] - 39s 841ms/step - loss: 0.2269 - categorical_crossentropy: 0.2269 - categorical_accuracy: 0.9210 - mean_iou: 0.4790 - dice_coefficient: 0.8648 - auc_1: 0.9677 - val_loss: 0.1882 - val_categorical_crossentropy: 0.1882 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4809 - val_dice_coefficient: 0.8563 - val_auc_1: 0.9859
# Epoch 14/50
# 47/47 [==============================] - 39s 840ms/step - loss: 0.2187 - categorical_crossentropy: 0.2187 - categorical_accuracy: 0.9210 - mean_iou: 0.4844 - dice_coefficient: 0.8686 - auc_1: 0.9704 - val_loss: 0.1904 - val_categorical_crossentropy: 0.1904 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4820 - val_dice_coefficient: 0.8535 - val_auc_1: 0.9862
# Epoch 15/50
# 47/47 [==============================] - 39s 841ms/step - loss: 0.2189 - categorical_crossentropy: 0.2189 - categorical_accuracy: 0.9210 - mean_iou: 0.4858 - dice_coefficient: 0.8684 - auc_1: 0.9707 - val_loss: 0.1835 - val_categorical_crossentropy: 0.1835 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4880 - val_dice_coefficient: 0.8602 - val_auc_1: 0.9862
# Epoch 16/50
# 47/47 [==============================] - 39s 840ms/step - loss: 0.2148 - categorical_crossentropy: 0.2148 - categorical_accuracy: 0.9210 - mean_iou: 0.4903 - dice_coefficient: 0.8687 - auc_1: 0.9720 - val_loss: 0.1774 - val_categorical_crossentropy: 0.1774 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4932 - val_dice_coefficient: 0.8660 - val_auc_1: 0.9864
# Epoch 17/50
# 47/47 [==============================] - 39s 840ms/step - loss: 0.2094 - categorical_crossentropy: 0.2094 - categorical_accuracy: 0.9210 - mean_iou: 0.4945 - dice_coefficient: 0.8711 - auc_1: 0.9735 - val_loss: 0.1742 - val_categorical_crossentropy: 0.1742 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4958 - val_dice_coefficient: 0.8687 - val_auc_1: 0.9868
# Epoch 18/50
# 47/47 [==============================] - 39s 840ms/step - loss: 0.2056 - categorical_crossentropy: 0.2056 - categorical_accuracy: 0.9210 - mean_iou: 0.4972 - dice_coefficient: 0.8727 - auc_1: 0.9746 - val_loss: 0.1716 - val_categorical_crossentropy: 0.1716 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4994 - val_dice_coefficient: 0.8712 - val_auc_1: 0.9869
# Epoch 19/50
# 47/47 [==============================] - 39s 841ms/step - loss: 0.2032 - categorical_crossentropy: 0.2032 - categorical_accuracy: 0.9210 - mean_iou: 0.5006 - dice_coefficient: 0.8735 - auc_1: 0.9753 - val_loss: 0.1691 - val_categorical_crossentropy: 0.1691 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.5012 - val_dice_coefficient: 0.8735 - val_auc_1: 0.9872
# Epoch 20/50
# 47/47 [==============================] - 40s 844ms/step - loss: 0.2008 - categorical_crossentropy: 0.2008 - categorical_accuracy: 0.9210 - mean_iou: 0.5026 - dice_coefficient: 0.8745 - auc_1: 0.9759 - val_loss: 0.1645 - val_categorical_crossentropy: 0.1645 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.5049 - val_dice_coefficient: 0.8780 - val_auc_1: 0.9874
# Epoch 21/50
# 47/47 [==============================] - 40s 843ms/step - loss: 0.1973 - categorical_crossentropy: 0.1973 - categorical_accuracy: 0.9210 - mean_iou: 0.5056 - dice_coefficient: 0.8766 - auc_1: 0.9768 - val_loss: 0.1622 - val_categorical_crossentropy: 0.1622 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.5071 - val_dice_coefficient: 0.8800 - val_auc_1: 0.9876
# Epoch 22/50
# 47/47 [==============================] - 40s 844ms/step - loss: 0.1947 - categorical_crossentropy: 0.1947 - categorical_accuracy: 0.9210 - mean_iou: 0.5080 - dice_coefficient: 0.8781 - auc_1: 0.9774 - val_loss: 0.1604 - val_categorical_crossentropy: 0.1604 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.5094 - val_dice_coefficient: 0.8817 - val_auc_1: 0.9878
# Epoch 23/50
# 47/47 [==============================] - 39s 842ms/step - loss: 0.1922 - categorical_crossentropy: 0.1922 - categorical_accuracy: 0.9210 - mean_iou: 0.5105 - dice_coefficient: 0.8798 - auc_1: 0.9780 - val_loss: 0.1599 - val_categorical_crossentropy: 0.1599 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.5107 - val_dice_coefficient: 0.8819 - val_auc_1: 0.9880
# Epoch 24/50
# 47/47 [==============================] - 39s 842ms/step - loss: 0.1916 - categorical_crossentropy: 0.1916 - categorical_accuracy: 0.9210 - mean_iou: 0.5122 - dice_coefficient: 0.8797 - auc_1: 0.9782 - val_loss: 0.1546 - val_categorical_crossentropy: 0.1546 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.5150 - val_dice_coefficient: 0.8875 - val_auc_1: 0.9882
# Epoch 25/50
# 47/47 [==============================] - 39s 842ms/step - loss: 0.1883 - categorical_crossentropy: 0.1883 - categorical_accuracy: 0.9210 - mean_iou: 0.5151 - dice_coefficient: 0.8822 - auc_1: 0.9788 - val_loss: 0.1525 - val_categorical_crossentropy: 0.1525 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.5176 - val_dice_coefficient: 0.8895 - val_auc_1: 0.9883
# Epoch 26/50
# 47/47 [==============================] - 39s 842ms/step - loss: 0.1865 - categorical_crossentropy: 0.1865 - categorical_accuracy: 0.9210 - mean_iou: 0.5174 - dice_coefficient: 0.8834 - auc_1: 0.9791 - val_loss: 0.1510 - val_categorical_crossentropy: 0.1510 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.5199 - val_dice_coefficient: 0.8911 - val_auc_1: 0.9884
# Epoch 27/50
# 47/47 [==============================] - 39s 840ms/step - loss: 0.1852 - categorical_crossentropy: 0.1852 - categorical_accuracy: 0.9210 - mean_iou: 0.5193 - dice_coefficient: 0.8842 - auc_1: 0.9794 - val_loss: 0.1491 - val_categorical_crossentropy: 0.1491 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.5225 - val_dice_coefficient: 0.8931 - val_auc_1: 0.9885
# Epoch 28/50
# 47/47 [==============================] - 39s 841ms/step - loss: 0.1836 - categorical_crossentropy: 0.1836 - categorical_accuracy: 0.9210 - mean_iou: 0.5215 - dice_coefficient: 0.8853 - auc_1: 0.9797 - val_loss: 0.1479 - val_categorical_crossentropy: 0.1479 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.5250 - val_dice_coefficient: 0.8945 - val_auc_1: 0.9886
# Epoch 29/50
# 47/47 [==============================] - 40s 843ms/step - loss: 0.1823 - categorical_crossentropy: 0.1823 - categorical_accuracy: 0.9210 - mean_iou: 0.5236 - dice_coefficient: 0.8862 - auc_1: 0.9799 - val_loss: 0.1470 - val_categorical_crossentropy: 0.1470 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.5274 - val_dice_coefficient: 0.8955 - val_auc_1: 0.9886
# Epoch 30/50
# 47/47 [==============================] - 39s 842ms/step - loss: 0.1806 - categorical_crossentropy: 0.1806 - categorical_accuracy: 0.9211 - mean_iou: 0.5257 - dice_coefficient: 0.8877 - auc_1: 0.9802 - val_loss: 0.1479 - val_categorical_crossentropy: 0.1479 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.5284 - val_dice_coefficient: 0.8944 - val_auc_1: 0.9887
# Epoch 31/50
# 47/47 [==============================] - 39s 841ms/step - loss: 0.1810 - categorical_crossentropy: 0.1810 - categorical_accuracy: 0.9211 - mean_iou: 0.5268 - dice_coefficient: 0.8866 - auc_1: 0.9802 - val_loss: 0.1441 - val_categorical_crossentropy: 0.1441 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.5323 - val_dice_coefficient: 0.8993 - val_auc_1: 0.9887
# Epoch 32/50
# 47/47 [==============================] - 39s 842ms/step - loss: 0.1789 - categorical_crossentropy: 0.1789 - categorical_accuracy: 0.9211 - mean_iou: 0.5293 - dice_coefficient: 0.8889 - auc_1: 0.9804 - val_loss: 0.1432 - val_categorical_crossentropy: 0.1432 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.5336 - val_dice_coefficient: 0.9003 - val_auc_1: 0.9887
# Epoch 33/50
# 47/47 [==============================] - 39s 841ms/step - loss: 0.1778 - categorical_crossentropy: 0.1778 - categorical_accuracy: 0.9211 - mean_iou: 0.5306 - dice_coefficient: 0.8896 - auc_1: 0.9807 - val_loss: 0.1422 - val_categorical_crossentropy: 0.1422 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.5351 - val_dice_coefficient: 0.9015 - val_auc_1: 0.9888
# Epoch 34/50
# 47/47 [==============================] - 40s 843ms/step - loss: 0.1766 - categorical_crossentropy: 0.1766 - categorical_accuracy: 0.9211 - mean_iou: 0.5323 - dice_coefficient: 0.8906 - auc_1: 0.9809 - val_loss: 0.1416 - val_categorical_crossentropy: 0.1416 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.5355 - val_dice_coefficient: 0.9019 - val_auc_1: 0.9888
# Epoch 35/50
# 47/47 [==============================] - 39s 842ms/step - loss: 0.1757 - categorical_crossentropy: 0.1757 - categorical_accuracy: 0.9212 - mean_iou: 0.5330 - dice_coefficient: 0.8910 - auc_1: 0.9811 - val_loss: 0.1423 - val_categorical_crossentropy: 0.1423 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.5376 - val_dice_coefficient: 0.9017 - val_auc_1: 0.9887
# Epoch 36/50
# 47/47 [==============================] - 39s 841ms/step - loss: 0.1730 - categorical_crossentropy: 0.1730 - categorical_accuracy: 0.9215 - mean_iou: 0.5378 - dice_coefficient: 0.8933 - auc_1: 0.9816 - val_loss: 0.1425 - val_categorical_crossentropy: 0.1425 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.5365 - val_dice_coefficient: 0.8989 - val_auc_1: 0.9893
# Epoch 37/50
# 47/47 [==============================] - 39s 842ms/step - loss: 0.1720 - categorical_crossentropy: 0.1720 - categorical_accuracy: 0.9242 - mean_iou: 0.5376 - dice_coefficient: 0.8918 - auc_1: 0.9821 - val_loss: 0.1521 - val_categorical_crossentropy: 0.1521 - val_categorical_accuracy: 0.9274 - val_mean_iou: 0.5398 - val_dice_coefficient: 0.8913 - val_auc_1: 0.9873
# Epoch 38/50
# 47/47 [==============================] - 39s 838ms/step - loss: 0.1649 - categorical_crossentropy: 0.1649 - categorical_accuracy: 0.9363 - mean_iou: 0.5566 - dice_coefficient: 0.8980 - auc_1: 0.9837 - val_loss: 0.1522 - val_categorical_crossentropy: 0.1522 - val_categorical_accuracy: 0.9273 - val_mean_iou: 0.5528 - val_dice_coefficient: 0.8914 - val_auc_1: 0.9877
# Epoch 39/50
# 47/47 [==============================] - 39s 834ms/step - loss: 0.1635 - categorical_crossentropy: 0.1635 - categorical_accuracy: 0.9391 - mean_iou: 0.5568 - dice_coefficient: 0.8951 - auc_1: 0.9842 - val_loss: 0.1349 - val_categorical_crossentropy: 0.1349 - val_categorical_accuracy: 0.9446 - val_mean_iou: 0.5391 - val_dice_coefficient: 0.9116 - val_auc_1: 0.9890
# Epoch 40/50
# 47/47 [==============================] - 39s 830ms/step - loss: 0.1582 - categorical_crossentropy: 0.1582 - categorical_accuracy: 0.9406 - mean_iou: 0.5679 - dice_coefficient: 0.9037 - auc_1: 0.9845 - val_loss: 0.2373 - val_categorical_crossentropy: 0.2373 - val_categorical_accuracy: 0.8668 - val_mean_iou: 0.5411 - val_dice_coefficient: 0.8583 - val_auc_1: 0.9664
# Epoch 41/50
# 47/47 [==============================] - 39s 829ms/step - loss: 0.1605 - categorical_crossentropy: 0.1605 - categorical_accuracy: 0.9399 - mean_iou: 0.5741 - dice_coefficient: 0.9025 - auc_1: 0.9841 - val_loss: 0.2322 - val_categorical_crossentropy: 0.2322 - val_categorical_accuracy: 0.8753 - val_mean_iou: 0.5533 - val_dice_coefficient: 0.8658 - val_auc_1: 0.9690
# Epoch 42/50
# 47/47 [==============================] - 39s 828ms/step - loss: 0.1565 - categorical_crossentropy: 0.1565 - categorical_accuracy: 0.9422 - mean_iou: 0.5842 - dice_coefficient: 0.9056 - auc_1: 0.9848 - val_loss: 0.1957 - val_categorical_crossentropy: 0.1957 - val_categorical_accuracy: 0.8983 - val_mean_iou: 0.5699 - val_dice_coefficient: 0.8825 - val_auc_1: 0.9773
# Epoch 43/50
# 47/47 [==============================] - 39s 827ms/step - loss: 0.1482 - categorical_crossentropy: 0.1482 - categorical_accuracy: 0.9457 - mean_iou: 0.5977 - dice_coefficient: 0.9119 - auc_1: 0.9862 - val_loss: 0.2268 - val_categorical_crossentropy: 0.2268 - val_categorical_accuracy: 0.8778 - val_mean_iou: 0.5519 - val_dice_coefficient: 0.8649 - val_auc_1: 0.9692
# Epoch 44/50
# 47/47 [==============================] - 39s 825ms/step - loss: 0.1446 - categorical_crossentropy: 0.1446 - categorical_accuracy: 0.9465 - mean_iou: 0.6026 - dice_coefficient: 0.9134 - auc_1: 0.9869 - val_loss: 0.1932 - val_categorical_crossentropy: 0.1932 - val_categorical_accuracy: 0.9005 - val_mean_iou: 0.5705 - val_dice_coefficient: 0.8815 - val_auc_1: 0.9777
# Epoch 45/50
# 47/47 [==============================] - 39s 825ms/step - loss: 0.1351 - categorical_crossentropy: 0.1351 - categorical_accuracy: 0.9490 - mean_iou: 0.6153 - dice_coefficient: 0.9181 - auc_1: 0.9886 - val_loss: 0.1867 - val_categorical_crossentropy: 0.1867 - val_categorical_accuracy: 0.9042 - val_mean_iou: 0.5754 - val_dice_coefficient: 0.8849 - val_auc_1: 0.9792
# Epoch 46/50
# 47/47 [==============================] - 39s 826ms/step - loss: 0.1278 - categorical_crossentropy: 0.1278 - categorical_accuracy: 0.9506 - mean_iou: 0.6270 - dice_coefficient: 0.9227 - auc_1: 0.9898 - val_loss: 0.1694 - val_categorical_crossentropy: 0.1694 - val_categorical_accuracy: 0.9145 - val_mean_iou: 0.5883 - val_dice_coefficient: 0.8943 - val_auc_1: 0.9831
# Epoch 47/50
# 47/47 [==============================] - 39s 824ms/step - loss: 0.1206 - categorical_crossentropy: 0.1206 - categorical_accuracy: 0.9519 - mean_iou: 0.6370 - dice_coefficient: 0.9262 - auc_1: 0.9910 - val_loss: 0.1749 - val_categorical_crossentropy: 0.1749 - val_categorical_accuracy: 0.9120 - val_mean_iou: 0.5880 - val_dice_coefficient: 0.8931 - val_auc_1: 0.9820
# Epoch 48/50
# 47/47 [==============================] - 39s 825ms/step - loss: 0.1148 - categorical_crossentropy: 0.1148 - categorical_accuracy: 0.9536 - mean_iou: 0.6471 - dice_coefficient: 0.9300 - auc_1: 0.9918 - val_loss: 0.1935 - val_categorical_crossentropy: 0.1935 - val_categorical_accuracy: 0.9019 - val_mean_iou: 0.5786 - val_dice_coefficient: 0.8848 - val_auc_1: 0.9780
# Epoch 49/50
# 47/47 [==============================] - 39s 826ms/step - loss: 0.1103 - categorical_crossentropy: 0.1103 - categorical_accuracy: 0.9554 - mean_iou: 0.6551 - dice_coefficient: 0.9332 - auc_1: 0.9924 - val_loss: 0.2355 - val_categorical_crossentropy: 0.2355 - val_categorical_accuracy: 0.8791 - val_mean_iou: 0.5568 - val_dice_coefficient: 0.8647 - val_auc_1: 0.9677
# Epoch 50/50
# 47/47 [==============================] - 39s 827ms/step - loss: 0.1076 - categorical_crossentropy: 0.1076 - categorical_accuracy: 0.9561 - mean_iou: 0.6608 - dice_coefficient: 0.9343 - auc_1: 0.9928 - val_loss: 0.2588 - val_categorical_crossentropy: 0.2588 - val_categorical_accuracy: 0.8666 - val_mean_iou: 0.5458 - val_dice_coefficient: 0.8541 - val_auc_1: 0.9614

# %% [markdown]
# **Task 4**: Let's predict mitochondria in the testing data! [15 Points]

# %%
# 
# After training, let's try the U-Net on our testing data.
#
# The code below displays the first 10 input images, the original masks by experts, 
# and the predicted masks from the U-Net.

# %%
rows = 10
fig, axs = plt.subplots(rows, 3, figsize=(8, 30))
for ax, (image, label) in zip(axs, test.take(rows).batch(1)):
  
  prediction = unet_model.predict(image)
  ax[0].matshow(image[0, :, :, 0])
  ax[1].matshow(label[0, :, :, 1], cmap="gray")
  ax[2].matshow(prediction[0].argmax(axis=-1), cmap="gray")

# %%
# 1) Question
# TODO: Why do we use the prediction[0].argmax(axis=-1) command
# to display the prediction?
# 
# TODO: YOUR ANSWER

# %% [markdown]
# Because the model predicts probability for each class, i.e. for each pixel in the image it makes a prediction for this pixel to be 0 or 1 [0.99, 0.01] something like that. To convert this prediction into the value for the pixel, we want to take the argument with the max probability (hence argmax), so that instead of [0.99,0.01] we have 0 (class 0 has 99% probability).

# %%
# 2) Question
# TODO: Is the quality of the segmentation good and how could we improve it?
# Hint: Think along the lines of some traditional image processing rather than
# increasing the training data size.
#
# TODO: YOUR ANSWER

# %% [markdown]
# **Bonus**: Compare against the state-of-the-art literature! [33 Points]

# %%
#
# The following paper also uses a 2D U-Net to detect mitochondria:
# 
# https://danielhaehn.com/papers/?casser2020fast
#

# %%
# 1) Question
#
# TODO: How many learnable parameters does your trained unet_model have?
# Hint: You can use TF's Model Summary function to answer this.
#

# %%
# TODO: YOUR CODE

# %%
unet_model.summary()
# Out:
# Model: "unet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# inputs (InputLayer)             [(None, None, None,  0
# __________________________________________________________________________________________________
# conv_block_9 (ConvBlock)        (None, None, None, 6 37568       inputs[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, None, None, 6 0           conv_block_9[0][0]
# __________________________________________________________________________________________________
# conv_block_10 (ConvBlock)       (None, None, None, 1 221440      max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, None, None, 1 0           conv_block_10[0][0]
# __________________________________________________________________________________________________
# conv_block_11 (ConvBlock)       (None, None, None, 2 885248      max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, None, None, 2 0           conv_block_11[0][0]
# __________________________________________________________________________________________________
# conv_block_12 (ConvBlock)       (None, None, None, 5 3539968     max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, None, None, 5 0           conv_block_12[0][0]
# __________________________________________________________________________________________________
# conv_block_13 (ConvBlock)       (None, None, None, 1 14157824    max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# upconv_block_4 (UpconvBlock)    (None, None, None, 5 2097664     conv_block_13[0][0]
# __________________________________________________________________________________________________
# crop_concat_block_4 (CropConcat (None, None, None, 1 0           upconv_block_4[0][0]
#                                                                  conv_block_12[0][0]
# __________________________________________________________________________________________________
# conv_block_14 (ConvBlock)       (None, None, None, 5 7078912     crop_concat_block_4[0][0]
# __________________________________________________________________________________________________
# upconv_block_5 (UpconvBlock)    (None, None, None, 2 524544      conv_block_14[0][0]
# __________________________________________________________________________________________________
# crop_concat_block_5 (CropConcat (None, None, None, 5 0           upconv_block_5[0][0]
#                                                                  conv_block_11[0][0]
# __________________________________________________________________________________________________
# conv_block_15 (ConvBlock)       (None, None, None, 2 1769984     crop_concat_block_5[0][0]
# __________________________________________________________________________________________________
# upconv_block_6 (UpconvBlock)    (None, None, None, 1 131200      conv_block_15[0][0]
# __________________________________________________________________________________________________
# crop_concat_block_6 (CropConcat (None, None, None, 2 0           upconv_block_6[0][0]
#                                                                  conv_block_10[0][0]
# __________________________________________________________________________________________________
# conv_block_16 (ConvBlock)       (None, None, None, 1 442624      crop_concat_block_6[0][0]
# __________________________________________________________________________________________________
# upconv_block_7 (UpconvBlock)    (None, None, None, 6 32832       conv_block_16[0][0]
# __________________________________________________________________________________________________
# crop_concat_block_7 (CropConcat (None, None, None, 1 0           upconv_block_7[0][0]
#                                                                  conv_block_9[0][0]
# __________________________________________________________________________________________________
# conv_block_17 (ConvBlock)       (None, None, None, 6 110720      crop_concat_block_7[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, None, None, 2 130         conv_block_17[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, None, None, 2 0           conv2d_37[0][0]
# __________________________________________________________________________________________________
# outputs (Activation)            (None, None, None, 2 0           activation_45[0][0]
# ==================================================================================================
# Total params: 31,030,658
# Trainable params: 31,030,658
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Total trainable parameters: 31,030,658

# %%
# 2) Question
#
# TODO: How many parameters do Casser et al. use?
#

# %%
# TODO: YOUR ANSWER

# %% [markdown]
# 1,178,480 (encoder) + 780,053 (decoder) = 1,958,533 (total)

# %%
# 3) Question
#
# TODO: How did Casser et al. reduce the parameters?
#

# %%
# TODO: YOUR ANSWER

# %% [markdown]
# 1) The authors reduced the number of convolutional filters throughout the network. </br>
# 2) They replaced transpose convolutions in the decoder with light-weight bilinear upsampling layers that require no parameters. </br>
# As a result, the encoder's parameter reduction is 94%, from 19,505,856 to 1,178,480. For the decoder, the reduction is 93.6% from 12,188,545 to 780,053.

# %%
# 4) Question
#
# TODO: Why did Casser et al. reduce the parameters?
#

# %%
# TODO: YOUR ANSWER

# %% [markdown]
# To increase the throughtput (by 40%) </br>
# Additionally, the authors found that in practice, 33.53% of the filters in the original U-Net stay inactive and waste significant compute. In contrast, an optimized U-Net reaches 99.7% utilization.

# %%
#
# You made it!!
#
#                 _ ___                /^^\ /^\  /^^\_
#     _          _@)@) \            ,,/ '` ~ `'~~ ', `\.
#   _/o\_ _ _ _/~`.`...'~\        ./~~..,'`','',.,' '  ~:
#  / `,'.~,~.~  .   , . , ~|,   ,/ .,' , ,. .. ,,.   `,  ~\_
# ( ' _' _ '_` _  '  .    , `\_/ .' ..' '  `  `   `..  `,   \_
#  ~V~ V~ V~ V~ ~\ `   ' .  '    , ' .,.,''`.,.''`.,.``. ',   \_
#   _/\ /\ /\ /\_/, . ' ,   `_/~\_ .' .,. ,, , _/~\_ `. `. '.,  \_
#  < ~ ~ '~`'~'`, .,  .   `_: ::: \_ '      `_/ ::: \_ `.,' . ',  \_
#   \ ' `_  '`_    _    ',/ _::_::_ \ _    _/ _::_::_ \   `.,'.,`., \-,-,-,_,_,
#    `'~~ `'~~ `'~~ `'~~  \(_)(_)(_)/  `~~' \(_)(_)(_)/ ~'`\_.._,._,'_;_;_;_;_;
#
