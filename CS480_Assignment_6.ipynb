# %% [markdown]
# <a href="https://colab.research.google.com/github/Jahnavi001/cs480student/blob/main/CS480_Assignment_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![CS480_w.png](data:image/png;base64,...)
# #Assignment 6

# %%
# In this assignment, we will train a U-Net classifer to detect mitochondria
# in electron microscopy images!

# %%
### IMPORTANT ###
#
# Activate GPU support: Runtime -> Change Runtime Type
# Hardware Accelerator: GPU
#
### IMPORTANT ###

# %%
# load numpy and matplotlib
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /usr/local/lib/python3.7/dist-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['test']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
# load the unet tensorflow code
# !pip install git+https://github.com/jakeret/unet.git
# Out:
# Collecting git+https://github.com/jakeret/unet.git
#   Cloning https://github.com/jakeret/unet.git to /tmp/pip-req-build-zzaai1ss
#   Running command git clone -q https://github.com/jakeret/unet.git /tmp/pip-req-build-zzaai1ss
# Requirement already satisfied (use --upgrade to upgrade): unet==0.0.post0.dev81+gf557a51 from git+https://github.com/jakeret/unet.git in /usr/local/lib/python3.7/dist-packages
# Building wheels for collected packages: unet
#   Building wheel for unet (setup.py) ... done
#   Created wheel for unet: filename=unet-0.0.post0.dev81+gf557a51-py2.py3-none-any.whl size=25658 sha256=66ccb7e10a480c30e737d0179809f9586ee8551f3f8f20aaf9209dcf594c079a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-s3og90xr/wheels/f5/38/c8/8f0a157cfd7616cc1a24811a52b9a669c0ee8fccc9f99d3cbc
# Successfully built unet

# %%
# .. and use it!
# Note: There are a ton of U-Net implementations but this one is easier to use!
import unet

# %% [markdown]
# **Task 1**: Study the unet circle example and learn about mitochondria! [15 Points]

# %%
# The unet package allows to train a U-Net classifier with little code.
# As discussed in class, the U-Net can be used to label/segment/annotate images.

# %%
# TODO: Please study the Circles example 
# https://github.com/jakeret/unet/blob/master/notebooks/circles.ipynb

# %%
# TODO: ... and look how the (artificial) dataset is generated
# https://github.com/jakeret/unet/blob/master/src/unet/datasets/circles.py

# %%
# 1) Question
# TODO: Please describe what the U-Net is trained to do.
#
# TODO: YOUR ANSWER
#For Bio Medical Image Segmentation. The architecture contains two paths. 
#First path is the contraction path (also called as the encoder) which is used to capture the context in the image. 
#The encoder is just a traditional stack of convolutional and max pooling layers. The second path is the symmetric expanding path (also called as the decoder) which is used to enable precise localization using transposed convolutions. Thus it is an end-to-end fully convolutional network (FCN), i.e. it only contains Convolutional layers and does not contain any Dense layer because of which it can accept image of any size.

# %%
# 2) Question
# TODO: In circles.py, what does the following mean:
#     channels = 1
#     classes = 2
#
# TODO: YOUR ANSWER
# In circles.py channels refers to no. of input tensors. In code we use one channel it is given as channels = 1.
# In circles.py classes refers to no. of classes used in the class i.e., the fundamental blueprint of the code.

# %%
# 3) Question
# TODO: What are mitochondria and what is their appearance in
# electron microscopy data?
# Hint: You can validate your answer in Task 4!
# TODO: YOUR ANSWER
#Mitochondria are membrane-bound cell organelles (mitochondrion, singular) that generate most of the chemical energy needed to power the cell's biochemical reactions. Chemical energy produced by the mitochondria is stored in a small molecule called adenosine triphosphate (ATP). Mitochondria contain their own small chromosomes. 
# Mitochondria observed in electron microscope have a relatively large matrix volume that pushes part of the inner membrane up against the outer membrane with a small space between them. The remaining inner membrane forms cristae projecting into the matrix, and the opposing membranes of these cristae are close together with a small space between them.

# %% [markdown]
# **Task 2**: Setup a datagenerator for mitochondria images! [45 Points]

# %%
# TODO: 
# Download https://cs480.org/data/mito.npz to your computer.
# Then, please upload mito.npz using the file panel on the left.

# %%
# The code below is similar to the circles.py file from Task 1.
# We follow Tensorflow conventions to design a tf.data.Dataset for training
# the U-Net.
#
# TODO: Please add four different data augmentation methods in the code block
# below. (image normalization to 0..1, horizontal data flip, vertical data flip,
# rotation by 90 degrees)
#
# Hint: https://github.com/jakeret/unet/blob/master/src/unet/datasets/oxford_iiit_pet.py#L25

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow_datasets.core import DatasetInfo
from typing import Tuple, List

IMAGE_SIZE = (256, 256)
channels = 1
classes = 2

def load_data(count:int, splits:Tuple[float]=(0.7, 0.2, 0.1), **kwargs) -> List[tf.data.Dataset]:
    return [tf.data.Dataset.from_tensor_slices(_build_samples(int(split * count), **kwargs))
            for split in splits]


def _build_samples(sample_count:int, **kwargs) -> Tuple[np.array, np.array]:

    # here we load the mitochondria data
    loaded = np.load('mito.npz')
    loadedimages = loaded['arr_0'][0].copy()
    loadedmasks = loaded['arr_0'][1].copy()

    # now let's go to numpyland
    images = np.empty((sample_count, IMAGE_SIZE[0], IMAGE_SIZE[1], 1))
    labels = np.empty((sample_count, IMAGE_SIZE[0], IMAGE_SIZE[1], 2))
    for i in range(sample_count):
        image, mask = loadedimages[i], loadedmasks[i]

        image = image.reshape((IMAGE_SIZE[0], IMAGE_SIZE[1], 1)).astype(np.float)
        mask = mask.reshape((IMAGE_SIZE[0], IMAGE_SIZE[1], 1))

        #
        # TODO: Normalize the image to 0..1

        #
        # TODO: YOUR CODE
        # 
        image =  tf.image.per_image_standardization(image)
        

        
        #
        # TODO: Use Tensorflow to flip the image horizontally
        #
        if tf.random.uniform(()) > 0.5:
            #
            # TODO: YOUR CODE
            image = tf.image.flip_left_right(image)
            
            
        #
        # TODO: Use Tensorflow to flip the image vertically
        #
        if tf.random.uniform(()) > 0.5:
            #
            # TODO: YOUR CODE
            image = tf.image.flip_up_down(image)
             

        #
        # TODO: Use Tensorflow to rotate the image 90 degrees
        #
        if tf.random.uniform(()) > 0.5:
            #
            # TODO: YOUR CODE
            image = tf.image.rot90(image, k=1)
            

        # augmentation done, let's store the image
        images[i] = image

        # here we split the mask to background and foreground
        fg = np.zeros((IMAGE_SIZE[0], IMAGE_SIZE[1], 1), dtype=np.bool)
        fg[mask == 255] = 1
        bg = np.zeros((IMAGE_SIZE[0], IMAGE_SIZE[1], 1), dtype=np.bool)
        bg[mask == 0] = 1
        
        labels[i, :, :, 0] = bg[:,:,0]
        labels[i, :, :, 1] = fg[:,:,0]

    return images, labels

# %% [markdown]
# **Task 3**: Let's train the U-Net! [25 Points]

# %%
#
# We can now create our training, validation, and testing data by calling
# our methods from Task 2.
#
train, val, test = load_data( 660, splits=(0.7, 0.2, 0.1) )

# %%
# 1) Question
# TODO: We have in total 660 images + 660 masks. Based on the code above,
# how many images are used for training alone?
#
# TODO: YOUR ANSWER
#462 images

# %%
#
# Let's setup the U-Net!
#
LEARNING_RATE = 1e-3

unet_model = unet.build_model(channels=channels,
                              num_classes=classes,
                              layer_depth=5,
                              filters_root=64,
                              padding="same")

unet.finalize_model(unet_model, learning_rate=LEARNING_RATE)

# %%
#
# And, let's setup the trainer...
#
trainer = unet.Trainer(checkpoint_callback=False,
                       learning_rate_scheduler=unet.SchedulerType.WARMUP_LINEAR_DECAY,
                       warmup_proportion=0.1,
                       learning_rate=LEARNING_RATE)

# %%
#
# ...and train the U-Net for 50 epochs with a batch_size of 10!
#
# TODO: Please complete the code below.
# Hint: Don't forget to use training and validation data.
# Hint 2: This will take roughly 30 minutes!
#
trainer.fit(unet_model,
            #
            # TODO: YOUR CODE
            #
            #
            train,
            val,
            epochs=50,
            batch_size=10
            )
# Out:
# Epoch 1/50
# 47/47 [==============================] - 44s 889ms/step - loss: 0.6815 - categorical_crossentropy: 0.6815 - categorical_accuracy: 0.6575 - mean_iou: 0.2821 - dice_coefficient: 0.5133 - auc_1: 0.4872 - val_loss: 0.3739 - val_categorical_crossentropy: 0.3739 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3733 - val_dice_coefficient: 0.7019 - val_auc_1: 0.9408
# Epoch 2/50
# 47/47 [==============================] - 40s 849ms/step - loss: 0.3205 - categorical_crossentropy: 0.3205 - categorical_accuracy: 0.9209 - mean_iou: 0.4417 - dice_coefficient: 0.8414 - auc_1: 0.9290 - val_loss: 0.3666 - val_categorical_crossentropy: 0.3666 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3768 - val_dice_coefficient: 0.7083 - val_auc_1: 0.9429
# Epoch 3/50
# 47/47 [==============================] - 40s 855ms/step - loss: 0.3372 - categorical_crossentropy: 0.3372 - categorical_accuracy: 0.9210 - mean_iou: 0.4310 - dice_coefficient: 0.8189 - auc_1: 0.9271 - val_loss: 0.2445 - val_categorical_crossentropy: 0.2445 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4364 - val_dice_coefficient: 0.8337 - val_auc_1: 0.9444
# Epoch 4/50
# 47/47 [==============================] - 40s 847ms/step - loss: 0.3081 - categorical_crossentropy: 0.3081 - categorical_accuracy: 0.9210 - mean_iou: 0.4404 - dice_coefficient: 0.8384 - auc_1: 0.9256 - val_loss: 0.2692 - val_categorical_crossentropy: 0.2692 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4216 - val_dice_coefficient: 0.8020 - val_auc_1: 0.9411
# Epoch 5/50
# 47/47 [==============================] - 40s 851ms/step - loss: 0.3085 - categorical_crossentropy: 0.3085 - categorical_accuracy: 0.9210 - mean_iou: 0.4393 - dice_coefficient: 0.8355 - auc_1: 0.9274 - val_loss: 0.2650 - val_categorical_crossentropy: 0.2650 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4231 - val_dice_coefficient: 0.8037 - val_auc_1: 0.9471
# Epoch 6/50
# 47/47 [==============================] - 40s 848ms/step - loss: 0.3042 - categorical_crossentropy: 0.3042 - categorical_accuracy: 0.9210 - mean_iou: 0.4401 - dice_coefficient: 0.8382 - auc_1: 0.9274 - val_loss: 0.2514 - val_categorical_crossentropy: 0.2514 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4307 - val_dice_coefficient: 0.8179 - val_auc_1: 0.9525
# Epoch 7/50
# 47/47 [==============================] - 40s 846ms/step - loss: 0.3000 - categorical_crossentropy: 0.3000 - categorical_accuracy: 0.9210 - mean_iou: 0.4403 - dice_coefficient: 0.8387 - auc_1: 0.9257 - val_loss: 0.2322 - val_categorical_crossentropy: 0.2322 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4430 - val_dice_coefficient: 0.8446 - val_auc_1: 0.9531
# Epoch 8/50
# 47/47 [==============================] - 40s 846ms/step - loss: 0.2942 - categorical_crossentropy: 0.2942 - categorical_accuracy: 0.9210 - mean_iou: 0.4430 - dice_coefficient: 0.8441 - auc_1: 0.9257 - val_loss: 0.2265 - val_categorical_crossentropy: 0.2265 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4469 - val_dice_coefficient: 0.8542 - val_auc_1: 0.9531
# Epoch 9/50
# 47/47 [==============================] - 40s 844ms/step - loss: 0.2916 - categorical_crossentropy: 0.2916 - categorical_accuracy: 0.9210 - mean_iou: 0.4444 - dice_coefficient: 0.8474 - auc_1: 0.9260 - val_loss: 0.2253 - val_categorical_crossentropy: 0.2253 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4477 - val_dice_coefficient: 0.8564 - val_auc_1: 0.9532
# Epoch 10/50
# 47/47 [==============================] - 40s 846ms/step - loss: 0.2908 - categorical_crossentropy: 0.2908 - categorical_accuracy: 0.9210 - mean_iou: 0.4448 - dice_coefficient: 0.8486 - auc_1: 0.9260 - val_loss: 0.2246 - val_categorical_crossentropy: 0.2246 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4482 - val_dice_coefficient: 0.8578 - val_auc_1: 0.9532
# Epoch 11/50
# 47/47 [==============================] - 40s 844ms/step - loss: 0.2902 - categorical_crossentropy: 0.2902 - categorical_accuracy: 0.9210 - mean_iou: 0.4452 - dice_coefficient: 0.8495 - auc_1: 0.9261 - val_loss: 0.2244 - val_categorical_crossentropy: 0.2244 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4484 - val_dice_coefficient: 0.8583 - val_auc_1: 0.9533
# Epoch 12/50
# 47/47 [==============================] - 40s 845ms/step - loss: 0.2898 - categorical_crossentropy: 0.2898 - categorical_accuracy: 0.9210 - mean_iou: 0.4453 - dice_coefficient: 0.8500 - auc_1: 0.9260 - val_loss: 0.2244 - val_categorical_crossentropy: 0.2244 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4483 - val_dice_coefficient: 0.8581 - val_auc_1: 0.9533
# Epoch 13/50
# 47/47 [==============================] - 40s 844ms/step - loss: 0.2895 - categorical_crossentropy: 0.2895 - categorical_accuracy: 0.9210 - mean_iou: 0.4455 - dice_coefficient: 0.8504 - auc_1: 0.9260 - val_loss: 0.2248 - val_categorical_crossentropy: 0.2248 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4480 - val_dice_coefficient: 0.8575 - val_auc_1: 0.9534
# Epoch 14/50
# 47/47 [==============================] - 40s 843ms/step - loss: 0.2893 - categorical_crossentropy: 0.2893 - categorical_accuracy: 0.9210 - mean_iou: 0.4456 - dice_coefficient: 0.8506 - auc_1: 0.9260 - val_loss: 0.2252 - val_categorical_crossentropy: 0.2252 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4477 - val_dice_coefficient: 0.8567 - val_auc_1: 0.9534
# Epoch 15/50
# 47/47 [==============================] - 40s 844ms/step - loss: 0.2891 - categorical_crossentropy: 0.2891 - categorical_accuracy: 0.9210 - mean_iou: 0.4457 - dice_coefficient: 0.8507 - auc_1: 0.9260 - val_loss: 0.2258 - val_categorical_crossentropy: 0.2258 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4471 - val_dice_coefficient: 0.8554 - val_auc_1: 0.9535
# Epoch 16/50
# 47/47 [==============================] - 40s 844ms/step - loss: 0.2889 - categorical_crossentropy: 0.2889 - categorical_accuracy: 0.9210 - mean_iou: 0.4456 - dice_coefficient: 0.8506 - auc_1: 0.9258 - val_loss: 0.2268 - val_categorical_crossentropy: 0.2268 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4463 - val_dice_coefficient: 0.8536 - val_auc_1: 0.9535
# Epoch 17/50
# 47/47 [==============================] - 40s 844ms/step - loss: 0.2888 - categorical_crossentropy: 0.2888 - categorical_accuracy: 0.9210 - mean_iou: 0.4455 - dice_coefficient: 0.8503 - auc_1: 0.9257 - val_loss: 0.2278 - val_categorical_crossentropy: 0.2278 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4455 - val_dice_coefficient: 0.8518 - val_auc_1: 0.9535
# Epoch 18/50
# 47/47 [==============================] - 40s 843ms/step - loss: 0.2888 - categorical_crossentropy: 0.2888 - categorical_accuracy: 0.9210 - mean_iou: 0.4453 - dice_coefficient: 0.8499 - auc_1: 0.9255 - val_loss: 0.2289 - val_categorical_crossentropy: 0.2289 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4447 - val_dice_coefficient: 0.8499 - val_auc_1: 0.9536
# Epoch 19/50
# 47/47 [==============================] - 40s 844ms/step - loss: 0.2887 - categorical_crossentropy: 0.2887 - categorical_accuracy: 0.9210 - mean_iou: 0.4451 - dice_coefficient: 0.8494 - auc_1: 0.9254 - val_loss: 0.2300 - val_categorical_crossentropy: 0.2300 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4439 - val_dice_coefficient: 0.8480 - val_auc_1: 0.9536
# Epoch 20/50
# 47/47 [==============================] - 39s 842ms/step - loss: 0.2887 - categorical_crossentropy: 0.2887 - categorical_accuracy: 0.9210 - mean_iou: 0.4449 - dice_coefficient: 0.8488 - auc_1: 0.9252 - val_loss: 0.2313 - val_categorical_crossentropy: 0.2313 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4429 - val_dice_coefficient: 0.8459 - val_auc_1: 0.9536
# Epoch 21/50
# 47/47 [==============================] - 40s 844ms/step - loss: 0.2886 - categorical_crossentropy: 0.2886 - categorical_accuracy: 0.9210 - mean_iou: 0.4447 - dice_coefficient: 0.8481 - auc_1: 0.9251 - val_loss: 0.2334 - val_categorical_crossentropy: 0.2334 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4415 - val_dice_coefficient: 0.8427 - val_auc_1: 0.9536
# Epoch 22/50
# 47/47 [==============================] - 40s 844ms/step - loss: 0.2888 - categorical_crossentropy: 0.2888 - categorical_accuracy: 0.9210 - mean_iou: 0.4440 - dice_coefficient: 0.8466 - auc_1: 0.9247 - val_loss: 0.2337 - val_categorical_crossentropy: 0.2337 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4412 - val_dice_coefficient: 0.8421 - val_auc_1: 0.9536
# Epoch 23/50
# 47/47 [==============================] - 40s 844ms/step - loss: 0.2885 - categorical_crossentropy: 0.2885 - categorical_accuracy: 0.9210 - mean_iou: 0.4440 - dice_coefficient: 0.8464 - auc_1: 0.9247 - val_loss: 0.2347 - val_categorical_crossentropy: 0.2347 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4405 - val_dice_coefficient: 0.8406 - val_auc_1: 0.9536
# Epoch 24/50
# 47/47 [==============================] - 40s 844ms/step - loss: 0.2885 - categorical_crossentropy: 0.2885 - categorical_accuracy: 0.9210 - mean_iou: 0.4437 - dice_coefficient: 0.8456 - auc_1: 0.9245 - val_loss: 0.2356 - val_categorical_crossentropy: 0.2356 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4400 - val_dice_coefficient: 0.8393 - val_auc_1: 0.9536
# Epoch 25/50
# 47/47 [==============================] - 40s 844ms/step - loss: 0.2884 - categorical_crossentropy: 0.2884 - categorical_accuracy: 0.9210 - mean_iou: 0.4434 - dice_coefficient: 0.8449 - auc_1: 0.9245 - val_loss: 0.2363 - val_categorical_crossentropy: 0.2363 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4395 - val_dice_coefficient: 0.8382 - val_auc_1: 0.9536
# Epoch 26/50
# 47/47 [==============================] - 40s 843ms/step - loss: 0.2884 - categorical_crossentropy: 0.2884 - categorical_accuracy: 0.9210 - mean_iou: 0.4431 - dice_coefficient: 0.8441 - auc_1: 0.9243 - val_loss: 0.2376 - val_categorical_crossentropy: 0.2376 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4386 - val_dice_coefficient: 0.8363 - val_auc_1: 0.9537
# Epoch 27/50
# 47/47 [==============================] - 40s 843ms/step - loss: 0.2884 - categorical_crossentropy: 0.2884 - categorical_accuracy: 0.9210 - mean_iou: 0.4425 - dice_coefficient: 0.8427 - auc_1: 0.9242 - val_loss: 0.2375 - val_categorical_crossentropy: 0.2375 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4386 - val_dice_coefficient: 0.8364 - val_auc_1: 0.9538
# Epoch 28/50
# 47/47 [==============================] - 40s 843ms/step - loss: 0.2879 - categorical_crossentropy: 0.2879 - categorical_accuracy: 0.9210 - mean_iou: 0.4426 - dice_coefficient: 0.8426 - auc_1: 0.9244 - val_loss: 0.2389 - val_categorical_crossentropy: 0.2389 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4378 - val_dice_coefficient: 0.8344 - val_auc_1: 0.9539
# Epoch 29/50
# 47/47 [==============================] - 39s 842ms/step - loss: 0.2883 - categorical_crossentropy: 0.2883 - categorical_accuracy: 0.9210 - mean_iou: 0.4418 - dice_coefficient: 0.8408 - auc_1: 0.9241 - val_loss: 0.2379 - val_categorical_crossentropy: 0.2379 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4384 - val_dice_coefficient: 0.8358 - val_auc_1: 0.9538
# Epoch 30/50
# 47/47 [==============================] - 40s 843ms/step - loss: 0.2876 - categorical_crossentropy: 0.2876 - categorical_accuracy: 0.9210 - mean_iou: 0.4422 - dice_coefficient: 0.8414 - auc_1: 0.9244 - val_loss: 0.2388 - val_categorical_crossentropy: 0.2388 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4378 - val_dice_coefficient: 0.8344 - val_auc_1: 0.9540
# Epoch 31/50
# 47/47 [==============================] - 39s 842ms/step - loss: 0.2877 - categorical_crossentropy: 0.2877 - categorical_accuracy: 0.9210 - mean_iou: 0.4416 - dice_coefficient: 0.8400 - auc_1: 0.9243 - val_loss: 0.2381 - val_categorical_crossentropy: 0.2381 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4382 - val_dice_coefficient: 0.8354 - val_auc_1: 0.9540
# Epoch 32/50
# 47/47 [==============================] - 39s 840ms/step - loss: 0.2871 - categorical_crossentropy: 0.2871 - categorical_accuracy: 0.9210 - mean_iou: 0.4417 - dice_coefficient: 0.8401 - auc_1: 0.9246 - val_loss: 0.2380 - val_categorical_crossentropy: 0.2380 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4383 - val_dice_coefficient: 0.8355 - val_auc_1: 0.9541
# Epoch 33/50
# 47/47 [==============================] - 39s 842ms/step - loss: 0.2869 - categorical_crossentropy: 0.2869 - categorical_accuracy: 0.9210 - mean_iou: 0.4416 - dice_coefficient: 0.8397 - auc_1: 0.9247 - val_loss: 0.2377 - val_categorical_crossentropy: 0.2377 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4385 - val_dice_coefficient: 0.8359 - val_auc_1: 0.9542
# Epoch 34/50
# 47/47 [==============================] - 39s 842ms/step - loss: 0.2867 - categorical_crossentropy: 0.2867 - categorical_accuracy: 0.9210 - mean_iou: 0.4415 - dice_coefficient: 0.8394 - auc_1: 0.9249 - val_loss: 0.2371 - val_categorical_crossentropy: 0.2371 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4388 - val_dice_coefficient: 0.8367 - val_auc_1: 0.9542
# Epoch 35/50
# 47/47 [==============================] - 39s 841ms/step - loss: 0.2863 - categorical_crossentropy: 0.2863 - categorical_accuracy: 0.9210 - mean_iou: 0.4415 - dice_coefficient: 0.8393 - auc_1: 0.9251 - val_loss: 0.2367 - val_categorical_crossentropy: 0.2367 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4391 - val_dice_coefficient: 0.8373 - val_auc_1: 0.9543
# Epoch 36/50
# 47/47 [==============================] - 39s 841ms/step - loss: 0.2860 - categorical_crossentropy: 0.2860 - categorical_accuracy: 0.9210 - mean_iou: 0.4414 - dice_coefficient: 0.8391 - auc_1: 0.9252 - val_loss: 0.2360 - val_categorical_crossentropy: 0.2360 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4396 - val_dice_coefficient: 0.8383 - val_auc_1: 0.9543
# Epoch 37/50
# 47/47 [==============================] - 40s 843ms/step - loss: 0.2857 - categorical_crossentropy: 0.2857 - categorical_accuracy: 0.9210 - mean_iou: 0.4415 - dice_coefficient: 0.8391 - auc_1: 0.9253 - val_loss: 0.2353 - val_categorical_crossentropy: 0.2353 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4400 - val_dice_coefficient: 0.8393 - val_auc_1: 0.9543
# Epoch 38/50
# 47/47 [==============================] - 39s 841ms/step - loss: 0.2852 - categorical_crossentropy: 0.2852 - categorical_accuracy: 0.9210 - mean_iou: 0.4416 - dice_coefficient: 0.8391 - auc_1: 0.9256 - val_loss: 0.2346 - val_categorical_crossentropy: 0.2346 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4405 - val_dice_coefficient: 0.8403 - val_auc_1: 0.9544
# Epoch 39/50
# 47/47 [==============================] - 39s 842ms/step - loss: 0.2850 - categorical_crossentropy: 0.2850 - categorical_accuracy: 0.9210 - mean_iou: 0.4416 - dice_coefficient: 0.8391 - auc_1: 0.9258 - val_loss: 0.2338 - val_categorical_crossentropy: 0.2338 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4410 - val_dice_coefficient: 0.8414 - val_auc_1: 0.9544
# Epoch 40/50
# 47/47 [==============================] - 39s 842ms/step - loss: 0.2845 - categorical_crossentropy: 0.2845 - categorical_accuracy: 0.9210 - mean_iou: 0.4417 - dice_coefficient: 0.8392 - auc_1: 0.9260 - val_loss: 0.2331 - val_categorical_crossentropy: 0.2331 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4415 - val_dice_coefficient: 0.8425 - val_auc_1: 0.9544
# Epoch 41/50
# 47/47 [==============================] - 39s 842ms/step - loss: 0.2841 - categorical_crossentropy: 0.2841 - categorical_accuracy: 0.9210 - mean_iou: 0.4418 - dice_coefficient: 0.8394 - auc_1: 0.9263 - val_loss: 0.2323 - val_categorical_crossentropy: 0.2323 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4420 - val_dice_coefficient: 0.8436 - val_auc_1: 0.9545
# Epoch 42/50
# 47/47 [==============================] - 39s 841ms/step - loss: 0.2837 - categorical_crossentropy: 0.2837 - categorical_accuracy: 0.9210 - mean_iou: 0.4419 - dice_coefficient: 0.8395 - auc_1: 0.9265 - val_loss: 0.2316 - val_categorical_crossentropy: 0.2316 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4425 - val_dice_coefficient: 0.8448 - val_auc_1: 0.9545
# Epoch 43/50
# 47/47 [==============================] - 39s 842ms/step - loss: 0.2833 - categorical_crossentropy: 0.2833 - categorical_accuracy: 0.9210 - mean_iou: 0.4421 - dice_coefficient: 0.8398 - auc_1: 0.9268 - val_loss: 0.2308 - val_categorical_crossentropy: 0.2308 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4431 - val_dice_coefficient: 0.8460 - val_auc_1: 0.9545
# Epoch 44/50
# 47/47 [==============================] - 40s 843ms/step - loss: 0.2829 - categorical_crossentropy: 0.2829 - categorical_accuracy: 0.9210 - mean_iou: 0.4422 - dice_coefficient: 0.8401 - auc_1: 0.9271 - val_loss: 0.2300 - val_categorical_crossentropy: 0.2300 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4436 - val_dice_coefficient: 0.8472 - val_auc_1: 0.9546
# Epoch 45/50
# 47/47 [==============================] - 40s 843ms/step - loss: 0.2825 - categorical_crossentropy: 0.2825 - categorical_accuracy: 0.9210 - mean_iou: 0.4424 - dice_coefficient: 0.8404 - auc_1: 0.9274 - val_loss: 0.2292 - val_categorical_crossentropy: 0.2292 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4442 - val_dice_coefficient: 0.8484 - val_auc_1: 0.9546
# Epoch 46/50
# 47/47 [==============================] - 39s 842ms/step - loss: 0.2820 - categorical_crossentropy: 0.2820 - categorical_accuracy: 0.9210 - mean_iou: 0.4426 - dice_coefficient: 0.8407 - auc_1: 0.9277 - val_loss: 0.2285 - val_categorical_crossentropy: 0.2285 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4447 - val_dice_coefficient: 0.8497 - val_auc_1: 0.9547
# Epoch 47/50
# 47/47 [==============================] - 40s 843ms/step - loss: 0.2816 - categorical_crossentropy: 0.2816 - categorical_accuracy: 0.9210 - mean_iou: 0.4428 - dice_coefficient: 0.8410 - auc_1: 0.9280 - val_loss: 0.2278 - val_categorical_crossentropy: 0.2278 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4452 - val_dice_coefficient: 0.8508 - val_auc_1: 0.9547
# Epoch 48/50
# 47/47 [==============================] - 40s 843ms/step - loss: 0.2812 - categorical_crossentropy: 0.2812 - categorical_accuracy: 0.9210 - mean_iou: 0.4430 - dice_coefficient: 0.8415 - auc_1: 0.9283 - val_loss: 0.2270 - val_categorical_crossentropy: 0.2270 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4458 - val_dice_coefficient: 0.8520 - val_auc_1: 0.9547
# Epoch 49/50
# 47/47 [==============================] - 40s 843ms/step - loss: 0.2807 - categorical_crossentropy: 0.2807 - categorical_accuracy: 0.9210 - mean_iou: 0.4432 - dice_coefficient: 0.8419 - auc_1: 0.9287 - val_loss: 0.2264 - val_categorical_crossentropy: 0.2264 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4463 - val_dice_coefficient: 0.8532 - val_auc_1: 0.9547
# Epoch 50/50
# 47/47 [==============================] - 39s 842ms/step - loss: 0.2804 - categorical_crossentropy: 0.2804 - categorical_accuracy: 0.9210 - mean_iou: 0.4434 - dice_coefficient: 0.8423 - auc_1: 0.9289 - val_loss: 0.2257 - val_categorical_crossentropy: 0.2257 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4468 - val_dice_coefficient: 0.8544 - val_auc_1: 0.9548

# %% [markdown]
# **Task 4**: Let's predict mitochondria in the testing data! [15 Points]

# %%
# 
# After training, let's try the U-Net on our testing data.
#ask
# The code below displays the first 10 input images, the original ms by experts, 
# and the predicted masks from the U-Net.

# %%
rows = 10
fig, axs = plt.subplots(rows, 3, figsize=(8, 30))
for ax, (image, label) in zip(axs, test.take(rows).batch(1)):
  
  prediction = unet_model.predict(image)
  ax[0].matshow(image[0, :, :, 0])
  ax[1].matshow(label[0, :, :, 1], cmap="gray")
  ax[2].matshow(prediction[0].argmax(axis=-1), cmap="gray")

# %%
# 1) Question
# TODO: Why do we use the prediction[0].argmax(axis=-1) command
# to display the prediction?
# 
# TODO: YOUR ANSWER
# we use the prediction[0].argmax(axis=-1) command to display the prediction because the predicted masks start at 0th index of the array that will displayed by the argmax.

# %%
# 2) Question
# TODO: Is the quality of the segmentation good and how could we improve it?
# Hint: Think along the lines of some traditional image processing rather than
# increasing the training data size.
#
# TODO: YOUR ANSWER
# The quality of the segmentation is good and can be improved. we can see the horizontal and vertical and the 90 degree rotations.
#Here,The predicted masks are not viewed but the original masks seem nearly good.

# %% [markdown]
# **Bonus**: Compare against the state-of-the-art literature! [33 Points]

# %%
#
# The following paper also uses a 2D U-Net to detect mitochondria:
# 
# https://danielhaehn.com/papers/?casser2020fast
#

# %%
# 1) Question
#
# TODO: How many learnable parameters does your trained unet_model have?
# Hint: You can use TF's Model Summary function to answer this.
#

# %%
# TODO: YOUR CODE
writer = tf.summary.create_file_writer("content/mito.npz")
with writer.as_default():
  tf.summary.scalar("my_metric", 0.5, step=step)
  writer.flush()

# %%
# 2) Question
#
# TODO: How many parameters do Casser et al. use?

# %%
# TODO: YOUR ANSWER
#19,505,856 parameters

# %%
# 3) Question
#
# TODO: How did Casser et al. reduce the parameters?
#

# %%
# TODO: YOUR ANSWER
# Intially, they reduced the no. of convolutional filters throughout the network. We then replace the transpose convolutions in the decoder with light-weight bilinear upsampling layers that
# require no parameters. 
#parameter reduction for the encoder is 94%, i.e.,19,505,856 to 1,178,480. 
#parameter reduction for the decoder, it is 93.6% reduction i.e., 12,188,545 to 780,053.

# %%
# 4) Question
#
# TODO: Why did Casser et al. reduce the parameters?
#

# %%
# TODO: YOUR ANSWER
# For acheiving a 40% additional throughput which further increases effectiveness, the parameters are reduced.

# %%
#
# You made it!!
#
#                 _ ___                /^^\ /^\  /^^\_
#     _          _@)@) \            ,,/ '` ~ `'~~ ', `\.
#   _/o\_ _ _ _/~`.`...'~\        ./~~..,'`','',.,' '  ~:
#  / `,'.~,~.~  .   , . , ~|,   ,/ .,' , ,. .. ,,.   `,  ~\_
# ( ' _' _ '_` _  '  .    , `\_/ .' ..' '  `  `   `..  `,   \_
#  ~V~ V~ V~ V~ ~\ `   ' .  '    , ' .,.,''`.,.''`.,.``. ',   \_
#   _/\ /\ /\ /\_/, . ' ,   `_/~\_ .' .,. ,, , _/~\_ `. `. '.,  \_
#  < ~ ~ '~`'~'`, .,  .   `_: ::: \_ '      `_/ ::: \_ `.,' . ',  \_
#   \ ' `_  '`_    _    ',/ _::_::_ \ _    _/ _::_::_ \   `.,'.,`., \-,-,-,_,_,
#    `'~~ `'~~ `'~~ `'~~  \(_)(_)(_)/  `~~' \(_)(_)(_)/ ~'`\_.._,._,'_;_;_;_;_;
#
