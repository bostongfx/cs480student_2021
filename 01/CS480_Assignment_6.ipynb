# %% [markdown]
# <a href="https://colab.research.google.com/github/pushna99/cs480student/blob/main/01/CS480_Assignment_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![CS480_w.png](data:image/png;base64,...)
# #Assignment 6

# %%
# In this assignment, we will train a U-Net classifer to detect mitochondria
# in electron microscopy images!

# %%
### IMPORTANT ###
#
# Activate GPU support: Runtime -> Change Runtime Type
# Hardware Accelerator: GPU
#
### IMPORTANT ###

# %%
# load numpy and matplotlib
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# load the unet tensorflow code
# !pip install git+https://github.com/jakeret/unet.git
# Out:
# Collecting git+https://github.com/jakeret/unet.git
#   Cloning https://github.com/jakeret/unet.git to /tmp/pip-req-build-8dwx_pas
#   Running command git clone -q https://github.com/jakeret/unet.git /tmp/pip-req-build-8dwx_pas
# Building wheels for collected packages: unet
#   Building wheel for unet (setup.py) ... done
#   Created wheel for unet: filename=unet-0.0.post0.dev81+gf557a51-py2.py3-none-any.whl size=25658 sha256=19569daa02ce1ebe6b90595de908814e1cf146f2a82880b9861ea25a3f7cba58
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ektbqau7/wheels/f5/38/c8/8f0a157cfd7616cc1a24811a52b9a669c0ee8fccc9f99d3cbc
# Successfully built unet
# Installing collected packages: unet
# Successfully installed unet-0.0.post0.dev81+gf557a51

# %%
# .. and use it!
# Note: There are a ton of U-Net implementations but this one is easier to use!
import unet

# %% [markdown]
# **Task 1**: Study the unet circle example and learn about mitochondria! [15 Points]

# %%
# The unet package allows to train a U-Net classifier with little code.
# As discussed in class, the U-Net can be used to label/segment/annotate images.

# %%
# TODO: Please study the Circles example 
# https://github.com/jakeret/unet/blob/master/notebooks/circles.ipynb

# %%
# TODO: ... and look how the (artificial) dataset is generated
# https://github.com/jakeret/unet/blob/master/src/unet/datasets/circles.py

# %%
# 1) Question
# TODO: Please describe what the U-Net is trained to do.
#
# TODO: YOUR ANSWER
# UNet is a convolutional neural network architecture that expanded with few changes in the CNN architecture. 
# It was invented to deal with biomedical images where the target is not only to classify whether there 
# is an infection or not but also to identify the area of infection.

# %%
# 2) Question
# TODO: In circles.py, what does the following mean:
#     channels = 1
#     classes = 2
#
# TODO: YOUR ANSWER
# The channels are the number of input tensors in the following code and the channel is 1 in the code.
# The classes are the fundamental blueprint of the code and there are two classes that it can be differentiated in the code.

# %%
# 3) Question
# TODO: What are mitochondria and what is their appearance in
# electron microscopy data?
# Hint: You can validate your answer in Task 4!
#
# TODO: YOUR ANSWER
# Mitochondria are membrane-bound cell organelles that generate most of the chemical energy needed to power the cell's biochemical reactions. 
# Chemical energy produced by the mitochondria is stored in a small molecule called adenosine triphosphate (ATP).
# They are also referred to as "The Power House of the Cell".
# Mitochondria have a distinctive appearance when viewed by electron microscopy. 
# They often appear as rounded or sausage-shaped structures measuring about 0.5-1.0 µm in diameter and 2-8 µm in length; 
# although their size and shape vary, and they are often much bigger in plants.

# %% [markdown]
# **Task 2**: Setup a datagenerator for mitochondria images! [45 Points]

# %%
# TODO: 
# Download https://cs480.org/data/mito.npz to your computer.
# Then, please upload mito.npz using the file panel on the left.

# %%
# The code below is similar to the circles.py file from Task 1.
# We follow Tensorflow conventions to design a tf.data.Dataset for training
# the U-Net.
#
# TODO: Please add four different data augmentation methods in the code block
# below. (image normalization to 0..1, horizontal data flip, vertical data flip,
# rotation by 90 degrees)
#
# Hint: https://github.com/jakeret/unet/blob/master/src/unet/datasets/oxford_iiit_pet.py#L25

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow_datasets.core import DatasetInfo
from typing import Tuple, List

IMAGE_SIZE = (256, 256)
channels = 1
classes = 2

def load_data(count:int, splits:Tuple[float]=(0.7, 0.2, 0.1), **kwargs) -> List[tf.data.Dataset]:
    return [tf.data.Dataset.from_tensor_slices(_build_samples(int(split * count), **kwargs))
            for split in splits]


def _build_samples(sample_count:int, **kwargs) -> Tuple[np.array, np.array]:

    # here we load the mitochondria data
    loaded = np.load('mito.npz')
    loadedimages = loaded['arr_0'][0].copy()
    loadedmasks = loaded['arr_0'][1].copy()

    # now let's go to numpyland
    images = np.empty((sample_count, IMAGE_SIZE[0], IMAGE_SIZE[1], 1))
    labels = np.empty((sample_count, IMAGE_SIZE[0], IMAGE_SIZE[1], 2))
    for i in range(sample_count):
        image, mask = loadedimages[i], loadedmasks[i]

        image = image.reshape((IMAGE_SIZE[0], IMAGE_SIZE[1], 1)).astype(np.float)
        mask = mask.reshape((IMAGE_SIZE[0], IMAGE_SIZE[1], 1))

        #
        # TODO: Normalize the image to 0..1

        #
        # TODO: YOUR CODE
        # 
        images =  tf.image.per_image_standardization(images)
        #mask= tf.image.per_image_standardization(mask)

        
        #
        # TODO: Use Tensorflow to flip the image horizontally
        #
        if tf.random.uniform(()) > 0.5:
            #
            # TODO: YOUR CODE
            image = tf.image.flip_left_right(image)
            #mask = tf.image.flip_left_right(mask)
            
        #
        # TODO: Use Tensorflow to flip the image vertically
        #
        if tf.random.uniform(()) > 0.5:
            #
            # TODO: YOUR CODE
            image = tf.image.flip_up_down(image)
            #mask = tf.image.flip_up_down(mask) 

        #
        # TODO: Use Tensorflow to rotate the image 90 degrees
        #
        if tf.random.uniform(()) > 0.5:
            #
            # TODO: YOUR CODE
            image = tf.image.rot90(image, k=1)
            #mask = tf.image.rot90(mask,k=1)

        # augmentation done, let's store the image
        images[i] = image

        # here we split the mask to background and foreground
        fg = np.zeros((IMAGE_SIZE[0], IMAGE_SIZE[1], 1), dtype=np.bool)
        fg[mask == 255] = 1
        bg = np.zeros((IMAGE_SIZE[0], IMAGE_SIZE[1], 1), dtype=np.bool)
        bg[mask == 0] = 1
        
        labels[i, :, :, 0] = bg[:,:,0]
        labels[i, :, :, 1] = fg[:,:,0]

    return images, labels

# %% [markdown]
# **Task 3**: Let's train the U-Net! [25 Points]

# %%
#
# We can now create our training, validation, and testing data by calling
# our methods from Task 2.
#
train, val, test = load_data( 660, splits=(0.7, 0.2, 0.1) )

# %%
# 1) Question
# TODO: We have in total 660 images + 660 masks. Based on the code above,
# how many images are used for training alone?
# 462 images

# %%
#
# Let's setup the U-Net!
#
LEARNING_RATE = 1e-3

unet_model = unet.build_model(channels=channels,
                              num_classes=classes,
                              layer_depth=5,
                              filters_root=64,
                              padding="same")

unet.finalize_model(unet_model, learning_rate=LEARNING_RATE)

# %%
#
# And, let's setup the trainer...
#
trainer = unet.Trainer(checkpoint_callback=False,
                       learning_rate_scheduler=unet.SchedulerType.WARMUP_LINEAR_DECAY,
                       warmup_proportion=0.1,
                       learning_rate=LEARNING_RATE)

# %%
#
# ...and train the U-Net for 50 epochs with a batch_size of 10!
#
# TODO: Please complete the code below.
# Hint: Don't forget to use training and validation data.
# Hint 2: This will take roughly 30 minutes!
#
trainer.fit(unet_model,
            train,
            val,
            epochs=50,
            batch_size=10
            )
# Out:
# Epoch 1/50
# 47/47 [==============================] - 59s 1s/step - loss: 8.6401 - categorical_crossentropy: 8.6401 - categorical_accuracy: 0.6212 - mean_iou: 0.2904 - dice_coefficient: 0.5312 - auc: 0.5405 - val_loss: 0.2029 - val_categorical_crossentropy: 0.2029 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4757 - val_dice_coefficient: 0.9196 - val_auc: 0.9817
# Epoch 2/50
# 47/47 [==============================] - 38s 810ms/step - loss: 0.7586 - categorical_crossentropy: 0.7586 - categorical_accuracy: 0.9029 - mean_iou: 0.3691 - dice_coefficient: 0.6816 - auc: 0.7975 - val_loss: 0.6931 - val_categorical_crossentropy: 0.6931 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.2702 - val_dice_coefficient: 0.5000 - val_auc: 0.5004
# Epoch 3/50
# 47/47 [==============================] - 38s 820ms/step - loss: 0.5907 - categorical_crossentropy: 0.5907 - categorical_accuracy: 0.9159 - mean_iou: 0.3515 - dice_coefficient: 0.6461 - auc: 0.7790 - val_loss: 0.4086 - val_categorical_crossentropy: 0.4086 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3615 - val_dice_coefficient: 0.6718 - val_auc: 0.9774
# Epoch 4/50
# 47/47 [==============================] - 39s 826ms/step - loss: 0.3414 - categorical_crossentropy: 0.3414 - categorical_accuracy: 0.9188 - mean_iou: 0.4424 - dice_coefficient: 0.8307 - auc: 0.9364 - val_loss: 0.6680 - val_categorical_crossentropy: 0.6680 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.2771 - val_dice_coefficient: 0.5131 - val_auc: 0.9449
# Epoch 5/50
# 47/47 [==============================] - 39s 834ms/step - loss: 0.3043 - categorical_crossentropy: 0.3043 - categorical_accuracy: 0.9195 - mean_iou: 0.4503 - dice_coefficient: 0.8476 - auc: 0.9426 - val_loss: 0.3893 - val_categorical_crossentropy: 0.3893 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3687 - val_dice_coefficient: 0.6860 - val_auc: 0.9816
# Epoch 6/50
# 47/47 [==============================] - 39s 832ms/step - loss: 0.2831 - categorical_crossentropy: 0.2831 - categorical_accuracy: 0.9203 - mean_iou: 0.4556 - dice_coefficient: 0.8589 - auc: 0.9440 - val_loss: 0.5518 - val_categorical_crossentropy: 0.5518 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3114 - val_dice_coefficient: 0.5777 - val_auc: 0.9806
# Epoch 7/50
# 47/47 [==============================] - 39s 834ms/step - loss: 0.2736 - categorical_crossentropy: 0.2736 - categorical_accuracy: 0.9206 - mean_iou: 0.4552 - dice_coefficient: 0.8558 - auc: 0.9465 - val_loss: 0.4656 - val_categorical_crossentropy: 0.4656 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3403 - val_dice_coefficient: 0.6321 - val_auc: 0.9834
# Epoch 8/50
# 47/47 [==============================] - 39s 836ms/step - loss: 0.2788 - categorical_crossentropy: 0.2788 - categorical_accuracy: 0.9206 - mean_iou: 0.4538 - dice_coefficient: 0.8547 - auc: 0.9439 - val_loss: 0.5742 - val_categorical_crossentropy: 0.5742 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3046 - val_dice_coefficient: 0.5649 - val_auc: 0.9763
# Epoch 9/50
# 47/47 [==============================] - 39s 834ms/step - loss: 0.2818 - categorical_crossentropy: 0.2818 - categorical_accuracy: 0.9207 - mean_iou: 0.4509 - dice_coefficient: 0.8481 - auc: 0.9427 - val_loss: 0.5525 - val_categorical_crossentropy: 0.5525 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3114 - val_dice_coefficient: 0.5776 - val_auc: 0.9802
# Epoch 10/50
# 47/47 [==============================] - 39s 835ms/step - loss: 0.2808 - categorical_crossentropy: 0.2808 - categorical_accuracy: 0.9207 - mean_iou: 0.4510 - dice_coefficient: 0.8477 - auc: 0.9428 - val_loss: 0.5032 - val_categorical_crossentropy: 0.5032 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3273 - val_dice_coefficient: 0.6078 - val_auc: 0.9821
# Epoch 11/50
# 47/47 [==============================] - 39s 837ms/step - loss: 0.2794 - categorical_crossentropy: 0.2794 - categorical_accuracy: 0.9208 - mean_iou: 0.4503 - dice_coefficient: 0.8460 - auc: 0.9417 - val_loss: 0.4953 - val_categorical_crossentropy: 0.4953 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3301 - val_dice_coefficient: 0.6130 - val_auc: 0.9808
# Epoch 12/50
# 47/47 [==============================] - 39s 840ms/step - loss: 0.2736 - categorical_crossentropy: 0.2736 - categorical_accuracy: 0.9208 - mean_iou: 0.4539 - dice_coefficient: 0.8540 - auc: 0.9434 - val_loss: 0.4570 - val_categorical_crossentropy: 0.4570 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3432 - val_dice_coefficient: 0.6379 - val_auc: 0.9831
# Epoch 13/50
# 47/47 [==============================] - 39s 840ms/step - loss: 0.2741 - categorical_crossentropy: 0.2741 - categorical_accuracy: 0.9209 - mean_iou: 0.4535 - dice_coefficient: 0.8534 - auc: 0.9440 - val_loss: 0.5114 - val_categorical_crossentropy: 0.5114 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3248 - val_dice_coefficient: 0.6029 - val_auc: 0.9771
# Epoch 14/50
# 47/47 [==============================] - 39s 841ms/step - loss: 0.2725 - categorical_crossentropy: 0.2725 - categorical_accuracy: 0.9209 - mean_iou: 0.4534 - dice_coefficient: 0.8524 - auc: 0.9433 - val_loss: 0.4431 - val_categorical_crossentropy: 0.4431 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3483 - val_dice_coefficient: 0.6477 - val_auc: 0.9827
# Epoch 15/50
# 47/47 [==============================] - 39s 839ms/step - loss: 0.2696 - categorical_crossentropy: 0.2696 - categorical_accuracy: 0.9209 - mean_iou: 0.4557 - dice_coefficient: 0.8578 - auc: 0.9445 - val_loss: 0.5125 - val_categorical_crossentropy: 0.5125 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3244 - val_dice_coefficient: 0.6023 - val_auc: 0.9758
# Epoch 16/50
# 47/47 [==============================] - 39s 840ms/step - loss: 0.2699 - categorical_crossentropy: 0.2699 - categorical_accuracy: 0.9209 - mean_iou: 0.4552 - dice_coefficient: 0.8565 - auc: 0.9442 - val_loss: 0.4293 - val_categorical_crossentropy: 0.4293 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3533 - val_dice_coefficient: 0.6572 - val_auc: 0.9827
# Epoch 17/50
# 47/47 [==============================] - 39s 840ms/step - loss: 0.2686 - categorical_crossentropy: 0.2686 - categorical_accuracy: 0.9210 - mean_iou: 0.4555 - dice_coefficient: 0.8571 - auc: 0.9449 - val_loss: 0.5261 - val_categorical_crossentropy: 0.5261 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3200 - val_dice_coefficient: 0.5940 - val_auc: 0.9733
# Epoch 18/50
# 47/47 [==============================] - 39s 839ms/step - loss: 0.2694 - categorical_crossentropy: 0.2694 - categorical_accuracy: 0.9209 - mean_iou: 0.4550 - dice_coefficient: 0.8561 - auc: 0.9442 - val_loss: 0.4301 - val_categorical_crossentropy: 0.4301 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3530 - val_dice_coefficient: 0.6567 - val_auc: 0.9821
# Epoch 19/50
# 47/47 [==============================] - 39s 841ms/step - loss: 0.2671 - categorical_crossentropy: 0.2671 - categorical_accuracy: 0.9210 - mean_iou: 0.4561 - dice_coefficient: 0.8585 - auc: 0.9455 - val_loss: 0.5134 - val_categorical_crossentropy: 0.5134 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3242 - val_dice_coefficient: 0.6020 - val_auc: 0.9765
# Epoch 20/50
# 47/47 [==============================] - 39s 840ms/step - loss: 0.2670 - categorical_crossentropy: 0.2670 - categorical_accuracy: 0.9210 - mean_iou: 0.4565 - dice_coefficient: 0.8592 - auc: 0.9453 - val_loss: 0.4387 - val_categorical_crossentropy: 0.4387 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3499 - val_dice_coefficient: 0.6506 - val_auc: 0.9799
# Epoch 21/50
# 47/47 [==============================] - 39s 839ms/step - loss: 0.2662 - categorical_crossentropy: 0.2662 - categorical_accuracy: 0.9210 - mean_iou: 0.4567 - dice_coefficient: 0.8600 - auc: 0.9458 - val_loss: 0.5215 - val_categorical_crossentropy: 0.5215 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3216 - val_dice_coefficient: 0.5970 - val_auc: 0.9719
# Epoch 22/50
# 47/47 [==============================] - 39s 839ms/step - loss: 0.2661 - categorical_crossentropy: 0.2661 - categorical_accuracy: 0.9210 - mean_iou: 0.4573 - dice_coefficient: 0.8611 - auc: 0.9458 - val_loss: 0.4415 - val_categorical_crossentropy: 0.4415 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3489 - val_dice_coefficient: 0.6488 - val_auc: 0.9791
# Epoch 23/50
# 47/47 [==============================] - 39s 840ms/step - loss: 0.2656 - categorical_crossentropy: 0.2656 - categorical_accuracy: 0.9210 - mean_iou: 0.4569 - dice_coefficient: 0.8601 - auc: 0.9461 - val_loss: 0.5271 - val_categorical_crossentropy: 0.5271 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3198 - val_dice_coefficient: 0.5937 - val_auc: 0.9728
# Epoch 24/50
# 47/47 [==============================] - 39s 837ms/step - loss: 0.2653 - categorical_crossentropy: 0.2653 - categorical_accuracy: 0.9210 - mean_iou: 0.4575 - dice_coefficient: 0.8613 - auc: 0.9462 - val_loss: 0.4487 - val_categorical_crossentropy: 0.4487 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3462 - val_dice_coefficient: 0.6438 - val_auc: 0.9785
# Epoch 25/50
# 47/47 [==============================] - 39s 838ms/step - loss: 0.2647 - categorical_crossentropy: 0.2647 - categorical_accuracy: 0.9210 - mean_iou: 0.4571 - dice_coefficient: 0.8603 - auc: 0.9464 - val_loss: 0.5163 - val_categorical_crossentropy: 0.5163 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3232 - val_dice_coefficient: 0.6001 - val_auc: 0.9726
# Epoch 26/50
# 47/47 [==============================] - 39s 838ms/step - loss: 0.2647 - categorical_crossentropy: 0.2647 - categorical_accuracy: 0.9210 - mean_iou: 0.4576 - dice_coefficient: 0.8616 - auc: 0.9464 - val_loss: 0.4602 - val_categorical_crossentropy: 0.4602 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3422 - val_dice_coefficient: 0.6361 - val_auc: 0.9786
# Epoch 27/50
# 47/47 [==============================] - 39s 838ms/step - loss: 0.2646 - categorical_crossentropy: 0.2646 - categorical_accuracy: 0.9210 - mean_iou: 0.4572 - dice_coefficient: 0.8608 - auc: 0.9464 - val_loss: 0.4788 - val_categorical_crossentropy: 0.4788 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3358 - val_dice_coefficient: 0.6240 - val_auc: 0.9782
# Epoch 28/50
# 47/47 [==============================] - 39s 838ms/step - loss: 0.2637 - categorical_crossentropy: 0.2637 - categorical_accuracy: 0.9210 - mean_iou: 0.4580 - dice_coefficient: 0.8622 - auc: 0.9471 - val_loss: 0.4764 - val_categorical_crossentropy: 0.4764 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3365 - val_dice_coefficient: 0.6254 - val_auc: 0.9778
# Epoch 29/50
# 47/47 [==============================] - 39s 838ms/step - loss: 0.2637 - categorical_crossentropy: 0.2637 - categorical_accuracy: 0.9210 - mean_iou: 0.4571 - dice_coefficient: 0.8597 - auc: 0.9469 - val_loss: 0.4702 - val_categorical_crossentropy: 0.4702 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3386 - val_dice_coefficient: 0.6293 - val_auc: 0.9796
# Epoch 30/50
# 47/47 [==============================] - 39s 837ms/step - loss: 0.2638 - categorical_crossentropy: 0.2638 - categorical_accuracy: 0.9210 - mean_iou: 0.4574 - dice_coefficient: 0.8610 - auc: 0.9467 - val_loss: 0.4981 - val_categorical_crossentropy: 0.4981 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3290 - val_dice_coefficient: 0.6113 - val_auc: 0.9768
# Epoch 31/50
# 47/47 [==============================] - 39s 838ms/step - loss: 0.2633 - categorical_crossentropy: 0.2633 - categorical_accuracy: 0.9210 - mean_iou: 0.4579 - dice_coefficient: 0.8619 - auc: 0.9471 - val_loss: 0.4229 - val_categorical_crossentropy: 0.4229 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3557 - val_dice_coefficient: 0.6618 - val_auc: 0.9815
# Epoch 32/50
# 47/47 [==============================] - 39s 838ms/step - loss: 0.2631 - categorical_crossentropy: 0.2631 - categorical_accuracy: 0.9210 - mean_iou: 0.4576 - dice_coefficient: 0.8614 - auc: 0.9472 - val_loss: 0.5132 - val_categorical_crossentropy: 0.5132 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3241 - val_dice_coefficient: 0.6019 - val_auc: 0.9750
# Epoch 33/50
# 47/47 [==============================] - 39s 839ms/step - loss: 0.2624 - categorical_crossentropy: 0.2624 - categorical_accuracy: 0.9210 - mean_iou: 0.4586 - dice_coefficient: 0.8633 - auc: 0.9478 - val_loss: 0.4423 - val_categorical_crossentropy: 0.4423 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3485 - val_dice_coefficient: 0.6482 - val_auc: 0.9798
# Epoch 34/50
# 47/47 [==============================] - 39s 837ms/step - loss: 0.2630 - categorical_crossentropy: 0.2630 - categorical_accuracy: 0.9210 - mean_iou: 0.4569 - dice_coefficient: 0.8593 - auc: 0.9470 - val_loss: 0.4680 - val_categorical_crossentropy: 0.4680 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3395 - val_dice_coefficient: 0.6310 - val_auc: 0.9783
# Epoch 35/50
# 47/47 [==============================] - 39s 839ms/step - loss: 0.2629 - categorical_crossentropy: 0.2629 - categorical_accuracy: 0.9210 - mean_iou: 0.4575 - dice_coefficient: 0.8605 - auc: 0.9472 - val_loss: 0.4848 - val_categorical_crossentropy: 0.4848 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3337 - val_dice_coefficient: 0.6199 - val_auc: 0.9772
# Epoch 36/50
# 47/47 [==============================] - 39s 839ms/step - loss: 0.2627 - categorical_crossentropy: 0.2627 - categorical_accuracy: 0.9210 - mean_iou: 0.4570 - dice_coefficient: 0.8588 - auc: 0.9473 - val_loss: 0.4939 - val_categorical_crossentropy: 0.4939 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3305 - val_dice_coefficient: 0.6140 - val_auc: 0.9768
# Epoch 37/50
# 47/47 [==============================] - 39s 838ms/step - loss: 0.2623 - categorical_crossentropy: 0.2623 - categorical_accuracy: 0.9210 - mean_iou: 0.4567 - dice_coefficient: 0.8578 - auc: 0.9475 - val_loss: 0.5004 - val_categorical_crossentropy: 0.5004 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3284 - val_dice_coefficient: 0.6099 - val_auc: 0.9757
# Epoch 38/50
# 47/47 [==============================] - 39s 838ms/step - loss: 0.2618 - categorical_crossentropy: 0.2618 - categorical_accuracy: 0.9210 - mean_iou: 0.4564 - dice_coefficient: 0.8565 - auc: 0.9479 - val_loss: 0.4868 - val_categorical_crossentropy: 0.4868 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3329 - val_dice_coefficient: 0.6185 - val_auc: 0.9768
# Epoch 39/50
# 47/47 [==============================] - 39s 837ms/step - loss: 0.2615 - categorical_crossentropy: 0.2615 - categorical_accuracy: 0.9210 - mean_iou: 0.4562 - dice_coefficient: 0.8562 - auc: 0.9480 - val_loss: 0.4989 - val_categorical_crossentropy: 0.4989 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3289 - val_dice_coefficient: 0.6108 - val_auc: 0.9757
# Epoch 40/50
# 47/47 [==============================] - 39s 838ms/step - loss: 0.2609 - categorical_crossentropy: 0.2609 - categorical_accuracy: 0.9210 - mean_iou: 0.4561 - dice_coefficient: 0.8553 - auc: 0.9485 - val_loss: 0.4995 - val_categorical_crossentropy: 0.4995 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3287 - val_dice_coefficient: 0.6105 - val_auc: 0.9753
# Epoch 41/50
# 47/47 [==============================] - 39s 838ms/step - loss: 0.2602 - categorical_crossentropy: 0.2602 - categorical_accuracy: 0.9210 - mean_iou: 0.4562 - dice_coefficient: 0.8549 - auc: 0.9490 - val_loss: 0.4977 - val_categorical_crossentropy: 0.4977 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3293 - val_dice_coefficient: 0.6116 - val_auc: 0.9753
# Epoch 42/50
# 47/47 [==============================] - 39s 838ms/step - loss: 0.2596 - categorical_crossentropy: 0.2596 - categorical_accuracy: 0.9210 - mean_iou: 0.4562 - dice_coefficient: 0.8548 - auc: 0.9495 - val_loss: 0.4953 - val_categorical_crossentropy: 0.4953 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3301 - val_dice_coefficient: 0.6131 - val_auc: 0.9752
# Epoch 43/50
# 47/47 [==============================] - 39s 838ms/step - loss: 0.2589 - categorical_crossentropy: 0.2589 - categorical_accuracy: 0.9210 - mean_iou: 0.4564 - dice_coefficient: 0.8548 - auc: 0.9499 - val_loss: 0.4966 - val_categorical_crossentropy: 0.4966 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3297 - val_dice_coefficient: 0.6123 - val_auc: 0.9747
# Epoch 44/50
# 47/47 [==============================] - 39s 837ms/step - loss: 0.2580 - categorical_crossentropy: 0.2580 - categorical_accuracy: 0.9210 - mean_iou: 0.4568 - dice_coefficient: 0.8550 - auc: 0.9506 - val_loss: 0.4940 - val_categorical_crossentropy: 0.4940 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3305 - val_dice_coefficient: 0.6139 - val_auc: 0.9745
# Epoch 45/50
# 47/47 [==============================] - 39s 839ms/step - loss: 0.2570 - categorical_crossentropy: 0.2570 - categorical_accuracy: 0.9210 - mean_iou: 0.4570 - dice_coefficient: 0.8550 - auc: 0.9513 - val_loss: 0.4944 - val_categorical_crossentropy: 0.4944 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3304 - val_dice_coefficient: 0.6137 - val_auc: 0.9739
# Epoch 46/50
# 47/47 [==============================] - 39s 839ms/step - loss: 0.2564 - categorical_crossentropy: 0.2564 - categorical_accuracy: 0.9210 - mean_iou: 0.4575 - dice_coefficient: 0.8558 - auc: 0.9517 - val_loss: 0.4915 - val_categorical_crossentropy: 0.4915 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3314 - val_dice_coefficient: 0.6155 - val_auc: 0.9740
# Epoch 47/50
# 47/47 [==============================] - 39s 837ms/step - loss: 0.2553 - categorical_crossentropy: 0.2553 - categorical_accuracy: 0.9210 - mean_iou: 0.4576 - dice_coefficient: 0.8552 - auc: 0.9525 - val_loss: 0.4903 - val_categorical_crossentropy: 0.4903 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3318 - val_dice_coefficient: 0.6163 - val_auc: 0.9736
# Epoch 48/50
# 47/47 [==============================] - 39s 839ms/step - loss: 0.2542 - categorical_crossentropy: 0.2542 - categorical_accuracy: 0.9210 - mean_iou: 0.4584 - dice_coefficient: 0.8565 - auc: 0.9531 - val_loss: 0.4901 - val_categorical_crossentropy: 0.4901 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3319 - val_dice_coefficient: 0.6164 - val_auc: 0.9734
# Epoch 49/50
# 47/47 [==============================] - 39s 837ms/step - loss: 0.2532 - categorical_crossentropy: 0.2532 - categorical_accuracy: 0.9210 - mean_iou: 0.4586 - dice_coefficient: 0.8562 - auc: 0.9538 - val_loss: 0.4893 - val_categorical_crossentropy: 0.4893 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3322 - val_dice_coefficient: 0.6170 - val_auc: 0.9732
# Epoch 50/50
# 47/47 [==============================] - 39s 838ms/step - loss: 0.2518 - categorical_crossentropy: 0.2518 - categorical_accuracy: 0.9210 - mean_iou: 0.4594 - dice_coefficient: 0.8573 - auc: 0.9546 - val_loss: 0.4882 - val_categorical_crossentropy: 0.4882 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3326 - val_dice_coefficient: 0.6177 - val_auc: 0.9731

# %% [markdown]
# **Task 4**: Let's predict mitochondria in the testing data! [15 Points]

# %%
# 
# After training, let's try the U-Net on our testing data.
#
# The code below displays the first 10 input images, the original masks by experts, 
# and the predicted masks from the U-Net.

# %%
rows = 10
fig, axs = plt.subplots(rows, 3, figsize=(8, 30))
for ax, (image, label) in zip(axs, test.take(rows).batch(1)):
  
  prediction = unet_model.predict(image)
  ax[0].matshow(image[0, :, :, 0])
  ax[1].matshow(label[0, :, :, 1], cmap="gray")
  ax[2].matshow(prediction[0].argmax(axis=-1), cmap='gray')

# %%
# 1) Question
# TODO: Why do we use the prediction[0].argmax(axis=-1) command
# to display the prediction?
# 
# TODO: 
# because the predicted masks start at 0 index of the array that will be displayed by argmax

# %%
# 2) Question
# TODO: Is the quality of the segmentation good and how could we improve it?
# Hint: Think along the lines of some traditional image processing rather than
# increasing the training data size.
#
# TODO: YOUR ANSWER
# The segmentation is pretty good and can be improved. we can see the horizontal and vertical and the 90 degree rotations.
# For one thing, the predicted masks are not viewed but the original masks seem nearly good.

# %% [markdown]
# **Bonus**: Compare against the state-of-the-art literature! [33 Points]

# %%
#
# The following paper also uses a 2D U-Net to detect mitochondria:
# 
# https://danielhaehn.com/papers/?casser2020fast
#

# %%
# 1) Question
#
# TODO: How many learnable parameters does your trained unet_model have?
# Hint: You can use TF's Model Summary function to answer this.
#

# %%
# TODO: YOUR CODE

# %%
writer = tf.summary.create_file_writer("content/mito.npz")
with writer.as_default():
  tf.summary.scalar("my_metric", 0.5, step=step)
  writer.flush()

# %%
# 2) Question
#
# TODO: How many parameters do Casser et al. use?
#

# %%
# TODO: YOUR ANSWER

# %%
# 19,505,856 parameters

# %%
# 3) Question
#
# TODO: How did Casser et al. reduce the parameters?

# %%
# TODO: YOUR ANSWER

# %%
# Firstly, they reduced the number of convolutional filters throughout the network. We then replace
# transpose convolutions in the decoder with light-weight bilinear upsampling layers that
# require no parameters. For the encoder, parameter reduction is 94%, i.e., 19,505,856 to 1,178,480
# For the decoder, it is 93.6% reduction i.e., 12,188,545 to 780,053.

# %%
# 4) Question
#
# TODO: Why did Casser et al. reduce the parameters?
#

# %%
# TODO: YOUR ANSWER

# %%
# The parameters are reduced to acheive a 40% additional throughput which further increases effectiveness

# %%
#
# You made it!!
#
#                 _ ___                /^^\ /^\  /^^\_
#     _          _@)@) \            ,,/ '` ~ `'~~ ', `\.
#   _/o\_ _ _ _/~`.`...'~\        ./~~..,'`','',.,' '  ~:
#  / `,'.~,~.~  .   , . , ~|,   ,/ .,' , ,. .. ,,.   `,  ~\_
# ( ' _' _ '_` _  '  .    , `\_/ .' ..' '  `  `   `..  `,   \_
#  ~V~ V~ V~ V~ ~\ `   ' .  '    , ' .,.,''`.,.''`.,.``. ',   \_
#   _/\ /\ /\ /\_/, . ' ,   `_/~\_ .' .,. ,, , _/~\_ `. `. '.,  \_
#  < ~ ~ '~`'~'`, .,  .   `_: ::: \_ '      `_/ ::: \_ `.,' . ',  \_
#   \ ' `_  '`_    _    ',/ _::_::_ \ _    _/ _::_::_ \   `.,'.,`., \-,-,-,_,_,
#    `'~~ `'~~ `'~~ `'~~  \(_)(_)(_)/  `~~' \(_)(_)(_)/ ~'`\_.._,._,'_;_;_;_;_;
#
