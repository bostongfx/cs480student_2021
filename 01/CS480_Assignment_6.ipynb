# %% [markdown]
# <a href="https://colab.research.google.com/github/Shreyapotlapally/cs480student/blob/main/01/CS480_Assignment_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![CS480_w.png](data:image/png;base64,...)
# #Assignment 6

# %%
# In this assignment, we will train a U-Net classifer to detect mitochondria
# in electron microscopy images!

# %%
### IMPORTANT ###
#
# Activate GPU support: Runtime -> Change Runtime Type
# Hardware Accelerator: GPU
#
### IMPORTANT ###

# %%
# load numpy and matplotlib
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# load the unet tensorflow code
# !pip install git+https://github.com/jakeret/unet.git
# Out:
# Collecting git+https://github.com/jakeret/unet.git
#   Cloning https://github.com/jakeret/unet.git to /tmp/pip-req-build-t6u4_def
#   Running command git clone -q https://github.com/jakeret/unet.git /tmp/pip-req-build-t6u4_def
# Building wheels for collected packages: unet
#   Building wheel for unet (setup.py) ... done
#   Created wheel for unet: filename=unet-0.0.post0.dev81+gf557a51-py2.py3-none-any.whl size=25658 sha256=de3fcadc0d92656db25f282cdd16dda98c46463365c85e683085bff381701400
#   Stored in directory: /tmp/pip-ephem-wheel-cache-j6o7csv9/wheels/f5/38/c8/8f0a157cfd7616cc1a24811a52b9a669c0ee8fccc9f99d3cbc
# Successfully built unet
# Installing collected packages: unet
# Successfully installed unet-0.0.post0.dev81+gf557a51

# %%
# .. and use it!
# Note: There are a ton of U-Net implementations but this one is easier to use!
import unet

# %% [markdown]
# **Task 1**: Study the unet circle example and learn about mitochondria! [15 Points]

# %%
# The unet package allows to train a U-Net classifier with little code.
# As discussed in class, the U-Net can be used to label/segment/annotate images.

# %%
# TODO: Please study the Circles example 
# https://github.com/jakeret/unet/blob/master/notebooks/circles.ipynb

# %%
# TODO: ... and look how the (artificial) dataset is generated
# https://github.com/jakeret/unet/blob/master/src/unet/datasets/circles.py

# %%
# 1) Question
# TODO: Please describe what the U-Net is trained to do.
# It deals with the biomedical images and is used to convert the input image into the output segmentation map.
# TODO: YOUR ANSWER

# %%
# 2) Question
# TODO: In circles.py, what does the following mean:
#     channels = 1
#     classes = 2
# The channels represent the number of input tensors whereas the classes represent the fundamental blueprint of the code.

# TODO: YOUR ANSWER

# %%
# 3) Question
# TODO: What are mitochondria and what is their appearance in
# electron microscopy data?
# Hint: You can validate your answer in Task 4!
# Mitochondria are membrane-bound cell organelles that generate most of the chemical energy needed to power the cell's biochemical reactions. 
# Chemical energy produced by the mitochondria is stored in a small molecule called adenosine triphosphate (ATP).
# They are also referred to as "The Power House of the Cell".
# Mitochondria have a distinctive appearance when viewed by electron microscopy. 
# They often appear as rounded or sausage-shaped structures measuring about 0.5-1.0 µm in diameter and 2-8 µm in length; 
# although their size and shape vary, and they are often much bigger in plants.

# TODO: YOUR ANSWER

# %% [markdown]
# **Task 2**: Setup a datagenerator for mitochondria images! [45 Points]

# %%
# TODO: 
# Download https://cs480.org/data/mito.npz to your computer.
# Then, please upload mito.npz using the file panel on the left.

# %%
# The code below is similar to the circles.py file from Task 1.
# We follow Tensorflow conventions to design a tf.data.Dataset for training
# the U-Net.
#
# TODO: Please add four different data augmentation methods in the code block
# below. (image normalization to 0..1, horizontal data flip, vertical data flip,
# rotation by 90 degrees)
#
# Hint: https://github.com/jakeret/unet/blob/master/src/unet/datasets/oxford_iiit_pet.py#L25

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow_datasets.core import DatasetInfo
from typing import Tuple, List

IMAGE_SIZE = (256, 256)
channels = 1
classes = 2

def load_data(count:int, splits:Tuple[float]=(0.7, 0.2, 0.1), **kwargs) -> List[tf.data.Dataset]:
    return [tf.data.Dataset.from_tensor_slices(_build_samples(int(split * count), **kwargs))
            for split in splits]


def _build_samples(sample_count:int, **kwargs) -> Tuple[np.array, np.array]:

    # here we load the mitochondria data
    loaded = np.load('mito.npz')
    loadedimages = loaded['arr_0'][0].copy()
    loadedmasks = loaded['arr_0'][1].copy()

    # now let's go to numpyland
    images = np.empty((sample_count, IMAGE_SIZE[0], IMAGE_SIZE[1], 1))
    labels = np.empty((sample_count, IMAGE_SIZE[0], IMAGE_SIZE[1], 2))
    for i in range(sample_count):
        image, mask = loadedimages[i], loadedmasks[i]

        image = image.reshape((IMAGE_SIZE[0], IMAGE_SIZE[1], 1)).astype(np.float)
        mask = mask.reshape((IMAGE_SIZE[0], IMAGE_SIZE[1], 1))

        #
        # TODO: Normalize the image to 0..1
        #
        # TODO: YOUR CODE
        image = tf.image.per_image_standardization(image)
        #
        # TODO: Use Tensorflow to flip the image horizontally
        #
        if tf.random.uniform(()) > 0.5:
            #
            # TODO: YOUR CODE
            #
            image = tf.image.flip_left_right(image) 
        #
        # TODO: Use Tensorflow to flip the image vertically
        #
        if tf.random.uniform(()) > 0.5:
            #
            # TODO: YOUR CODE
            #
            image = tf.image.flip_up_down(image) 

        #
        # TODO: Use Tensorflow to rotate the image 90 degrees
        #
        if tf.random.uniform(()) > 0.5:
            #
            # TODO: YOUR CODE
            #
            image = tf.image.rot90(image, k=1)

        # augmentation done, let's store the image
        images[i] = image

        # here we split the mask to background and foreground
        fg = np.zeros((IMAGE_SIZE[0], IMAGE_SIZE[1], 1), dtype=np.bool)
        fg[mask == 255] = 1
        bg = np.zeros((IMAGE_SIZE[0], IMAGE_SIZE[1], 1), dtype=np.bool)
        bg[mask == 0] = 1
        
        labels[i, :, :, 0] = bg[:,:,0]
        labels[i, :, :, 1] = fg[:,:,0]

    return images, labels

# %% [markdown]
# **Task 3**: Let's train the U-Net! [25 Points]

# %%
#
# We can now create our training, validation, and testing data by calling
# our methods from Task 2.
#
train, val, test = load_data( 660, splits=(0.7, 0.2, 0.1) )

# %%
# 1) Question
# TODO: We have in total 660 images + 660 masks. Based on the code above,
# how many images are used for training alone?
#
# 462 Images.

# %%
#
# Let's setup the U-Net!
#
LEARNING_RATE = 1e-3

unet_model = unet.build_model(channels=channels,
                              num_classes=classes,
                              layer_depth=5,
                              filters_root=64,
                              padding="same")

unet.finalize_model(unet_model, learning_rate=LEARNING_RATE)

# %%
#
# And, let's setup the trainer...
#
trainer = unet.Trainer(checkpoint_callback=False,
                       learning_rate_scheduler=unet.SchedulerType.WARMUP_LINEAR_DECAY,
                       warmup_proportion=0.1,
                       learning_rate=LEARNING_RATE)

# %%
#
# ...and train the U-Net for 50 epochs with a batch_size of 10!
#
# TODO: Please complete the code below.
# Hint: Don't forget to use training and validation data.
# Hint 2: This will take roughly 30 minutes!
#
trainer.fit(unet_model,
            train,
            val,
            epochs=50,
            batch_size=10
            )
# Out:
# Epoch 1/50
# 47/47 [==============================] - 58s 1s/step - loss: 0.5938 - categorical_crossentropy: 0.5938 - categorical_accuracy: 0.8193 - mean_iou: 0.3195 - dice_coefficient: 0.5873 - auc: 0.7469 - val_loss: 0.3436 - val_categorical_crossentropy: 0.3436 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3857 - val_dice_coefficient: 0.7269 - val_auc: 0.9420
# Epoch 2/50
# 47/47 [==============================] - 38s 804ms/step - loss: 0.3499 - categorical_crossentropy: 0.3499 - categorical_accuracy: 0.9210 - mean_iou: 0.4312 - dice_coefficient: 0.8223 - auc: 0.9206 - val_loss: 0.3437 - val_categorical_crossentropy: 0.3437 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3865 - val_dice_coefficient: 0.7288 - val_auc: 0.9406
# Epoch 3/50
# 47/47 [==============================] - 38s 817ms/step - loss: 0.3273 - categorical_crossentropy: 0.3273 - categorical_accuracy: 0.9210 - mean_iou: 0.4339 - dice_coefficient: 0.8250 - auc: 0.9266 - val_loss: 0.2557 - val_categorical_crossentropy: 0.2557 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4293 - val_dice_coefficient: 0.8185 - val_auc: 0.9427
# Epoch 4/50
# 47/47 [==============================] - 39s 825ms/step - loss: 0.3074 - categorical_crossentropy: 0.3074 - categorical_accuracy: 0.9210 - mean_iou: 0.4400 - dice_coefficient: 0.8376 - auc: 0.9256 - val_loss: 0.2734 - val_categorical_crossentropy: 0.2734 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4195 - val_dice_coefficient: 0.7972 - val_auc: 0.9418
# Epoch 5/50
# 47/47 [==============================] - 39s 830ms/step - loss: 0.3080 - categorical_crossentropy: 0.3080 - categorical_accuracy: 0.9210 - mean_iou: 0.4392 - dice_coefficient: 0.8358 - auc: 0.9269 - val_loss: 0.2709 - val_categorical_crossentropy: 0.2709 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4201 - val_dice_coefficient: 0.7981 - val_auc: 0.9432
# Epoch 6/50
# 47/47 [==============================] - 39s 833ms/step - loss: 0.3051 - categorical_crossentropy: 0.3051 - categorical_accuracy: 0.9210 - mean_iou: 0.4396 - dice_coefficient: 0.8376 - auc: 0.9265 - val_loss: 0.2530 - val_categorical_crossentropy: 0.2530 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4296 - val_dice_coefficient: 0.8171 - val_auc: 0.9497
# Epoch 7/50
# 47/47 [==============================] - 40s 853ms/step - loss: 0.2991 - categorical_crossentropy: 0.2991 - categorical_accuracy: 0.9210 - mean_iou: 0.4406 - dice_coefficient: 0.8403 - auc: 0.9248 - val_loss: 0.2332 - val_categorical_crossentropy: 0.2332 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4422 - val_dice_coefficient: 0.8449 - val_auc: 0.9498
# Epoch 8/50
# 47/47 [==============================] - 39s 842ms/step - loss: 0.2937 - categorical_crossentropy: 0.2937 - categorical_accuracy: 0.9210 - mean_iou: 0.4431 - dice_coefficient: 0.8454 - auc: 0.9251 - val_loss: 0.2287 - val_categorical_crossentropy: 0.2287 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4455 - val_dice_coefficient: 0.8527 - val_auc: 0.9498
# Epoch 9/50
# 47/47 [==============================] - 40s 847ms/step - loss: 0.2918 - categorical_crossentropy: 0.2918 - categorical_accuracy: 0.9210 - mean_iou: 0.4443 - dice_coefficient: 0.8481 - auc: 0.9253 - val_loss: 0.2267 - val_categorical_crossentropy: 0.2267 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4469 - val_dice_coefficient: 0.8564 - val_auc: 0.9498
# Epoch 10/50
# 47/47 [==============================] - 40s 844ms/step - loss: 0.2908 - categorical_crossentropy: 0.2908 - categorical_accuracy: 0.9210 - mean_iou: 0.4449 - dice_coefficient: 0.8498 - auc: 0.9254 - val_loss: 0.2263 - val_categorical_crossentropy: 0.2263 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4472 - val_dice_coefficient: 0.8572 - val_auc: 0.9498
# Epoch 11/50
# 47/47 [==============================] - 40s 845ms/step - loss: 0.2903 - categorical_crossentropy: 0.2903 - categorical_accuracy: 0.9210 - mean_iou: 0.4451 - dice_coefficient: 0.8505 - auc: 0.9253 - val_loss: 0.2262 - val_categorical_crossentropy: 0.2262 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4473 - val_dice_coefficient: 0.8575 - val_auc: 0.9498
# Epoch 12/50
# 47/47 [==============================] - 40s 845ms/step - loss: 0.2900 - categorical_crossentropy: 0.2900 - categorical_accuracy: 0.9210 - mean_iou: 0.4453 - dice_coefficient: 0.8510 - auc: 0.9253 - val_loss: 0.2263 - val_categorical_crossentropy: 0.2263 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4472 - val_dice_coefficient: 0.8572 - val_auc: 0.9498
# Epoch 13/50
# 47/47 [==============================] - 40s 843ms/step - loss: 0.2897 - categorical_crossentropy: 0.2897 - categorical_accuracy: 0.9210 - mean_iou: 0.4454 - dice_coefficient: 0.8513 - auc: 0.9251 - val_loss: 0.2267 - val_categorical_crossentropy: 0.2267 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4468 - val_dice_coefficient: 0.8565 - val_auc: 0.9498
# Epoch 14/50
# 47/47 [==============================] - 40s 844ms/step - loss: 0.2895 - categorical_crossentropy: 0.2895 - categorical_accuracy: 0.9210 - mean_iou: 0.4455 - dice_coefficient: 0.8515 - auc: 0.9250 - val_loss: 0.2272 - val_categorical_crossentropy: 0.2272 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4464 - val_dice_coefficient: 0.8554 - val_auc: 0.9499
# Epoch 15/50
# 47/47 [==============================] - 39s 843ms/step - loss: 0.2893 - categorical_crossentropy: 0.2893 - categorical_accuracy: 0.9210 - mean_iou: 0.4455 - dice_coefficient: 0.8515 - auc: 0.9250 - val_loss: 0.2279 - val_categorical_crossentropy: 0.2279 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4458 - val_dice_coefficient: 0.8540 - val_auc: 0.9499
# Epoch 16/50
# 47/47 [==============================] - 39s 842ms/step - loss: 0.2891 - categorical_crossentropy: 0.2891 - categorical_accuracy: 0.9210 - mean_iou: 0.4454 - dice_coefficient: 0.8514 - auc: 0.9248 - val_loss: 0.2289 - val_categorical_crossentropy: 0.2289 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4449 - val_dice_coefficient: 0.8521 - val_auc: 0.9500
# Epoch 17/50
# 47/47 [==============================] - 40s 844ms/step - loss: 0.2892 - categorical_crossentropy: 0.2892 - categorical_accuracy: 0.9210 - mean_iou: 0.4452 - dice_coefficient: 0.8509 - auc: 0.9245 - val_loss: 0.2299 - val_categorical_crossentropy: 0.2299 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4442 - val_dice_coefficient: 0.8503 - val_auc: 0.9500
# Epoch 18/50
# 47/47 [==============================] - 40s 845ms/step - loss: 0.2889 - categorical_crossentropy: 0.2889 - categorical_accuracy: 0.9210 - mean_iou: 0.4452 - dice_coefficient: 0.8507 - auc: 0.9244 - val_loss: 0.2269 - val_categorical_crossentropy: 0.2269 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4466 - val_dice_coefficient: 0.8556 - val_auc: 0.9502
# Epoch 19/50
# 47/47 [==============================] - 40s 844ms/step - loss: 0.2839 - categorical_crossentropy: 0.2839 - categorical_accuracy: 0.9210 - mean_iou: 0.4475 - dice_coefficient: 0.8549 - auc: 0.9286 - val_loss: 0.2308 - val_categorical_crossentropy: 0.2308 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4435 - val_dice_coefficient: 0.8486 - val_auc: 0.9501
# Epoch 20/50
# 47/47 [==============================] - 40s 843ms/step - loss: 0.2882 - categorical_crossentropy: 0.2882 - categorical_accuracy: 0.9210 - mean_iou: 0.4445 - dice_coefficient: 0.8488 - auc: 0.9240 - val_loss: 0.2338 - val_categorical_crossentropy: 0.2338 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4413 - val_dice_coefficient: 0.8436 - val_auc: 0.9502
# Epoch 21/50
# 47/47 [==============================] - 39s 841ms/step - loss: 0.2887 - categorical_crossentropy: 0.2887 - categorical_accuracy: 0.9210 - mean_iou: 0.4441 - dice_coefficient: 0.8479 - auc: 0.9237 - val_loss: 0.2340 - val_categorical_crossentropy: 0.2340 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4411 - val_dice_coefficient: 0.8433 - val_auc: 0.9501
# Epoch 22/50
# 47/47 [==============================] - 39s 842ms/step - loss: 0.2885 - categorical_crossentropy: 0.2885 - categorical_accuracy: 0.9210 - mean_iou: 0.4441 - dice_coefficient: 0.8480 - auc: 0.9236 - val_loss: 0.2352 - val_categorical_crossentropy: 0.2352 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4403 - val_dice_coefficient: 0.8412 - val_auc: 0.9501
# Epoch 23/50
# 47/47 [==============================] - 39s 841ms/step - loss: 0.2884 - categorical_crossentropy: 0.2884 - categorical_accuracy: 0.9210 - mean_iou: 0.4439 - dice_coefficient: 0.8473 - auc: 0.9235 - val_loss: 0.2363 - val_categorical_crossentropy: 0.2363 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4395 - val_dice_coefficient: 0.8396 - val_auc: 0.9501
# Epoch 24/50
# 47/47 [==============================] - 39s 839ms/step - loss: 0.2883 - categorical_crossentropy: 0.2883 - categorical_accuracy: 0.9210 - mean_iou: 0.4436 - dice_coefficient: 0.8464 - auc: 0.9232 - val_loss: 0.2373 - val_categorical_crossentropy: 0.2373 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4389 - val_dice_coefficient: 0.8381 - val_auc: 0.9501
# Epoch 25/50
# 47/47 [==============================] - 39s 840ms/step - loss: 0.2882 - categorical_crossentropy: 0.2882 - categorical_accuracy: 0.9210 - mean_iou: 0.4432 - dice_coefficient: 0.8455 - auc: 0.9231 - val_loss: 0.2381 - val_categorical_crossentropy: 0.2381 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4384 - val_dice_coefficient: 0.8370 - val_auc: 0.9501
# Epoch 26/50
# 47/47 [==============================] - 39s 840ms/step - loss: 0.2880 - categorical_crossentropy: 0.2880 - categorical_accuracy: 0.9210 - mean_iou: 0.4429 - dice_coefficient: 0.8446 - auc: 0.9231 - val_loss: 0.2389 - val_categorical_crossentropy: 0.2389 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4379 - val_dice_coefficient: 0.8358 - val_auc: 0.9501
# Epoch 27/50
# 47/47 [==============================] - 39s 841ms/step - loss: 0.2879 - categorical_crossentropy: 0.2879 - categorical_accuracy: 0.9210 - mean_iou: 0.4425 - dice_coefficient: 0.8435 - auc: 0.9230 - val_loss: 0.2393 - val_categorical_crossentropy: 0.2393 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4376 - val_dice_coefficient: 0.8352 - val_auc: 0.9501
# Epoch 28/50
# 47/47 [==============================] - 39s 840ms/step - loss: 0.2878 - categorical_crossentropy: 0.2878 - categorical_accuracy: 0.9210 - mean_iou: 0.4421 - dice_coefficient: 0.8425 - auc: 0.9229 - val_loss: 0.2390 - val_categorical_crossentropy: 0.2390 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4378 - val_dice_coefficient: 0.8356 - val_auc: 0.9501
# Epoch 29/50
# 47/47 [==============================] - 39s 840ms/step - loss: 0.2873 - categorical_crossentropy: 0.2873 - categorical_accuracy: 0.9210 - mean_iou: 0.4422 - dice_coefficient: 0.8425 - auc: 0.9231 - val_loss: 0.2393 - val_categorical_crossentropy: 0.2393 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4376 - val_dice_coefficient: 0.8352 - val_auc: 0.9501
# Epoch 30/50
# 47/47 [==============================] - 39s 840ms/step - loss: 0.2873 - categorical_crossentropy: 0.2873 - categorical_accuracy: 0.9210 - mean_iou: 0.4418 - dice_coefficient: 0.8415 - auc: 0.9230 - val_loss: 0.2390 - val_categorical_crossentropy: 0.2390 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4378 - val_dice_coefficient: 0.8356 - val_auc: 0.9502
# Epoch 31/50
# 47/47 [==============================] - 39s 840ms/step - loss: 0.2870 - categorical_crossentropy: 0.2870 - categorical_accuracy: 0.9210 - mean_iou: 0.4418 - dice_coefficient: 0.8414 - auc: 0.9232 - val_loss: 0.2389 - val_categorical_crossentropy: 0.2389 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4378 - val_dice_coefficient: 0.8357 - val_auc: 0.9502
# Epoch 32/50
# 47/47 [==============================] - 39s 841ms/step - loss: 0.2867 - categorical_crossentropy: 0.2867 - categorical_accuracy: 0.9210 - mean_iou: 0.4417 - dice_coefficient: 0.8409 - auc: 0.9233 - val_loss: 0.2386 - val_categorical_crossentropy: 0.2386 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4380 - val_dice_coefficient: 0.8362 - val_auc: 0.9500
# Epoch 33/50
# 47/47 [==============================] - 39s 841ms/step - loss: 0.2864 - categorical_crossentropy: 0.2864 - categorical_accuracy: 0.9210 - mean_iou: 0.4416 - dice_coefficient: 0.8407 - auc: 0.9235 - val_loss: 0.2382 - val_categorical_crossentropy: 0.2382 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4383 - val_dice_coefficient: 0.8367 - val_auc: 0.9500
# Epoch 34/50
# 47/47 [==============================] - 39s 840ms/step - loss: 0.2862 - categorical_crossentropy: 0.2862 - categorical_accuracy: 0.9210 - mean_iou: 0.4415 - dice_coefficient: 0.8404 - auc: 0.9236 - val_loss: 0.2378 - val_categorical_crossentropy: 0.2378 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4386 - val_dice_coefficient: 0.8374 - val_auc: 0.9500
# Epoch 35/50
# 47/47 [==============================] - 39s 839ms/step - loss: 0.2858 - categorical_crossentropy: 0.2858 - categorical_accuracy: 0.9210 - mean_iou: 0.4415 - dice_coefficient: 0.8403 - auc: 0.9237 - val_loss: 0.2373 - val_categorical_crossentropy: 0.2373 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4389 - val_dice_coefficient: 0.8381 - val_auc: 0.9501
# Epoch 36/50
# 47/47 [==============================] - 39s 839ms/step - loss: 0.2855 - categorical_crossentropy: 0.2855 - categorical_accuracy: 0.9210 - mean_iou: 0.4415 - dice_coefficient: 0.8402 - auc: 0.9239 - val_loss: 0.2369 - val_categorical_crossentropy: 0.2369 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4392 - val_dice_coefficient: 0.8388 - val_auc: 0.9501
# Epoch 37/50
# 47/47 [==============================] - 39s 841ms/step - loss: 0.2852 - categorical_crossentropy: 0.2852 - categorical_accuracy: 0.9210 - mean_iou: 0.4416 - dice_coefficient: 0.8402 - auc: 0.9241 - val_loss: 0.2364 - val_categorical_crossentropy: 0.2364 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4395 - val_dice_coefficient: 0.8394 - val_auc: 0.9502
# Epoch 38/50
# 47/47 [==============================] - 39s 839ms/step - loss: 0.2849 - categorical_crossentropy: 0.2849 - categorical_accuracy: 0.9210 - mean_iou: 0.4416 - dice_coefficient: 0.8400 - auc: 0.9244 - val_loss: 0.2357 - val_categorical_crossentropy: 0.2357 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4399 - val_dice_coefficient: 0.8405 - val_auc: 0.9503
# Epoch 39/50
# 47/47 [==============================] - 39s 842ms/step - loss: 0.2845 - categorical_crossentropy: 0.2845 - categorical_accuracy: 0.9210 - mean_iou: 0.4417 - dice_coefficient: 0.8402 - auc: 0.9246 - val_loss: 0.2353 - val_categorical_crossentropy: 0.2353 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4403 - val_dice_coefficient: 0.8412 - val_auc: 0.9503
# Epoch 40/50
# 47/47 [==============================] - 39s 841ms/step - loss: 0.2841 - categorical_crossentropy: 0.2841 - categorical_accuracy: 0.9210 - mean_iou: 0.4418 - dice_coefficient: 0.8403 - auc: 0.9249 - val_loss: 0.2347 - val_categorical_crossentropy: 0.2347 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4407 - val_dice_coefficient: 0.8420 - val_auc: 0.9501
# Epoch 41/50
# 47/47 [==============================] - 39s 839ms/step - loss: 0.2838 - categorical_crossentropy: 0.2838 - categorical_accuracy: 0.9210 - mean_iou: 0.4418 - dice_coefficient: 0.8403 - auc: 0.9251 - val_loss: 0.2341 - val_categorical_crossentropy: 0.2341 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4410 - val_dice_coefficient: 0.8429 - val_auc: 0.9502
# Epoch 42/50
# 47/47 [==============================] - 39s 841ms/step - loss: 0.2836 - categorical_crossentropy: 0.2836 - categorical_accuracy: 0.9210 - mean_iou: 0.4419 - dice_coefficient: 0.8404 - auc: 0.9253 - val_loss: 0.2334 - val_categorical_crossentropy: 0.2334 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4415 - val_dice_coefficient: 0.8440 - val_auc: 0.9503
# Epoch 43/50
# 47/47 [==============================] - 39s 841ms/step - loss: 0.2831 - categorical_crossentropy: 0.2831 - categorical_accuracy: 0.9210 - mean_iou: 0.4421 - dice_coefficient: 0.8408 - auc: 0.9257 - val_loss: 0.2329 - val_categorical_crossentropy: 0.2329 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4419 - val_dice_coefficient: 0.8449 - val_auc: 0.9503
# Epoch 44/50
# 47/47 [==============================] - 39s 842ms/step - loss: 0.2827 - categorical_crossentropy: 0.2827 - categorical_accuracy: 0.9210 - mean_iou: 0.4423 - dice_coefficient: 0.8410 - auc: 0.9260 - val_loss: 0.2323 - val_categorical_crossentropy: 0.2323 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4423 - val_dice_coefficient: 0.8458 - val_auc: 0.9504
# Epoch 45/50
# 47/47 [==============================] - 39s 841ms/step - loss: 0.2824 - categorical_crossentropy: 0.2824 - categorical_accuracy: 0.9210 - mean_iou: 0.4424 - dice_coefficient: 0.8412 - auc: 0.9262 - val_loss: 0.2317 - val_categorical_crossentropy: 0.2317 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4428 - val_dice_coefficient: 0.8468 - val_auc: 0.9504
# Epoch 46/50
# 47/47 [==============================] - 39s 840ms/step - loss: 0.2820 - categorical_crossentropy: 0.2820 - categorical_accuracy: 0.9210 - mean_iou: 0.4426 - dice_coefficient: 0.8415 - auc: 0.9266 - val_loss: 0.2310 - val_categorical_crossentropy: 0.2310 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4432 - val_dice_coefficient: 0.8478 - val_auc: 0.9505
# Epoch 47/50
# 47/47 [==============================] - 39s 841ms/step - loss: 0.2816 - categorical_crossentropy: 0.2816 - categorical_accuracy: 0.9210 - mean_iou: 0.4428 - dice_coefficient: 0.8419 - auc: 0.9270 - val_loss: 0.2304 - val_categorical_crossentropy: 0.2304 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4437 - val_dice_coefficient: 0.8488 - val_auc: 0.9504
# Epoch 48/50
# 47/47 [==============================] - 39s 837ms/step - loss: 0.2812 - categorical_crossentropy: 0.2812 - categorical_accuracy: 0.9210 - mean_iou: 0.4430 - dice_coefficient: 0.8423 - auc: 0.9272 - val_loss: 0.2298 - val_categorical_crossentropy: 0.2298 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4442 - val_dice_coefficient: 0.8499 - val_auc: 0.9504
# Epoch 49/50
# 47/47 [==============================] - 39s 841ms/step - loss: 0.2808 - categorical_crossentropy: 0.2808 - categorical_accuracy: 0.9210 - mean_iou: 0.4432 - dice_coefficient: 0.8427 - auc: 0.9276 - val_loss: 0.2291 - val_categorical_crossentropy: 0.2291 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4447 - val_dice_coefficient: 0.8510 - val_auc: 0.9505
# Epoch 50/50
# 47/47 [==============================] - 39s 839ms/step - loss: 0.2804 - categorical_crossentropy: 0.2804 - categorical_accuracy: 0.9210 - mean_iou: 0.4435 - dice_coefficient: 0.8432 - auc: 0.9280 - val_loss: 0.2285 - val_categorical_crossentropy: 0.2285 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4451 - val_dice_coefficient: 0.8521 - val_auc: 0.9506

# %% [markdown]
# **Task 4**: Let's predict mitochondria in the testing data! [15 Points]

# %%
# 
# After training, let's try the U-Net on our testing data.
#
# The code below displays the first 10 input images, the original masks by experts, 
# and the predicted masks from the U-Net.

# %%
rows = 10
fig, axs = plt.subplots(rows, 3, figsize=(8, 30))
for ax, (image, label) in zip(axs, test.take(rows).batch(1)):
  
  prediction = unet_model.predict(image)
  ax[0].matshow(image[0, :, :, 0])
  ax[1].matshow(label[0, :, :, 1], cmap="gray")
  ax[2].matshow(prediction[0].argmax(axis=-1), cmap="gray")

# %%
# 1) Question
# TODO: Why do we use the prediction[0].argmax(axis=-1) command
# to display the prediction?

# We use it because the predicted masks start at 0 index of the array that will be displayed by argmax.
# TODO: YOUR ANSWER

# %%
# 2) Question
# TODO: Is the quality of the segmentation good and how could we improve it?
# Hint: Think along the lines of some traditional image processing rather than
# increasing the training data size.

# The segmentation ig good and can be improved. The horizontal, vertical and 90 degree rotations can be seen.
# TODO: YOUR ANSWER

# %% [markdown]
# **Bonus**: Compare against the state-of-the-art literature! [33 Points]

# %%
#
# The following paper also uses a 2D U-Net to detect mitochondria:
# 
# https://danielhaehn.com/papers/?casser2020fast
#

# %%
# 1) Question
#
# TODO: How many learnable parameters does your trained unet_model have?
# Hint: You can use TF's Model Summary function to answer this.
#

# %%
# TODO: YOUR CODE

# %%
writer = tf.summary.create_file_writer("content/mito.npz")
with writer.as_default():
  tf.summary.scalar("my_metric", 0.5, step=step)
  writer.flush()

# %%
# 2) Question
#
# TODO: How many parameters do Casser et al. use?
#

# %%
# TODO: The number of parameters are 19,505,856.

# %%
# 3) Question
#
# TODO: How did Casser et al. reduce the parameters?
#

# %%
# TODO: It reduced the number of convolutional filters throughout the network and then replace
# transpose convolutions in the decoder with light-weight bilinear upsampling layers that
# require no parameters. For the encoder, parameter reduction is 94%, i.e., 19,505,856 to 1,178,480 and
# for the decoder, it is 93.6% reduction i.e., 12,188,545 to 780,053.

# %%
# 4) Question
#
# TODO: Why did Casser et al. reduce the parameters?
#

# %%
# TODO: The parameters are reduced to acheive 40% additional throughput which further increases effectiveness.

# %%
#
# You made it!!
#
#                 _ ___                /^^\ /^\  /^^\_
#     _          _@)@) \            ,,/ '` ~ `'~~ ', `\.
#   _/o\_ _ _ _/~`.`...'~\        ./~~..,'`','',.,' '  ~:
#  / `,'.~,~.~  .   , . , ~|,   ,/ .,' , ,. .. ,,.   `,  ~\_
# ( ' _' _ '_` _  '  .    , `\_/ .' ..' '  `  `   `..  `,   \_
#  ~V~ V~ V~ V~ ~\ `   ' .  '    , ' .,.,''`.,.''`.,.``. ',   \_
#   _/\ /\ /\ /\_/, . ' ,   `_/~\_ .' .,. ,, , _/~\_ `. `. '.,  \_
#  < ~ ~ '~`'~'`, .,  .   `_: ::: \_ '      `_/ ::: \_ `.,' . ',  \_
#   \ ' `_  '`_    _    ',/ _::_::_ \ _    _/ _::_::_ \   `.,'.,`., \-,-,-,_,_,
#    `'~~ `'~~ `'~~ `'~~  \(_)(_)(_)/  `~~' \(_)(_)(_)/ ~'`\_.._,._,'_;_;_;_;_;
#
