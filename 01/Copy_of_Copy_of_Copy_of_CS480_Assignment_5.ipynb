# %% [markdown]
# <a href="https://colab.research.google.com/github/pushna99/cs480student/blob/main/01/Copy_of_Copy_of_Copy_of_CS480_Assignment_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![CS480_w.png](data:image/png;base64,...)
# #Assignment 5

# %%
# In this assignment, we will visualize and explore a CT scan!

# %%
# load numpy and matplotlib
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# we are using pydicom, so lets install it!
# !pip install pydicom
# Out:
# Collecting pydicom
#   Downloading https://files.pythonhosted.org/packages/f4/15/df16546bc59bfca390cf072d473fb2c8acd4231636f64356593a63137e55/pydicom-2.1.2-py3-none-any.whl (1.9MB)
#      |████████████████████████████████| 1.9MB 2.5MB/s
# Installing collected packages: pydicom
# Successfully installed pydicom-2.1.2

# %% [markdown]
# **Task 1**: Download and visualize data with SliceDrop! [20 Points]

# %%
# Please download https://cs480.org/data/ct.zip and extract it on your computer!
# This is a CT scan of an arm in DICOM format.

# %%
# 1) Let's explore the data without loading it.
# TODO: Without loading the data, how many slices are there?

# %%
# TODO: There are 3 slices - Axial, Sagittal and Coronal

# %%
# 2) Let's visualize the data with SliceDrop! 
# Go to https://slicedrop.com and drag'n'drop all .dcm files into the browser.
# Please use the 2D sliders to show axial, sagittal, and coronal slices in 3D.

# %%
# TODO Please post a screenshot of SliceDrop's 3D View in the text box below by 
# using the Upload image button after double-click.

# %% [markdown]
# ![Screenshot 2021-04-12 183629.png](data:image/png;base64,...)![Screenshot 2021-04-12 183557.png](data:image/png;base64,...)

# %% [markdown]
# **Task 2**: Load the data using pydicom as a 3D volume and then reslice it! [35 Points]

# %%
# TODO: Please upload ct.zip using the file panel on the left.
# Then use the following snippet to extract the data.

# %%
import zipfile
with zipfile.ZipFile('ct.zip', 'r') as zip_ref:
    zip_ref.extractall('.')

# %%
# 1) Now loop through all the DICOM files and store them in a 3D numpy array.
# Hint: You can either store them in a list first or read the dimensions of a
# single image slice to properly create the 3D numpy array.
# Hint 2: os.listdir(DIR) gives a list of filenames in a directory.
# Hint 2b: This list is not sorted - make sure you sort it.
# Hint 3: The dcmread function loads a single DICOM file.
# Hint 4: You can then use .pixel_array to access the image data.

# %%
from pydicom import dcmread
# !pip install dicom
import os
import numpy
# !pip install dicom_numpy
import dicom
import sys
import glob
# Out:
# Collecting dicom
#   Downloading https://files.pythonhosted.org/packages/6c/0e/488becc361f1416f6682a9b9c223eb6a9db2d5d093fb46ea91c762eb6e4a/dicom-0.9.9.post1-py3-none-any.whl (766kB)
#      |████████████████████████████████| 768kB 3.0MB/s
# Installing collected packages: dicom
# Successfully installed dicom-0.9.9.post1
# Collecting dicom_numpy
#   Downloading https://files.pythonhosted.org/packages/ee/f6/528b6458924866f3b7d4a7048df60f3f8b142e432dbfea543e5fd9916871/dicom_numpy-0.5.0.tar.gz
# Requirement already satisfied: pydicom in /usr/local/lib/python3.7/dist-packages (from dicom_numpy) (2.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from dicom_numpy) (1.19.5)
# Building wheels for collected packages: dicom-numpy
#   Building wheel for dicom-numpy (setup.py) ... done
#   Created wheel for dicom-numpy: filename=dicom_numpy-0.5.0-py2.py3-none-any.whl size=6454 sha256=573db31df05afb29e0c2badf0ea4b664308f8b56e4777ebe2f0f36d9dc2f5573
#   Stored in directory: /root/.cache/pip/wheels/58/83/be/0beac28a5893128dbfb33419b024e5c7bd9ca62c8fdf8dd630
# Successfully built dicom-numpy
# Installing collected packages: dicom-numpy
# Successfully installed dicom-numpy-0.5.0
# /usr/local/lib/python3.7/dist-packages/dicom/__init__.py:53: UserWarning:
# This code is using an older version of pydicom, which is no longer
# maintained as of Jan 2017.  You can access the new pydicom features and API
# by installing `pydicom` from PyPI.
# See 'Transitioning to pydicom 1.x' section at pydicom.readthedocs.org
# for more information.
#
#   warnings.warn(msg)

# %%
PathDicom = "/content/ct/"
lstFilesDCM = []
for dirName, subdirList, fileList in os.walk(PathDicom):
    for filename in fileList:
        if ".dcm" in filename.lower():
            lstFilesDCM.append(os.path.join(dirName,filename))

# %%
RefDs = dcmread(lstFilesDCM[0])
ConstPixelDims = (int(RefDs.Rows), int(RefDs.Columns), len(lstFilesDCM))
ConstPixelSpacing = (float(RefDs.PixelSpacing[0]), float(RefDs.PixelSpacing[1]), float(RefDs.SliceThickness))
sampl1=[]

# %%
ArrayDicom = numpy.zeros(ConstPixelDims, dtype=RefDs.pixel_array.dtype)
for filenameDCM in lstFilesDCM:
    ds = dcmread(filenameDCM)
    sampl1.append(ds)
    ArrayDicom[:, :, lstFilesDCM.index(filenameDCM)] = ds.pixel_array

# %%
sampl1
# Out:
# [Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 202
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: CT Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.276.0.7238010.5.1.4.0.75157.1397189444.4964
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.276.0.7238010.5.0.3.5.4
# (0002, 0013) Implementation Version Name         SH: 'OSIRIX'
# (0002, 0016) Source Application Entity Title     AE: 'DicomBrowser'
# -------------------------------------------------
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL', 'CT_SOM5 SPI']
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.276.0.7238010.5.1.4.0.75157.1397189444.4964
# (0008, 0020) Study Date                          DA: '20090301'
# (0008, 0021) Series Date                         DA: '20090301'
# (0008, 0022) Acquisition Date                    DA: '20090301'
# (0008, 0023) Content Date                        DA: '20090301'
# (0008, 0030) Study Time                          TM: '000000.000'
# (0008, 0031) Series Time                         TM: '000628.000'
# (0008, 0032) Acquisition Time                    TM: '000532.548'
# (0008, 0033) Content Time                        TM: '000532.548'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 0070) Manufacturer                        LO: 'Manufacturer'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1030) Study Description                   LO: 'ARM'
# (0008, 103e) Series Description                  LO: 'R-ARM LEE 100MB'
# (0008, 1090) Manufacturer's Model Name           LO: 'OsiriX'
# (0008, 1140)  Referenced Image Sequence  1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.5962.99.1.448739794.1825383526.1396313143762.40.0
#    ---------
# (0008, 2112)  Source Image Sequence  1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: 1.3.12.2.1107.5.9.1
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.5962.99.1.448739794.1825383526.1396313143762.41.0
#    ---------
# (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: '121327'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Full fidelity image, uncompressed or lossless compressed'
#    ---------
# (0010, 0010) Patient's Name                      PN: 'ARM^CT'
# (0010, 0020) Patient ID                          LO: '1050'
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: ''
# (0012, 0062) Patient Identity Removed            CS: 'YES'
# (0012, 0063) De-identification Method            LO: ['Deidentified', 'Descriptors retained', 'Patient Characteristics removed', 'Device identity removed', 'Institution identity removed', 'Dates modified', 'Unsafe private removed', 'UIDs remapped']
# (0012, 0064)  De-identification Method Code Sequence  5 item(s) ----
#    (0008, 0100) Code Value                          SH: '113100'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Basic Application Confidentiality Profile'
#    ---------
#    (0008, 0100) Code Value                          SH: '210005'
#    (0008, 0102) Coding Scheme Designator            SH: '99PMP'
#    (0008, 0104) Code Meaning                        LO: 'Retain all descriptors unchanged'
#    ---------
#    (0008, 0100) Code Value                          SH: '113107'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Retain Longitudinal Temporal Information Modified Dates Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '113111'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Retain Safe Private Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '210001'
#    (0008, 0102) Coding Scheme Designator            SH: '99PMP'
#    (0008, 0104) Code Meaning                        LO: 'Remap UIDs'
#    ---------
# (0018, 0015) Body Part Examined                  CS: 'EXTREMITY'
# (0018, 0050) Slice Thickness                     DS: "3.0"
# (0018, 0060) KVP                                 DS: "120.0"
# (0018, 0090) Data Collection Diameter            DS: "500.0"
# (0018, 1000) Device Serial Number                LO: 'SN000000'
# (0018, 1100) Reconstruction Diameter             DS: "317.0"
# (0018, 1110) Distance Source to Detector         DS: "1040.0"
# (0018, 1111) Distance Source to Patient          DS: "570.0"
# (0018, 1120) Gantry/Detector Tilt                DS: "0.0"
# (0018, 1130) Table Height                        DS: "182.0"
# (0018, 1140) Rotation Direction                  CS: 'CW'
# (0018, 1150) Exposure Time                       IS: "500"
# (0018, 1151) X-Ray Tube Current                  IS: "520"
# (0018, 1152) Exposure                            IS: "200"
# (0018, 1160) Filter Type                         SH: '0'
# (0018, 1170) Generator Power                     IS: "62"
# (0018, 1190) Focal Spot(s)                       DS: "1.2"
# (0018, 1200) Date of Last Calibration            DA: '20090228'
# (0018, 1201) Time of Last Calibration            TM: '134729.000'
# (0018, 1210) Convolution Kernel                  SH: 'B30f'
# (0018, 5100) Patient Position                    CS: 'HFS'
# (0020, 000d) Study Instance UID                  UI: 1.3.6.1.4.1.5962.99.1.448739794.1825383526.1396313143762.43.0
# (0020, 000e) Series Instance UID                 UI: 1.3.6.1.4.1.19291.2.1.2.4188822440541100002
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: "600"
# (0020, 0012) Acquisition Number                  IS: "1"
# (0020, 0013) Instance Number                     IS: "42"
# (0020, 0032) Image Position (Patient)            DS: [-206.190430, -294.854492, -546.000000]
# (0020, 0037) Image Orientation (Patient)         DS: [1.000000, 0.000000, 0.000000, 0.000000, 1.000000, 0.000000]
# (0020, 0052) Frame of Reference UID              UI: 1.3.6.1.4.1.5962.99.1.448739794.1825383526.1396313143762.45.0
# (0020, 1040) Position Reference Indicator        LO: ''
# (0020, 1041) Slice Location                      DS: "-546.0"
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 454
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: [0.619141, 0.619141]
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 0
# (0028, 1050) Window Center                       DS: "30.0"
# (0028, 1051) Window Width                        DS: "410.0"
# (0028, 1052) Rescale Intercept                   DS: "-1024.0"
# (0028, 1053) Rescale Slope                       DS: "1.0"
# (0028, 1054) Rescale Type                        LO: 'HU'
# (0032, 1040) Study Arrival Date                  DA: '20090301'
# (0032, 1041) Study Arrival Time                  TM: '000144.000'
# (0032, 1050) Study Completion Date               DA: '20090301'
# (0032, 1051) Study Completion Time               TM: '155848.000'
# (7fe0, 0010) Pixel Data                          OW: Array of 464896 elements,
#  Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 202
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: CT Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.276.0.7238010.5.1.4.0.75157.1397189444.4999
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.276.0.7238010.5.0.3.5.4
# (0002, 0013) Implementation Version Name         SH: 'OSIRIX'
# (0002, 0016) Source Application Entity Title     AE: 'DicomBrowser'
# -------------------------------------------------
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL', 'CT_SOM5 SPI']
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.276.0.7238010.5.1.4.0.75157.1397189444.4999
# (0008, 0020) Study Date                          DA: '20090301'
# (0008, 0021) Series Date                         DA: '20090301'
# (0008, 0022) Acquisition Date                    DA: '20090301'
# (0008, 0023) Content Date                        DA: '20090301'
# (0008, 0030) Study Time                          TM: '000000.000'
# (0008, 0031) Series Time                         TM: '000628.000'
# (0008, 0032) Acquisition Time                    TM: '000530.436'
# (0008, 0033) Content Time                        TM: '000530.436'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 0070) Manufacturer                        LO: 'Manufacturer'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1030) Study Description                   LO: 'ARM'
# (0008, 103e) Series Description                  LO: 'R-ARM LEE 100MB'
# (0008, 1090) Manufacturer's Model Name           LO: 'OsiriX'
# (0008, 1140)  Referenced Image Sequence  1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.5962.99.1.448739794.1825383526.1396313143762.40.0
#    ---------
# (0008, 2112)  Source Image Sequence  1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: 1.3.12.2.1107.5.9.1
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.5962.99.1.448739794.1825383526.1396313143762.41.0
#    ---------
# (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: '121327'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Full fidelity image, uncompressed or lossless compressed'
#    ---------
# (0010, 0010) Patient's Name                      PN: 'ARM^CT'
# (0010, 0020) Patient ID                          LO: '1050'
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: ''
# (0012, 0062) Patient Identity Removed            CS: 'YES'
# (0012, 0063) De-identification Method            LO: ['Deidentified', 'Descriptors retained', 'Patient Characteristics removed', 'Device identity removed', 'Institution identity removed', 'Dates modified', 'Unsafe private removed', 'UIDs remapped']
# (0012, 0064)  De-identification Method Code Sequence  5 item(s) ----
#    (0008, 0100) Code Value                          SH: '113100'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Basic Application Confidentiality Profile'
#    ---------
#    (0008, 0100) Code Value                          SH: '210005'
#    (0008, 0102) Coding Scheme Designator            SH: '99PMP'
#    (0008, 0104) Code Meaning                        LO: 'Retain all descriptors unchanged'
#    ---------
#    (0008, 0100) Code Value                          SH: '113107'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Retain Longitudinal Temporal Information Modified Dates Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '113111'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Retain Safe Private Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '210001'
#    (0008, 0102) Coding Scheme Designator            SH: '99PMP'
#    (0008, 0104) Code Meaning                        LO: 'Remap UIDs'
#    ---------
# (0018, 0015) Body Part Examined                  CS: 'EXTREMITY'
# (0018, 0050) Slice Thickness                     DS: "3.0"
# (0018, 0060) KVP                                 DS: "120.0"
# (0018, 0090) Data Collection Diameter            DS: "500.0"
# (0018, 1000) Device Serial Number                LO: 'SN000000'
# (0018, 1100) Reconstruction Diameter             DS: "317.0"
# (0018, 1110) Distance Source to Detector         DS: "1040.0"
# (0018, 1111) Distance Source to Patient          DS: "570.0"
# (0018, 1120) Gantry/Detector Tilt                DS: "0.0"
# (0018, 1130) Table Height                        DS: "182.0"
# (0018, 1140) Rotation Direction                  CS: 'CW'
# (0018, 1150) Exposure Time                       IS: "500"
# (0018, 1151) X-Ray Tube Current                  IS: "520"
# (0018, 1152) Exposure                            IS: "200"
# (0018, 1160) Filter Type                         SH: '0'
# (0018, 1170) Generator Power                     IS: "62"
# (0018, 1190) Focal Spot(s)                       DS: "1.2"
# (0018, 1200) Date of Last Calibration            DA: '20090228'
# (0018, 1201) Time of Last Calibration            TM: '134729.000'
# (0018, 1210) Convolution Kernel                  SH: 'B30f'
# (0018, 5100) Patient Position                    CS: 'HFS'
# (0020, 000d) Study Instance UID                  UI: 1.3.6.1.4.1.5962.99.1.448739794.1825383526.1396313143762.43.0
# (0020, 000e) Series Instance UID                 UI: 1.3.6.1.4.1.19291.2.1.2.4188822440541100002
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: "600"
# (0020, 0012) Acquisition Number                  IS: "1"
# (0020, 0013) Instance Number                     IS: "77"
# (0020, 0032) Image Position (Patient)            DS: [-206.190430, -294.854492, -651.000000]
# (0020, 0037) Image Orientation (Patient)         DS: [1.000000, 0.000000, 0.000000, 0.000000, 1.000000, 0.000000]
# (0020, 0052) Frame of Reference UID              UI: 1.3.6.1.4.1.5962.99.1.448739794.1825383526.1396313143762.45.0
# (0020, 1040) Position Reference Indicator        LO: ''
# (0020, 1041) Slice Location                      DS: "-651.0"
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 454
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: [0.619141, 0.619141]
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 0
# (0028, 1050) Window Center                       DS: "30.0"
# (0028, 1051) Window Width                        DS: "410.0"
# (0028, 1052) Rescale Intercept                   DS: "-1024.0"
# (0028, 1053) Rescale Slope                       DS: "1.0"
# (0028, 1054) Rescale Type                        LO: 'HU'
# (0032, 1040) Study Arrival Date                  DA: '20090301'
# (0032, 1041) Study Arrival Time                  TM: '000144.000'
# (0032, 1050) Study Completion Date               DA: '20090301'
# (0032, 1051) Study Completion Time               TM: '155848.000'
# (7fe0, 0010) Pixel Data                          OW: Array of 464896 elements,
#  Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 202
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: CT Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.276.0.7238010.5.1.4.0.75157.1397189445.5140
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.276.0.7238010.5.0.3.5.4
# (0002, 0013) Implementation Version Name         SH: 'OSIRIX'
# (0002, 0016) Source Application Entity Title     AE: 'DicomBrowser'
# -------------------------------------------------
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL', 'CT_SOM5 SPI']
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.276.0.7238010.5.1.4.0.75157.1397189445.5140
# (0008, 0020) Study Date                          DA: '20090301'
# (0008, 0021) Series Date                         DA: '20090301'
# (0008, 0022) Acquisition Date                    DA: '20090301'
# (0008, 0023) Content Date                        DA: '20090301'
# (0008, 0030) Study Time                          TM: '000000.000'
# (0008, 0031) Series Time                         TM: '000628.000'
# (0008, 0032) Acquisition Time                    TM: '000521.989'
# (0008, 0033) Content Time                        TM: '000521.989'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 0070) Manufacturer                        LO: 'Manufacturer'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1030) Study Description                   LO: 'ARM'
# (0008, 103e) Series Description                  LO: 'R-ARM LEE 100MB'
# (0008, 1090) Manufacturer's Model Name           LO: 'OsiriX'
# (0008, 1140)  Referenced Image Sequence  1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.5962.99.1.448739794.1825383526.1396313143762.40.0
#    ---------
# (0008, 2112)  Source Image Sequence  1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: 1.3.12.2.1107.5.9.1
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.5962.99.1.448739794.1825383526.1396313143762.41.0
#    ---------
# (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: '121327'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Full fidelity image, uncompressed or lossless compressed'
#    ---------
# (0010, 0010) Patient's Name                      PN: 'ARM^CT'
# (0010, 0020) Patient ID                          LO: '1050'
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: ''
# (0012, 0062) Patient Identity Removed            CS: 'YES'
# (0012, 0063) De-identification Method            LO: ['Deidentified', 'Descriptors retained', 'Patient Characteristics removed', 'Device identity removed', 'Institution identity removed', 'Dates modified', 'Unsafe private removed', 'UIDs remapped']
# (0012, 0064)  De-identification Method Code Sequence  5 item(s) ----
#    (0008, 0100) Code Value                          SH: '113100'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Basic Application Confidentiality Profile'
#    ---------
#    (0008, 0100) Code Value                          SH: '210005'
#    (0008, 0102) Coding Scheme Designator            SH: '99PMP'
#    (0008, 0104) Code Meaning                        LO: 'Retain all descriptors unchanged'
#    ---------
#    (0008, 0100) Code Value                          SH: '113107'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Retain Longitudinal Temporal Information Modified Dates Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '113111'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Retain Safe Private Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '210001'
#    (0008, 0102) Coding Scheme Designator            SH: '99PMP'
#    (0008, 0104) Code Meaning                        LO: 'Remap UIDs'
#    ---------
# (0018, 0015) Body Part Examined                  CS: 'EXTREMITY'
# (0018, 0050) Slice Thickness                     DS: "3.0"
# (0018, 0060) KVP                                 DS: "120.0"
# (0018, 0090) Data Collection Diameter            DS: "500.0"
# (0018, 1000) Device Serial Number                LO: 'SN000000'
# (0018, 1100) Reconstruction Diameter             DS: "317.0"
# (0018, 1110) Distance Source to Detector         DS: "1040.0"
# (0018, 1111) Distance Source to Patient          DS: "570.0"
# (0018, 1120) Gantry/Detector Tilt                DS: "0.0"
# (0018, 1130) Table Height                        DS: "182.0"
# (0018, 1140) Rotation Direction                  CS: 'CW'
# (0018, 1150) Exposure Time                       IS: "500"
# (0018, 1151) X-Ray Tube Current                  IS: "520"
# (0018, 1152) Exposure                            IS: "200"
# (0018, 1160) Filter Type                         SH: '0'
# (0018, 1170) Generator Power                     IS: "62"
# (0018, 1190) Focal Spot(s)                       DS: "1.2"
# (0018, 1200) Date of Last Calibration            DA: '20090228'
# (0018, 1201) Time of Last Calibration            TM: '134729.000'
# (0018, 1210) Convolution Kernel                  SH: 'B30f'
# (0018, 5100) Patient Position                    CS: 'HFS'
# (0020, 000d) Study Instance UID                  UI: 1.3.6.1.4.1.5962.99.1.448739794.1825383526.1396313143762.43.0
# (0020, 000e) Series Instance UID                 UI: 1.3.6.1.4.1.19291.2.1.2.4188822440541100002
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: "600"
# (0020, 0012) Acquisition Number                  IS: "1"
# (0020, 0013) Instance Number                     IS: "218"
# (0020, 0032) Image Position (Patient)            DS: [-206.190430, -294.854492, -1074.000000]
# (0020, 0037) Image Orientation (Patient)         DS: [1.000000, 0.000000, 0.000000, 0.000000, 1.000000, 0.000000]
# (0020, 0052) Frame of Reference UID              UI: 1.3.6.1.4.1.5962.99.1.448739794.1825383526.1396313143762.45.0
# (0020, 1040) Position Reference Indicator        LO: ''
# (0020, 1041) Slice Location                      DS: "-1074.0"
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 454
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: [0.619141, 0.619141]
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 0
# (0028, 1050) Window Center                       DS: "30.0"
# (0028, 1051) Window Width                        DS: "410.0"
# (0028, 1052) Rescale Intercept                   DS: "-1024.0"
# (0028, 1053) Rescale Slope                       DS: "1.0"
# (0028, 1054) Rescale Type                        LO: 'HU'
# (0032, 1040) Study Arrival Date                  DA: '20090301'
# (0032, 1041) Study Arrival Time                  TM: '000144.000'
# (0032, 1050) Study Completion Date               DA: '20090301'
# (0032, 1051) Study Completion Time               TM: '155848.000'
# (7fe0, 0010) Pixel Data                          OW: Array of 464896 elements,
#  Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 202
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: CT Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.276.0.7238010.5.1.4.0.75157.1397189444.4973
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.276.0.7238010.5.0.3.5.4
# (0002, 0013) Implementation Version Name         SH: 'OSIRIX'
# (0002, 0016) Source Application Entity Title     AE: 'DicomBrowser'
# -------------------------------------------------
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL', 'CT_SOM5 SPI']
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.276.0.7238010.5.1.4.0.75157.1397189444.4973
# (0008, 0020) Study Date                          DA: '20090301'
# (0008, 0021) Series Date                         DA: '20090301'
# (0008, 0022) Acquisition Date                    DA: '20090301'
# (0008, 0023) Content Date                        DA: '20090301'
# (0008, 0030) Study Time                          TM: '000000.000'
# (0008, 0031) Series Time                         TM: '000628.000'
# (0008, 0032) Acquisition Time                    TM: '000531.996'
# (0008, 0033) Content Time                        TM: '000531.996'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 0070) Manufacturer                        LO: 'Manufacturer'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1030) Study Description                   LO: 'ARM'
# (0008, 103e) Series Description                  LO: 'R-ARM LEE 100MB'
# (0008, 1090) Manufacturer's Model Name           LO: 'OsiriX'
# (0008, 1140)  Referenced Image Sequence  1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.5962.99.1.448739794.1825383526.1396313143762.40.0
#    ---------
# (0008, 2112)  Source Image Sequence  1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: 1.3.12.2.1107.5.9.1
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.5962.99.1.448739794.1825383526.1396313143762.41.0
#    ---------
# (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: '121327'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Full fidelity image, uncompressed or lossless compressed'
#    ---------
# (0010, 0010) Patient's Name                      PN: 'ARM^CT'
# (0010, 0020) Patient ID                          LO: '1050'
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: ''
# (0012, 0062) Patient Identity Removed            CS: 'YES'
# (0012, 0063) De-identification Method            LO: ['Deidentified', 'Descriptors retained', 'Patient Characteristics removed', 'Device identity removed', 'Institution identity removed', 'Dates modified', 'Unsafe private removed', 'UIDs remapped']
# (0012, 0064)  De-identification Method Code Sequence  5 item(s) ----
#    (0008, 0100) Code Value                          SH: '113100'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Basic Application Confidentiality Profile'
#    ---------
#    (0008, 0100) Code Value                          SH: '210005'
#    (0008, 0102) Coding Scheme Designator            SH: '99PMP'
#    (0008, 0104) Code Meaning                        LO: 'Retain all descriptors unchanged'
#    ---------
#    (0008, 0100) Code Value                          SH: '113107'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Retain Longitudinal Temporal Information Modified Dates Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '113111'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Retain Safe Private Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '210001'
#    (0008, 0102) Coding Scheme Designator            SH: '99PMP'
#    (0008, 0104) Code Meaning                        LO: 'Remap UIDs'
#    ---------
# (0018, 0015) Body Part Examined                  CS: 'EXTREMITY'
# (0018, 0050) Slice Thickness                     DS: "3.0"
# (0018, 0060) KVP                                 DS: "120.0"
# (0018, 0090) Data Collection Diameter            DS: "500.0"
# (0018, 1000) Device Serial Number                LO: 'SN000000'
# (0018, 1100) Reconstruction Diameter             DS: "317.0"
# (0018, 1110) Distance Source to Detector         DS: "1040.0"
# (0018, 1111) Distance Source to Patient          DS: "570.0"
# (0018, 1120) Gantry/Detector Tilt                DS: "0.0"
# (0018, 1130) Table Height                        DS: "182.0"
# (0018, 1140) Rotation Direction                  CS: 'CW'
# (0018, 1150) Exposure Time                       IS: "500"
# (0018, 1151) X-Ray Tube Current                  IS: "520"
# (0018, 1152) Exposure                            IS: "200"
# (0018, 1160) Filter Type                         SH: '0'
# (0018, 1170) Generator Power                     IS: "62"
# (0018, 1190) Focal Spot(s)                       DS: "1.2"
# (0018, 1200) Date of Last Calibration            DA: '20090228'
# (0018, 1201) Time of Last Calibration            TM: '134729.000'
# (0018, 1210) Convolution Kernel                  SH: 'B30f'
# (0018, 5100) Patient Position                    CS: 'HFS'
# (0020, 000d) Study Instance UID                  UI: 1.3.6.1.4.1.5962.99.1.448739794.1825383526.1396313143762.43.0
# (0020, 000e) Series Instance UID                 UI: 1.3.6.1.4.1.19291.2.1.2.4188822440541100002
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: "600"
# (0020, 0012) Acquisition Number                  IS: "1"
# (0020, 0013) Instance Number                     IS: "51"
# (0020, 0032) Image Position (Patient)            DS: [-206.190430, -294.854492, -573.000000]
# (0020, 0037) Image Orientation (Patient)         DS: [1.000000, 0.000000, 0.000000, 0.000000, 1.000000, 0.000000]
# (0020, 0052) Frame of Reference UID              UI: 1.3.6.1.4.1.5962.99.1.448739794.1825383526.1396313143762.45.0
# (0020, 1040) Position Reference Indicator        LO: ''
# (0020, 1041) Slice Location                      DS: "-573.0"
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 454
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: [0.619141, 0.619141]
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 0
# (0028, 1050) Window Center                       DS: "30.0"
# (0028, 1051) Window Width                        DS: "410.0"
# (0028, 1052) Rescale Intercept                   DS: "-1024.0"
# (0028, 1053) Rescale Slope                       DS: "1.0"
# (0028, 1054) Rescale Type                        LO: 'HU'
# (0032, 1040) Study Arrival Date                  DA: '20090301'
# (0032, 1041) Study Arrival Time                  TM: '000144.000'
# (0032, 1050) Study Completion Date               DA: '20090301'
# (0032, 1051) Study Completion Time               TM: '155848.000'
# (7fe0, 0010) Pixel Data                          OW: Array of 464896 elements,
#  Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 202
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: CT Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.276.0.7238010.5.1.4.0.75157.1397189445.5115
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.276.0.7238010.5.0.3.5.4
# (0002, 0013) Implementation Version Name         SH: 'OSIRIX'
# (0002, 0016) Source Application Entity Title     AE: 'DicomBrowser'
# -------------------------------------------------
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL', 'CT_SOM5 SPI']
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.276.0.7238010.5.1.4.0.75157.1397189445.5115
# (0008, 0020) Study Date                          DA: '20090301'
# (0008, 0021) Series Date                         DA: '20090301'
# (0008, 0022) Acquisition Date                    DA: '20090301'
# (0008, 0023) Content Date                        DA: '20090301'
# (0008, 0030) Study Time                          TM: '000000.000'
# (0008, 0031) Series Time                         TM: '000628.000'
# (0008, 0032) Acquisition Time                    TM: '000523.477'
# (0008, 0033) Content Time                        TM: '000523.477'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 0070) Manufacturer                        LO: 'Manufacturer'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1030) Study Description                   LO: 'ARM'
# (0008, 103e) Series Description                  LO: 'R-ARM LEE 100MB'
# (0008, 1090) Manufacturer's Model Name           LO: 'OsiriX'
# (0008, 1140)  Referenced Image Sequence  1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.5962.99.1.448739794.1825383526.1396313143762.40.0
#    ---------
# (0008, 2112)  Source Image Sequence  1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: 1.3.12.2.1107.5.9.1
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.5962.99.1.448739794.1825383526.1396313143762.41.0
#    ---------
# (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: '121327'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Full fidelity image, uncompressed or lossless compressed'
#    ---------
# (0010, 0010) Patient's Name                      PN: 'ARM^CT'
# (0010, 0020) Patient ID                          LO: '1050'
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: ''
# (0012, 0062) Patient Identity Removed            CS: 'YES'
# (0012, 0063) De-identification Method            LO: ['Deidentified', 'Descriptors retained', 'Patient Characteristics removed', 'Device identity removed', 'Institution identity removed', 'Dates modified', 'Unsafe private removed', 'UIDs remapped']
# (0012, 0064)  De-identification Method Code Sequence  5 item(s) ----
#    (0008, 0100) Code Value                          SH: '113100'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Basic Application Confidentiality Profile'
#    ---------
#    (0008, 0100) Code Value                          SH: '210005'
#    (0008, 0102) Coding Scheme Designator            SH: '99PMP'
#    (0008, 0104) Code Meaning                        LO: 'Retain all descriptors unchanged'
#    ---------
#    (0008, 0100) Code Value                          SH: '113107'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Retain Longitudinal Temporal Information Modified Dates Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '113111'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Retain Safe Private Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '210001'
#    (0008, 0102) Coding Scheme Designator            SH: '99PMP'
#    (0008, 0104) Code Meaning                        LO: 'Remap UIDs'
#    ---------
# (0018, 0015) Body Part Examined                  CS: 'EXTREMITY'
# (0018, 0050) Slice Thickness                     DS: "3.0"
# (0018, 0060) KVP                                 DS: "120.0"
# (0018, 0090) Data Collection Diameter            DS: "500.0"
# (0018, 1000) Device Serial Number                LO: 'SN000000'
# (0018, 1100) Reconstruction Diameter             DS: "317.0"
# (0018, 1110) Distance Source to Detector         DS: "1040.0"
# (0018, 1111) Distance Source to Patient          DS: "570.0"
# (0018, 1120) Gantry/Detector Tilt                DS: "0.0"
# (0018, 1130) Table Height                        DS: "182.0"
# (0018, 1140) Rotation Direction                  CS: 'CW'
# (0018, 1150) Exposure Time                       IS: "500"
# (0018, 1151) X-Ray Tube Current                  IS: "520"
# (0018, 1152) Exposure                            IS: "200"
# (0018, 1160) Filter Type                         SH: '0'
# (0018, 1170) Generator Power                     IS: "62"
# (0018, 1190) Focal Spot(s)                       DS: "1.2"
# (0018, 1200) Date of Last Calibration            DA: '20090228'
# (0018, 1201) Time of Last Calibration            TM: '134729.000'
# (0018, 1210) Convolution Kernel                  SH: 'B30f'
# (0018, 5100) Patient Position                    CS: 'HFS'
# (0020, 000d) Study Instance UID                  UI: 1.3.6.1.4.1.5962.99.1.448739794.1825383526.1396313143762.43.0
# (0020, 000e) Series Instance UID                 UI: 1.3.6.1.4.1.19291.2.1.2.4188822440541100002
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: "600"
# (0020, 0012) Acquisition Number                  IS: "1"
# (0020, 0013) Instance Number                     IS: "193"
# (0020, 0032) Image Position (Patient)            DS: [-206.190430, -294.854492, -999.000000]
# (0020, 0037) Image Orientation (Patient)         DS: [1.000000, 0.000000, 0.000000, 0.000000, 1.000000, 0.000000]
# (0020, 0052) Frame of Reference UID              UI: 1.3.6.1.4.1.5962.99.1.448739794.1825383526.1396313143762.45.0
# (0020, 1040) Position Reference Indicator        LO: ''
# (0020, 1041) Slice Location                      DS: "-999.0"
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 454
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: [0.619141, 0.619141]
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 0
# (0028, 1050) Window Center                       DS: "30.0"
# (0028, 1051) Window Width                        DS: "410.0"
# (0028, 1052) Rescale Intercept                   DS: "-1024.0"
# (0028, 1053) Rescale Slope                       DS: "1.0"
# (0028, 1054) Rescale Type                        LO: 'HU'
# (0032, 1040) Study Arrival Date                  DA: '20090301'
# (0032, 1041) Study Arrival Time                  TM: '000144.000'
# (0032, 1050) Study Completion Date               DA: '20090301'
# (0032, 1051) Study Completion Time               TM: '155848.000'
# (7fe0, 0010) Pixel Data                          OW: Array of 464896 elements,
#  Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 202
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: CT Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.276.0.7238010.5.1.4.0.75157.1397189444.4993
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.276.0.7238010.5.0.3.5.4
# (0002, 0013) Implementation Version Name         SH: 'OSIRIX'
# (0002, 0016) Source Application Entity Title     AE: 'DicomBrowser'
# -------------------------------------------------
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL', 'CT_SOM5 SPI']
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.276.0.7238010.5.1.4.0.75157.1397189444.4993
# (0008, 0020) Study Date                          DA: '20090301'
# (0008, 0021) Series Date                         DA: '20090301'
# (0008, 0022) Acquisition Date                    DA: '20090301'
# (0008, 0023) Content Date                        DA: '20090301'
# (0008, 0030) Study Time                          TM: '000000.000'
# (0008, 0031) Series Time                         TM: '000628.000'
# (0008, 0032) Acquisition Time                    TM: '000530.796'
# (0008, 0033) Content Time                        TM: '000530.796'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 0070) Manufacturer                        LO: 'Manufacturer'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1030) Study Description                   LO: 'ARM'
# (0008, 103e) Series Description                  LO: 'R-ARM LEE 100MB'
# (0008, 1090) Manufacturer's Model Name           LO: 'OsiriX'
# (0008, 1140)  Referenced Image Sequence  1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.5962.99.1.448739794.1825383526.1396313143762.40.0
#    ---------
# (0008, 2112)  Source Image Sequence  1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: 1.3.12.2.1107.5.9.1
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.5962.99.1.448739794.1825383526.1396313143762.41.0
#    ---------
# (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: '121327'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Full fidelity image, uncompressed or lossless compressed'
#    ---------
# (0010, 0010) Patient's Name                      PN: 'ARM^CT'
# (0010, 0020) Patient ID                          LO: '1050'
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: ''
# (0012, 0062) Patient Identity Removed            CS: 'YES'
# (0012, 0063) De-identification Method            LO: ['Deidentified', 'Descriptors retained', 'Patient Characteristics removed', 'Device identity removed', 'Institution identity removed', 'Dates modified', 'Unsafe private removed', 'UIDs remapped']
# (0012, 0064)  De-identification Method Code Sequence  5 item(s) ----
#    (0008, 0100) Code Value                          SH: '113100'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Basic Application Confidentiality Profile'
#    ---------
#    (0008, 0100) Code Value                          SH: '210005'
#    (0008, 0102) Coding Scheme Designator            SH: '99PMP'
#    (0008, 0104) Code Meaning                        LO: 'Retain all descriptors unchanged'
#    ---------
#    (0008, 0100) Code Value                          SH: '113107'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Retain Longitudinal Temporal Information Modified Dates Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '113111'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Retain Safe Private Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '210001'
#    (0008, 0102) Coding Scheme Designator            SH: '99PMP'
#    (0008, 0104) Code Meaning                        LO: 'Remap UIDs'
#    ---------
# (0018, 0015) Body Part Examined                  CS: 'EXTREMITY'
# (0018, 0050) Slice Thickness                     DS: "3.0"
# (0018, 0060) KVP                                 DS: "120.0"
# (0018, 0090) Data Collection Diameter            DS: "500.0"
# (0018, 1000) Device Serial Number                LO: 'SN000000'
# (0018, 1100) Reconstruction Diameter             DS: "317.0"
# (0018, 1110) Distance Source to Detector         DS: "1040.0"
# (0018, 1111) Distance Source to Patient          DS: "570.0"
# (0018, 1120) Gantry/Detector Tilt                DS: "0.0"
# (0018, 1130) Table Height                        DS: "182.0"
# (0018, 1140) Rotation Direction                  CS: 'CW'
# (0018, 1150) Exposure Time                       IS: "500"
# (0018, 1151) X-Ray Tube Current                  IS: "520"
# (0018, 1152) Exposure                            IS: "200"
# (0018, 1160) Filter Type                         SH: '0'
# (0018, 1170) Generator Power                     IS: "62"
# (0018, 1190) Focal Spot(s)                       DS: "1.2"
# (0018, 1200) Date of Last Calibration            DA: '20090228'
# (0018, 1201) Time of Last Calibration            TM: '134729.000'
# (0018, 1210) Convolution Kernel                  SH: 'B30f'
# (0018, 5100) Patient Position                    CS: 'HFS'
# (0020, 000d) Study Instance UID                  UI: 1.3.6.1.4.1.5962.99.1.448739794.1825383526.1396313143762.43.0
# (0020, 000e) Series Instance UID                 UI: 1.3.6.1.4.1.19291.2.1.2.4188822440541100002
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: "600"
# (0020, 0012) Acquisition Number                  IS: "1"
# (0020, 0013) Instance Number                     IS: "71"
# (0020, 0032) Image Position (Patient)            DS: [-206.190430, -294.854492, -633.000000]
# (0020, 0037) Image Orientation (Patient)         DS: [1.000000, 0.000000, 0.000000, 0.000000, 1.000000, 0.000000]
# (0020, 0052) Frame of Reference UID              UI: 1.3.6.1.4.1.5962.99.1.448739794.1825383526.1396313143762.45.0
# (0020, 1040) Position Reference Indicator        LO: ''
# (0020, 1041) Slice Location                      DS: "-633.0"
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 454
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: [0.619141, 0.619141]
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 0
# (0028, 1050) Window Center                       DS: "30.0"
# (0028, 1051) Window Width                        DS: "410.0"
# (0028, 1052) Rescale Intercept                   DS: "-1024.0"
# (0028, 1053) Rescale Slope                       DS: "1.0"
# (0028, 1054) Rescale Type                        LO: 'HU'
# (0032, 1040) Study Arrival Date                  DA: '20090301'
# (0032, 1041) Study Arrival Time                  TM: '000144.000'
# (0032, 1050) Study Completion Date               DA: '20090301'
# (0032, 1051) Study Completion Time               TM: '155848.000'
# (7fe0, 0010) Pixel Data                          OW: Array of 464896 elements,
#  Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 202
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: CT Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.276.0.7238010.5.1.4.0.75157.1397189444.4985
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.276.0.7238010.5.0.3.5.4
# (0002, 0013) Implementation Version Name         SH: 'OSIRIX'
# (0002, 0016) Source Application Entity Title     AE: 'DicomBrowser'
# -------------------------------------------------
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL', 'CT_SOM5 SPI']
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# ...
# (0032, 1041) Study Arrival Time                  TM: '000144.000'
# (0032, 1050) Study Completion Date               DA: '20090301'
# (0032, 1051) Study Completion Time               TM: '155848.000'
# (7fe0, 0010) Pixel Data                          OW: Array of 464896 elements,
#  Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 202
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: CT Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.276.0.7238010.5.1.4.0.75157.1397189444.5047
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.276.0.7238010.5.0.3.5.4
# (0002, 0013) Implementation Version Name         SH: 'OSIRIX'
# (0002, 0016) Source Application Entity Title     AE: 'DicomBrowser'
# -------------------------------------------------
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL', 'CT_SOM5 SPI']
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.276.0.7238010.5.1.4.0.75157.1397189444.5047
# (0008, 0020) Study Date                          DA: '20090301'
# (0008, 0021) Series Date                         DA: '20090301'
# (0008, 0022) Acquisition Date                    DA: '20090301'
# (0008, 0023) Content Date                        DA: '20090301'
# (0008, 0030) Study Time                          TM: '000000.000'
# (0008, 0031) Series Time                         TM: '000628.000'
# (0008, 0032) Acquisition Time                    TM: '000527.580'
# (0008, 0033) Content Time                        TM: '000527.580'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 0070) Manufacturer                        LO: 'Manufacturer'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1030) Study Description                   LO: 'ARM'
# (0008, 103e) Series Description                  LO: 'R-ARM LEE 100MB'
# (0008, 1090) Manufacturer's Model Name           LO: 'OsiriX'
# (0008, 1140)  Referenced Image Sequence  1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.5962.99.1.448739794.1825383526.1396313143762.40.0
#    ---------
# (0008, 2112)  Source Image Sequence  1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: 1.3.12.2.1107.5.9.1
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.5962.99.1.448739794.1825383526.1396313143762.41.0
#    ---------
# (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: '121327'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Full fidelity image, uncompressed or lossless compressed'
#    ---------
# (0010, 0010) Patient's Name                      PN: 'ARM^CT'
# (0010, 0020) Patient ID                          LO: '1050'
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: ''
# (0012, 0062) Patient Identity Removed            CS: 'YES'
# (0012, 0063) De-identification Method            LO: ['Deidentified', 'Descriptors retained', 'Patient Characteristics removed', 'Device identity removed', 'Institution identity removed', 'Dates modified', 'Unsafe private removed', 'UIDs remapped']
# (0012, 0064)  De-identification Method Code Sequence  5 item(s) ----
#    (0008, 0100) Code Value                          SH: '113100'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Basic Application Confidentiality Profile'
#    ---------
#    (0008, 0100) Code Value                          SH: '210005'
#    (0008, 0102) Coding Scheme Designator            SH: '99PMP'
#    (0008, 0104) Code Meaning                        LO: 'Retain all descriptors unchanged'
#    ---------
#    (0008, 0100) Code Value                          SH: '113107'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Retain Longitudinal Temporal Information Modified Dates Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '113111'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Retain Safe Private Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '210001'
#    (0008, 0102) Coding Scheme Designator            SH: '99PMP'
#    (0008, 0104) Code Meaning                        LO: 'Remap UIDs'
#    ---------
# (0018, 0015) Body Part Examined                  CS: 'EXTREMITY'
# (0018, 0050) Slice Thickness                     DS: "3.0"
# (0018, 0060) KVP                                 DS: "120.0"
# (0018, 0090) Data Collection Diameter            DS: "500.0"
# (0018, 1000) Device Serial Number                LO: 'SN000000'
# (0018, 1100) Reconstruction Diameter             DS: "317.0"
# (0018, 1110) Distance Source to Detector         DS: "1040.0"
# (0018, 1111) Distance Source to Patient          DS: "570.0"
# (0018, 1120) Gantry/Detector Tilt                DS: "0.0"
# (0018, 1130) Table Height                        DS: "182.0"
# (0018, 1140) Rotation Direction                  CS: 'CW'
# (0018, 1150) Exposure Time                       IS: "500"
# (0018, 1151) X-Ray Tube Current                  IS: "520"
# (0018, 1152) Exposure                            IS: "200"
# (0018, 1160) Filter Type                         SH: '0'
# (0018, 1170) Generator Power                     IS: "62"
# (0018, 1190) Focal Spot(s)                       DS: "1.2"
# (0018, 1200) Date of Last Calibration            DA: '20090228'
# (0018, 1201) Time of Last Calibration            TM: '134729.000'
# (0018, 1210) Convolution Kernel                  SH: 'B30f'
# (0018, 5100) Patient Position                    CS: 'HFS'
# (0020, 000d) Study Instance UID                  UI: 1.3.6.1.4.1.5962.99.1.448739794.1825383526.1396313143762.43.0
# (0020, 000e) Series Instance UID                 UI: 1.3.6.1.4.1.19291.2.1.2.4188822440541100002
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: "600"
# (0020, 0012) Acquisition Number                  IS: "1"
# (0020, 0013) Instance Number                     IS: "125"
# (0020, 0032) Image Position (Patient)            DS: [-206.190430, -294.854492, -795.000000]
# (0020, 0037) Image Orientation (Patient)         DS: [1.000000, 0.000000, 0.000000, 0.000000, 1.000000, 0.000000]
# (0020, 0052) Frame of Reference UID              UI: 1.3.6.1.4.1.5962.99.1.448739794.1825383526.1396313143762.45.0
# (0020, 1040) Position Reference Indicator        LO: ''
# (0020, 1041) Slice Location                      DS: "-795.0"
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 454
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: [0.619141, 0.619141]
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 0
# (0028, 1050) Window Center                       DS: "30.0"
# (0028, 1051) Window Width                        DS: "410.0"
# (0028, 1052) Rescale Intercept                   DS: "-1024.0"
# (0028, 1053) Rescale Slope                       DS: "1.0"
# (0028, 1054) Rescale Type                        LO: 'HU'
# (0032, 1040) Study Arrival Date                  DA: '20090301'
# (0032, 1041) Study Arrival Time                  TM: '000144.000'
# (0032, 1050) Study Completion Date               DA: '20090301'
# (0032, 1051) Study Completion Time               TM: '155848.000'
# (7fe0, 0010) Pixel Data                          OW: Array of 464896 elements,
#  Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 202
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: CT Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.276.0.7238010.5.1.4.0.75157.1397189444.5045
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.276.0.7238010.5.0.3.5.4
# (0002, 0013) Implementation Version Name         SH: 'OSIRIX'
# (0002, 0016) Source Application Entity Title     AE: 'DicomBrowser'
# -------------------------------------------------
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL', 'CT_SOM5 SPI']
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.276.0.7238010.5.1.4.0.75157.1397189444.5045
# (0008, 0020) Study Date                          DA: '20090301'
# (0008, 0021) Series Date                         DA: '20090301'
# (0008, 0022) Acquisition Date                    DA: '20090301'
# (0008, 0023) Content Date                        DA: '20090301'
# (0008, 0030) Study Time                          TM: '000000.000'
# (0008, 0031) Series Time                         TM: '000628.000'
# (0008, 0032) Acquisition Time                    TM: '000527.700'
# (0008, 0033) Content Time                        TM: '000527.700'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 0070) Manufacturer                        LO: 'Manufacturer'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1030) Study Description                   LO: 'ARM'
# (0008, 103e) Series Description                  LO: 'R-ARM LEE 100MB'
# (0008, 1090) Manufacturer's Model Name           LO: 'OsiriX'
# (0008, 1140)  Referenced Image Sequence  1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.5962.99.1.448739794.1825383526.1396313143762.40.0
#    ---------
# (0008, 2112)  Source Image Sequence  1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: 1.3.12.2.1107.5.9.1
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.5962.99.1.448739794.1825383526.1396313143762.41.0
#    ---------
# (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: '121327'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Full fidelity image, uncompressed or lossless compressed'
#    ---------
# (0010, 0010) Patient's Name                      PN: 'ARM^CT'
# (0010, 0020) Patient ID                          LO: '1050'
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: ''
# (0012, 0062) Patient Identity Removed            CS: 'YES'
# (0012, 0063) De-identification Method            LO: ['Deidentified', 'Descriptors retained', 'Patient Characteristics removed', 'Device identity removed', 'Institution identity removed', 'Dates modified', 'Unsafe private removed', 'UIDs remapped']
# (0012, 0064)  De-identification Method Code Sequence  5 item(s) ----
#    (0008, 0100) Code Value                          SH: '113100'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Basic Application Confidentiality Profile'
#    ---------
#    (0008, 0100) Code Value                          SH: '210005'
#    (0008, 0102) Coding Scheme Designator            SH: '99PMP'
#    (0008, 0104) Code Meaning                        LO: 'Retain all descriptors unchanged'
#    ---------
#    (0008, 0100) Code Value                          SH: '113107'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Retain Longitudinal Temporal Information Modified Dates Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '113111'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Retain Safe Private Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '210001'
#    (0008, 0102) Coding Scheme Designator            SH: '99PMP'
#    (0008, 0104) Code Meaning                        LO: 'Remap UIDs'
#    ---------
# (0018, 0015) Body Part Examined                  CS: 'EXTREMITY'
# (0018, 0050) Slice Thickness                     DS: "3.0"
# (0018, 0060) KVP                                 DS: "120.0"
# (0018, 0090) Data Collection Diameter            DS: "500.0"
# (0018, 1000) Device Serial Number                LO: 'SN000000'
# (0018, 1100) Reconstruction Diameter             DS: "317.0"
# (0018, 1110) Distance Source to Detector         DS: "1040.0"
# (0018, 1111) Distance Source to Patient          DS: "570.0"
# (0018, 1120) Gantry/Detector Tilt                DS: "0.0"
# (0018, 1130) Table Height                        DS: "182.0"
# (0018, 1140) Rotation Direction                  CS: 'CW'
# (0018, 1150) Exposure Time                       IS: "500"
# (0018, 1151) X-Ray Tube Current                  IS: "520"
# (0018, 1152) Exposure                            IS: "200"
# (0018, 1160) Filter Type                         SH: '0'
# (0018, 1170) Generator Power                     IS: "62"
# (0018, 1190) Focal Spot(s)                       DS: "1.2"
# (0018, 1200) Date of Last Calibration            DA: '20090228'
# (0018, 1201) Time of Last Calibration            TM: '134729.000'
# (0018, 1210) Convolution Kernel                  SH: 'B30f'
# (0018, 5100) Patient Position                    CS: 'HFS'
# (0020, 000d) Study Instance UID                  UI: 1.3.6.1.4.1.5962.99.1.448739794.1825383526.1396313143762.43.0
# (0020, 000e) Series Instance UID                 UI: 1.3.6.1.4.1.19291.2.1.2.4188822440541100002
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: "600"
# (0020, 0012) Acquisition Number                  IS: "1"
# (0020, 0013) Instance Number                     IS: "123"
# (0020, 0032) Image Position (Patient)            DS: [-206.190430, -294.854492, -789.000000]
# (0020, 0037) Image Orientation (Patient)         DS: [1.000000, 0.000000, 0.000000, 0.000000, 1.000000, 0.000000]
# (0020, 0052) Frame of Reference UID              UI: 1.3.6.1.4.1.5962.99.1.448739794.1825383526.1396313143762.45.0
# (0020, 1040) Position Reference Indicator        LO: ''
# (0020, 1041) Slice Location                      DS: "-789.0"
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 454
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: [0.619141, 0.619141]
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 0
# (0028, 1050) Window Center                       DS: "30.0"
# (0028, 1051) Window Width                        DS: "410.0"
# (0028, 1052) Rescale Intercept                   DS: "-1024.0"
# (0028, 1053) Rescale Slope                       DS: "1.0"
# (0028, 1054) Rescale Type                        LO: 'HU'
# (0032, 1040) Study Arrival Date                  DA: '20090301'
# (0032, 1041) Study Arrival Time                  TM: '000144.000'
# (0032, 1050) Study Completion Date               DA: '20090301'
# (0032, 1051) Study Completion Time               TM: '155848.000'
# (7fe0, 0010) Pixel Data                          OW: Array of 464896 elements]

# %%
# 2) Now create and show axial, sagittal, and coronal slices from the 3D volume.
# Hint: Please use imshow(XX, cmap='gray') to show the image.
import numpy as np
import matplotlib.pyplot as plt

# %%
# TODO: YOUR CODE FOR AXIAL
imshow(ArrayDicom[:, :, 32],cmap='gray')

# %%
# TODO: YOUR CODE FOR SAGITTAL
imshow(squeeze(ArrayDicom[:,32,:]).T,cmap='gray')

# %%
# TODO: YOUR CODE FOR CORONAL
imshow(squeeze(ArrayDicom[192, :, :].T),cmap='gray')

# %% [markdown]
# **Task 3**: Use the Window/Level-technique to visualize the data! [45 Points]

# %%
# We will now enhance the visualization from above by performing 
# Window/Level adjustment.
# Here is one way of doing that:
#   vmin = level - window/2
#   vmax = level + window/2
#   plt.imshow(hu_pixels + rescale, cmap='gray', vmin=vmin, vmax=vmax)
#   plt.show()

# %%
# 1) Please load the Window/Level values from the DICOM file,
# print these values, and then visualize one slice with window/level adjustment.
# Hint: The DICOM header has the following tags.
#   (0028, 1050) Window Center 
#   (0028, 1051) Window Width
# Hint 2: You can use slice[key].value to access DICOM tag values.
# Hint 3: (0028, 1052) Rescale Intercept might be important.

# %%
# TODO: 
sl1=sampl1[1]

# %%
hu_pixels=sl1.pixel_array*sl1.RescaleSlope
level=sl1.WindowCenter
window=sl1.WindowWidth
vmin = level - window/2
vmax = level + window/2
rescale=sl1.RescaleIntercept
plt.imshow(hu_pixels + rescale, cmap='gray', vmin=vmin, vmax=vmax)
plt.show()

# %%
print(vmin)
print(vmax)
# Out:
# -175.0
# 235.0

# %%
# 2) Play around with different Window/Level values that enhance
# the visualization.

# %%
# TODO: YOUR CODE
vmin= -100
vmax= 200
plt.imshow(hu_pixels + rescale, cmap='gray', vmin=vmin, vmax=vmax)
plt.show()
vmin= -50
vmax = 150
plt.imshow(hu_pixels + rescale, cmap='gray', vmin=vmin, vmax=vmax)
plt.show()
vmin= 0
vmax=100
plt.imshow(hu_pixels + rescale, cmap='gray', vmin=vmin, vmax=vmax)
plt.show()
vmin=20
vmax=80
plt.imshow(hu_pixels + rescale, cmap='gray', vmin=vmin, vmax=vmax)
plt.show()

# %%
# Which values make sense and why?

# %%
# TODO:

# %%
# the values which are very much to the extremes have a better window/level image quality than the images with much 
# nearer vmin, vmax values.

# %% [markdown]
# **Bonus**: Create segmentations (label maps) for the volume using thresholding HU! [33 Points]

# %%
# Similar to Window/Level adjustment for visualization, we can threshold
# the volume to highlight the following components using the Hounsfield Units:
# 1) Fat
# 2) Soft Tissue
# 3) Bones
#
# Please create 3 segmentation masks for these structures.
# Then, please visualize each 3 slices per structure to showcase the segmentation.
# Hint: As a reminder, the following code allows thresholding of a numpy array.
#   new_mask = imagevolume.copy()
#   new_mask[new_mask < XXX] = 0
# Hint2: You might need to cast new_mask to int16 not uint16.

# %%
# TODO: YOUR CODE TO SEGMENT FAT
imagevolume= ArrayDicom[:, :, 32]
new_mask = imagevolume.copy()
plt.imshow(hu_pixels + rescale, cmap='gray',vmin=-100,vmax=-50)
plt.show()
#the HU units for Fat is -100 to -50

# %%
# TODO: YOUR CODE TO SEGMENT SOFT TISSUE
imagevolume= ArrayDicom[:, :, 32]
new_mask = imagevolume.copy()
plt.imshow(hu_pixels + rescale, cmap='gray',vmin=10,vmax=40)
plt.show()
#The HU units for tissues/muscle is 10 and 40

# %%
  # TODO: YOUR CODE TO SEGMENT BONES
imagevolume= ArrayDicom[:, :, 32]
new_mask = imagevolume.copy()
plt.imshow(hu_pixels + rescale, cmap='gray',vmin=700,vmax=3000)
plt.show()
# the HU units for Bones is 700 and 3000

# %%
# Are the segmentations good?

# %%
# TODO: YOUR ANSWER

# %%
#Yeah, the segmentations are pretty good given the HU units and limits of each segments.

# %%
#
# Thank you and Great job!!
#
#                _.---._
#              .'       `.
#              :)       (:
#              \ (@) (@) /
#               \   A   /
#                )     (
#                \"""""/
#                 `._.'
#                  .=.
#          .---._.-.=.-._.---.
#         / ':-(_.-: :-._)-:` \
#        / /' (__.-: :-.__) `\ \
#       / /  (___.-` '-.___)  \ \
#      / /   (___.-'^`-.___)   \ \
#     / /    (___.-'=`-.___)    \ \
#    / /     (____.'=`.____)     \ \
#   / /       (___.'=`.___)       \ \
#  (_.;       `---'.=.`---'       ;._)
#  ;||        __  _.=._  __        ||;
#  ;||       (  `.-.=.-.'  )       ||;
#  ;||       \    `.=.'    /       ||;
#  ;||        \    .=.    /        ||;
#  ;||       .-`.`-._.-'.'-.       ||;
# .:::\      ( ,): O O :(, )      /:::.
# |||| `     / /'`--'--'`\ \     ' ||||
# ''''      / /           \ \      ''''
#          / /             \ \
#         / /               \ \
#        / /                 \ \
#       / /                   \ \
#      / /                     \ \
#     /.'                       `.\
#    (_)'                       `(_)
#     \\.                       .//
#      \\.                     .//
#       \\.                   .//
#        \\.                 .//
#         \\.               .//
#          \\.             .//
#     jgs   \\.           .//
#           ///)         (\\\
#         ,///'           `\\\,
#        ///'               `\\\
#       ""'                   '""
