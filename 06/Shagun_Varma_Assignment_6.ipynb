# %% [markdown]
# <a href="https://colab.research.google.com/github/ShagunVarma08/cs480student/blob/main/06/Shagun_Varma_Assignment_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![CS480_w.png](data:image/png;base64,...)
# #Assignment 6

# %%
# In this assignment, we will train a U-Net classifer to detect mitochondria
# in electron microscopy images!

# %%
### IMPORTANT ###
#
# Activate GPU support: Runtime -> Change Runtime Type
# Hardware Accelerator: GPU
#
### IMPORTANT ###

# %%
# load numpy and matplotlib
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# load the unet tensorflow code
# !pip install git+https://github.com/jakeret/unet.git
# Out:
# Collecting git+https://github.com/jakeret/unet.git
#   Cloning https://github.com/jakeret/unet.git to /tmp/pip-req-build-586gdcuj
#   Running command git clone -q https://github.com/jakeret/unet.git /tmp/pip-req-build-586gdcuj
# Requirement already satisfied (use --upgrade to upgrade): unet==0.0.post0.dev81+gf557a51 from git+https://github.com/jakeret/unet.git in /usr/local/lib/python3.7/dist-packages
# Building wheels for collected packages: unet
#   Building wheel for unet (setup.py) ... done
#   Created wheel for unet: filename=unet-0.0.post0.dev81+gf557a51-py2.py3-none-any.whl size=25658 sha256=d0399172dd663a25ed70e5addb9deeff3edb98ab13638f6ac4dff21b036c05e8
#   Stored in directory: /tmp/pip-ephem-wheel-cache-pmik0cdn/wheels/f5/38/c8/8f0a157cfd7616cc1a24811a52b9a669c0ee8fccc9f99d3cbc
# Successfully built unet

# %%
# .. and use it!
# Note: There are a ton of U-Net implementations but this one is easier to use!
import unet

# %% [markdown]
# # **Task 1**: Study the unet circle example and learn about mitochondria! [15 Points]

# %%
# The unet package allows to train a U-Net classifier with little code.
# As discussed in class, the U-Net can be used to label/segment/annotate images.

# %%
# TODO: Please study the Circles example 
# https://github.com/jakeret/unet/blob/master/notebooks/circles.ipynb

# %%
# TODO: ... and look how the (artificial) dataset is generated
# https://github.com/jakeret/unet/blob/master/src/unet/datasets/circles.py

# %%
# 1) Question
# TODO: Please describe what the U-Net is trained to do.
#
# TODO: YOUR ANSWER

# %% [markdown]
# U-Net takes in an image as input and outputs a segmentation map. It is called U-Net because it has a U shape in its architecture. Which means there are multiple layers where downsampling of the image is done where the general convolutional process takes place until some decision process is made and then upsampling is done while the multiple hierarchical layers communicate with each other. At the end you get the output segmentation map.

# %%
# 2) Question
# TODO: In circles.py, what does the following mean:
#     channels = 1
#     classes = 2
#
# TODO: YOUR ANSWER

# %% [markdown]
# channels =1 :
#
# It is the depth of the matrices or number of filters involved in the convolutions. And in this code the depth is set to 1.
#
# classes = 2  :
#
# The expected output in semantic segmentation are not just labels and bounding box parameters. The output itself is a high resolution image in which each pixel is classified to a particular class. Thus it is a pixel level image classification. So it means that there are 2 pixel level image classifications in this code.

# %%
# 3) Question
# TODO: What are mitochondria and what is their appearance in
# electron microscopy data?
# Hint: You can validate your answer in Task 4!
#
# TODO: YOUR ANSWER

# %% [markdown]
# Mitochondria are specialized structures unique to the cells of animals, plants and fungi. They serve as batteries, powering various functions of the cell and the organism as a whole.
#
# Mitochondria have a distinctive appearance when viewed by electron microscopy. They often appear as rounded or sausage-shaped structures.
#
# Reference : https://www.open.edu/openlearn/science-maths-technology/science/tour-the-cell/content-section-4.10

# %% [markdown]
# # **Task 2**: Setup a datagenerator for mitochondria images! [45 Points]

# %%
# TODO: 
# Download https://cs480.org/data/mito.npz to your computer.
# Then, please upload mito.npz using the file panel on the left.

# %% [markdown]
# Done!

# %%
# The code below is similar to the circles.py file from Task 1.
# We follow Tensorflow conventions to design a tf.data.Dataset for training
# the U-Net.
#
# TODO: Please add four different data augmentation methods in the code block
# below. (image normalization to 0..1, horizontal data flip, vertical data flip,
# rotation by 90 degrees)
#
# Hint: https://github.com/jakeret/unet/blob/master/src/unet/datasets/oxford_iiit_pet.py#L25

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow_datasets.core import DatasetInfo
from typing import Tuple, List

IMAGE_SIZE = (256, 256)
channels = 1
classes = 2

def load_data(count:int, splits:Tuple[float]=(0.7, 0.2, 0.1), **kwargs) -> List[tf.data.Dataset]:
    return [tf.data.Dataset.from_tensor_slices(_build_samples(int(split * count), **kwargs))
            for split in splits]


def _build_samples(sample_count:int, **kwargs) -> Tuple[np.array, np.array]:

    # here we load the mitochondria data
    loaded = np.load('mito.npz')
    loadedimages = loaded['arr_0'][0].copy()
    loadedmasks = loaded['arr_0'][1].copy()

    # now let's go to numpyland
    images = np.empty((sample_count, IMAGE_SIZE[0], IMAGE_SIZE[1], 1))
    labels = np.empty((sample_count, IMAGE_SIZE[0], IMAGE_SIZE[1], 2))
    for i in range(sample_count):
        image, mask = loadedimages[i], loadedmasks[i]

        image = image.reshape((IMAGE_SIZE[0], IMAGE_SIZE[1], 1)).astype(np.float)
        mask = mask.reshape((IMAGE_SIZE[0], IMAGE_SIZE[1], 1))

        # TODO: Normalize the image to 0..1
        #
        image = tf.cast(image, tf.float32) / 255.0
        mask -= 1
          
        # TODO: Use Tensorflow to flip the image horizontally
        #
        if tf.random.uniform(()) > 0.5:
            image = tf.image.flip_left_right(image)
            mask = tf.image.flip_left_right(mask)
    
        # TODO: Use Tensorflow to flip the image vertically
        #
        if tf.random.uniform(()) > 0.5:
           image = tf.image.random_flip_up_down(image)
           mask = tf.image.random_flip_up_down(mask)

        # TODO: Use Tensorflow to rotate the image 90 degrees
        # 
        if tf.random.uniform(()) > 0.5:
           image = tf.image.rot90(image)
           mask = tf.image.rot90(mask)

        # augmentation done, let's store the image
        images[i] = image

        # here we split the mask to background and foreground
        fg = np.zeros((IMAGE_SIZE[0], IMAGE_SIZE[1], 1), dtype=np.bool)
        fg[mask == 255] = 1
        bg = np.zeros((IMAGE_SIZE[0], IMAGE_SIZE[1], 1), dtype=np.bool)
        bg[mask == 0] = 1
        
        labels[i, :, :, 0] = bg[:,:,0]
        labels[i, :, :, 1] = fg[:,:,0]

    return images, labels

# %% [markdown]
# # **Task 3**: Let's train the U-Net! [25 Points]

# %%
# We can now create our training, validation, and testing data by calling
# our methods from Task 2.
#
train, val, test = load_data( 660, splits=(0.7, 0.2, 0.1) )

# %%
# 1) Question
# TODO: We have in total 660 images + 660 masks. Based on the code above,
# how many images are used for training alone?
#
# TODO: YOUR ANSWER

# %% [markdown]
# 70% of images are used for training alone i.e, 462 images are used for training alone.

# %%
# Let's setup the U-Net!
#
LEARNING_RATE = 1e-3

unet_model = unet.build_model(channels=channels,
                              num_classes=classes,
                              layer_depth=5,
                              filters_root=64,
                              padding="same")

unet.finalize_model(unet_model, learning_rate=LEARNING_RATE)

# %%
# And, let's setup the trainer...
#
trainer = unet.Trainer(checkpoint_callback=False,
                       learning_rate_scheduler=unet.SchedulerType.WARMUP_LINEAR_DECAY,
                       warmup_proportion=0.1,
                       learning_rate=LEARNING_RATE)

# %%
# ...and train the U-Net for 50 epochs with a batch_size of 10!
#
# TODO: Please complete the code below.
# Hint: Don't forget to use training and validation data.
# Hint 2: This will take roughly 30 minutes!
#

trainer.fit(unet_model,
            train,
            val,
            epochs=50,
            batch_size=10
            )
# Out:
# Epoch 1/50
# 47/47 [==============================] - 31s 559ms/step - loss: 0.5848 - categorical_crossentropy: 0.5848 - categorical_accuracy: 0.4472 - mean_iou: 0.2574 - dice_coefficient: 0.5172 - auc: 0.5801 - val_loss: 0.2972 - val_categorical_crossentropy: 0.2972 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3497 - val_dice_coefficient: 0.7082 - val_auc: 0.9893
# Epoch 2/50
# 47/47 [==============================] - 20s 435ms/step - loss: 0.0790 - categorical_crossentropy: 0.0790 - categorical_accuracy: 0.9210 - mean_iou: 0.4281 - dice_coefficient: 0.8831 - auc: 0.9721 - val_loss: 0.1915 - val_categorical_crossentropy: 0.1915 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3895 - val_dice_coefficient: 0.7923 - val_auc: 0.9896
# Epoch 3/50
# 47/47 [==============================] - 20s 436ms/step - loss: 0.0844 - categorical_crossentropy: 0.0844 - categorical_accuracy: 0.9210 - mean_iou: 0.4261 - dice_coefficient: 0.8779 - auc: 0.9741 - val_loss: 0.1865 - val_categorical_crossentropy: 0.1865 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3915 - val_dice_coefficient: 0.7966 - val_auc: 0.9895
# Epoch 4/50
# 47/47 [==============================] - 20s 435ms/step - loss: 0.1034 - categorical_crossentropy: 0.1034 - categorical_accuracy: 0.9210 - mean_iou: 0.4179 - dice_coefficient: 0.8607 - auc: 0.9722 - val_loss: 0.1328 - val_categorical_crossentropy: 0.1328 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4132 - val_dice_coefficient: 0.8431 - val_auc: 0.9895
# Epoch 5/50
# 47/47 [==============================] - 20s 435ms/step - loss: 0.0927 - categorical_crossentropy: 0.0927 - categorical_accuracy: 0.9210 - mean_iou: 0.4223 - dice_coefficient: 0.8699 - auc: 0.9737 - val_loss: 0.1438 - val_categorical_crossentropy: 0.1438 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4088 - val_dice_coefficient: 0.8335 - val_auc: 0.9897
# Epoch 6/50
# 47/47 [==============================] - 20s 435ms/step - loss: 0.0911 - categorical_crossentropy: 0.0911 - categorical_accuracy: 0.9210 - mean_iou: 0.4232 - dice_coefficient: 0.8716 - auc: 0.9742 - val_loss: 0.1409 - val_categorical_crossentropy: 0.1409 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4101 - val_dice_coefficient: 0.8361 - val_auc: 0.9898
# Epoch 7/50
# 47/47 [==============================] - 20s 436ms/step - loss: 0.0893 - categorical_crossentropy: 0.0893 - categorical_accuracy: 0.9210 - mean_iou: 0.4237 - dice_coefficient: 0.8728 - auc: 0.9748 - val_loss: 0.1511 - val_categorical_crossentropy: 0.1511 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4060 - val_dice_coefficient: 0.8273 - val_auc: 0.9898
# Epoch 8/50
# 47/47 [==============================] - 20s 435ms/step - loss: 0.0964 - categorical_crossentropy: 0.0964 - categorical_accuracy: 0.9210 - mean_iou: 0.4208 - dice_coefficient: 0.8666 - auc: 0.9741 - val_loss: 0.0974 - val_categorical_crossentropy: 0.0974 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4283 - val_dice_coefficient: 0.8754 - val_auc: 0.9899
# Epoch 9/50
# 47/47 [==============================] - 20s 436ms/step - loss: 0.0847 - categorical_crossentropy: 0.0847 - categorical_accuracy: 0.9210 - mean_iou: 0.4255 - dice_coefficient: 0.8767 - auc: 0.9761 - val_loss: 0.1041 - val_categorical_crossentropy: 0.1041 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4258 - val_dice_coefficient: 0.8695 - val_auc: 0.9899
# Epoch 10/50
# 47/47 [==============================] - 20s 435ms/step - loss: 0.0859 - categorical_crossentropy: 0.0859 - categorical_accuracy: 0.9210 - mean_iou: 0.4251 - dice_coefficient: 0.8758 - auc: 0.9765 - val_loss: 0.0994 - val_categorical_crossentropy: 0.0994 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4279 - val_dice_coefficient: 0.8739 - val_auc: 0.9900
# Epoch 11/50
# 47/47 [==============================] - 20s 436ms/step - loss: 0.0843 - categorical_crossentropy: 0.0843 - categorical_accuracy: 0.9210 - mean_iou: 0.4259 - dice_coefficient: 0.8773 - auc: 0.9774 - val_loss: 0.1006 - val_categorical_crossentropy: 0.1006 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4276 - val_dice_coefficient: 0.8731 - val_auc: 0.9901
# Epoch 12/50
# 47/47 [==============================] - 20s 435ms/step - loss: 0.0842 - categorical_crossentropy: 0.0842 - categorical_accuracy: 0.9210 - mean_iou: 0.4261 - dice_coefficient: 0.8775 - auc: 0.9781 - val_loss: 0.1008 - val_categorical_crossentropy: 0.1008 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4278 - val_dice_coefficient: 0.8731 - val_auc: 0.9903
# Epoch 13/50
# 47/47 [==============================] - 20s 435ms/step - loss: 0.0839 - categorical_crossentropy: 0.0839 - categorical_accuracy: 0.9210 - mean_iou: 0.4264 - dice_coefficient: 0.8778 - auc: 0.9787 - val_loss: 0.1008 - val_categorical_crossentropy: 0.1008 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4280 - val_dice_coefficient: 0.8733 - val_auc: 0.9903
# Epoch 14/50
# 47/47 [==============================] - 20s 435ms/step - loss: 0.0838 - categorical_crossentropy: 0.0838 - categorical_accuracy: 0.9210 - mean_iou: 0.4266 - dice_coefficient: 0.8780 - auc: 0.9794 - val_loss: 0.0996 - val_categorical_crossentropy: 0.0996 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4287 - val_dice_coefficient: 0.8747 - val_auc: 0.9904
# Epoch 15/50
# 47/47 [==============================] - 20s 436ms/step - loss: 0.0836 - categorical_crossentropy: 0.0836 - categorical_accuracy: 0.9210 - mean_iou: 0.4269 - dice_coefficient: 0.8784 - auc: 0.9799 - val_loss: 0.0996 - val_categorical_crossentropy: 0.0996 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4290 - val_dice_coefficient: 0.8749 - val_auc: 0.9904
# Epoch 16/50
# 47/47 [==============================] - 20s 435ms/step - loss: 0.0835 - categorical_crossentropy: 0.0835 - categorical_accuracy: 0.9210 - mean_iou: 0.4271 - dice_coefficient: 0.8785 - auc: 0.9804 - val_loss: 0.0979 - val_categorical_crossentropy: 0.0979 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4299 - val_dice_coefficient: 0.8767 - val_auc: 0.9904
# Epoch 17/50
# 47/47 [==============================] - 20s 435ms/step - loss: 0.0830 - categorical_crossentropy: 0.0830 - categorical_accuracy: 0.9210 - mean_iou: 0.4275 - dice_coefficient: 0.8791 - auc: 0.9809 - val_loss: 0.0970 - val_categorical_crossentropy: 0.0970 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4304 - val_dice_coefficient: 0.8777 - val_auc: 0.9905
# Epoch 18/50
# 47/47 [==============================] - 20s 436ms/step - loss: 0.0826 - categorical_crossentropy: 0.0826 - categorical_accuracy: 0.9210 - mean_iou: 0.4278 - dice_coefficient: 0.8795 - auc: 0.9814 - val_loss: 0.0970 - val_categorical_crossentropy: 0.0970 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4306 - val_dice_coefficient: 0.8779 - val_auc: 0.9905
# Epoch 19/50
# 47/47 [==============================] - 20s 435ms/step - loss: 0.0826 - categorical_crossentropy: 0.0826 - categorical_accuracy: 0.9210 - mean_iou: 0.4279 - dice_coefficient: 0.8796 - auc: 0.9817 - val_loss: 0.0957 - val_categorical_crossentropy: 0.0957 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4313 - val_dice_coefficient: 0.8793 - val_auc: 0.9905
# Epoch 20/50
# 47/47 [==============================] - 20s 435ms/step - loss: 0.0824 - categorical_crossentropy: 0.0824 - categorical_accuracy: 0.9210 - mean_iou: 0.4281 - dice_coefficient: 0.8799 - auc: 0.9820 - val_loss: 0.0939 - val_categorical_crossentropy: 0.0939 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4322 - val_dice_coefficient: 0.8811 - val_auc: 0.9905
# Epoch 21/50
# 47/47 [==============================] - 20s 435ms/step - loss: 0.0819 - categorical_crossentropy: 0.0819 - categorical_accuracy: 0.9210 - mean_iou: 0.4285 - dice_coefficient: 0.8805 - auc: 0.9824 - val_loss: 0.0932 - val_categorical_crossentropy: 0.0932 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4327 - val_dice_coefficient: 0.8819 - val_auc: 0.9906
# Epoch 22/50
# 47/47 [==============================] - 20s 435ms/step - loss: 0.0796 - categorical_crossentropy: 0.0796 - categorical_accuracy: 0.9210 - mean_iou: 0.4295 - dice_coefficient: 0.8825 - auc: 0.9827 - val_loss: 0.1004 - val_categorical_crossentropy: 0.1004 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4300 - val_dice_coefficient: 0.8757 - val_auc: 0.9906
# Epoch 23/50
# 47/47 [==============================] - 20s 435ms/step - loss: 0.0824 - categorical_crossentropy: 0.0824 - categorical_accuracy: 0.9210 - mean_iou: 0.4286 - dice_coefficient: 0.8802 - auc: 0.9827 - val_loss: 0.0954 - val_categorical_crossentropy: 0.0954 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4320 - val_dice_coefficient: 0.8802 - val_auc: 0.9906
# Epoch 24/50
# 47/47 [==============================] - 20s 435ms/step - loss: 0.0829 - categorical_crossentropy: 0.0829 - categorical_accuracy: 0.9210 - mean_iou: 0.4283 - dice_coefficient: 0.8797 - auc: 0.9830 - val_loss: 0.0872 - val_categorical_crossentropy: 0.0872 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4354 - val_dice_coefficient: 0.8875 - val_auc: 0.9906
# Epoch 25/50
# 47/47 [==============================] - 20s 435ms/step - loss: 0.0789 - categorical_crossentropy: 0.0789 - categorical_accuracy: 0.9210 - mean_iou: 0.4300 - dice_coefficient: 0.8833 - auc: 0.9834 - val_loss: 0.0907 - val_categorical_crossentropy: 0.0907 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4341 - val_dice_coefficient: 0.8847 - val_auc: 0.9906
# Epoch 26/50
# 47/47 [==============================] - 20s 435ms/step - loss: 0.0808 - categorical_crossentropy: 0.0808 - categorical_accuracy: 0.9210 - mean_iou: 0.4294 - dice_coefficient: 0.8817 - auc: 0.9834 - val_loss: 0.0880 - val_categorical_crossentropy: 0.0880 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4353 - val_dice_coefficient: 0.8871 - val_auc: 0.9907
# Epoch 27/50
# 47/47 [==============================] - 20s 435ms/step - loss: 0.0784 - categorical_crossentropy: 0.0784 - categorical_accuracy: 0.9210 - mean_iou: 0.4304 - dice_coefficient: 0.8839 - auc: 0.9838 - val_loss: 0.0905 - val_categorical_crossentropy: 0.0905 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4344 - val_dice_coefficient: 0.8850 - val_auc: 0.9906
# Epoch 28/50
# 47/47 [==============================] - 20s 436ms/step - loss: 0.0805 - categorical_crossentropy: 0.0805 - categorical_accuracy: 0.9210 - mean_iou: 0.4296 - dice_coefficient: 0.8820 - auc: 0.9839 - val_loss: 0.0866 - val_categorical_crossentropy: 0.0866 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4360 - val_dice_coefficient: 0.8884 - val_auc: 0.9907
# Epoch 29/50
# 47/47 [==============================] - 21s 437ms/step - loss: 0.0772 - categorical_crossentropy: 0.0772 - categorical_accuracy: 0.9210 - mean_iou: 0.4310 - dice_coefficient: 0.8850 - auc: 0.9841 - val_loss: 0.0875 - val_categorical_crossentropy: 0.0875 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4357 - val_dice_coefficient: 0.8878 - val_auc: 0.9907
# Epoch 30/50
# 47/47 [==============================] - 21s 437ms/step - loss: 0.0781 - categorical_crossentropy: 0.0781 - categorical_accuracy: 0.9210 - mean_iou: 0.4307 - dice_coefficient: 0.8842 - auc: 0.9841 - val_loss: 0.0872 - val_categorical_crossentropy: 0.0872 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4359 - val_dice_coefficient: 0.8880 - val_auc: 0.9908
# Epoch 31/50
# 47/47 [==============================] - 20s 437ms/step - loss: 0.0771 - categorical_crossentropy: 0.0771 - categorical_accuracy: 0.9210 - mean_iou: 0.4311 - dice_coefficient: 0.8851 - auc: 0.9844 - val_loss: 0.0870 - val_categorical_crossentropy: 0.0870 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4360 - val_dice_coefficient: 0.8883 - val_auc: 0.9908
# Epoch 32/50
# 47/47 [==============================] - 20s 437ms/step - loss: 0.0775 - categorical_crossentropy: 0.0775 - categorical_accuracy: 0.9210 - mean_iou: 0.4310 - dice_coefficient: 0.8848 - auc: 0.9845 - val_loss: 0.0873 - val_categorical_crossentropy: 0.0873 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4359 - val_dice_coefficient: 0.8880 - val_auc: 0.9909
# Epoch 33/50
# 47/47 [==============================] - 21s 437ms/step - loss: 0.0760 - categorical_crossentropy: 0.0760 - categorical_accuracy: 0.9210 - mean_iou: 0.4317 - dice_coefficient: 0.8862 - auc: 0.9847 - val_loss: 0.0877 - val_categorical_crossentropy: 0.0877 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4358 - val_dice_coefficient: 0.8877 - val_auc: 0.9909
# Epoch 34/50
# 47/47 [==============================] - 20s 437ms/step - loss: 0.0766 - categorical_crossentropy: 0.0766 - categorical_accuracy: 0.9210 - mean_iou: 0.4315 - dice_coefficient: 0.8856 - auc: 0.9848 - val_loss: 0.0880 - val_categorical_crossentropy: 0.0880 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4357 - val_dice_coefficient: 0.8874 - val_auc: 0.9910
# Epoch 35/50
# 47/47 [==============================] - 20s 437ms/step - loss: 0.0749 - categorical_crossentropy: 0.0749 - categorical_accuracy: 0.9210 - mean_iou: 0.4322 - dice_coefficient: 0.8871 - auc: 0.9850 - val_loss: 0.0888 - val_categorical_crossentropy: 0.0888 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4355 - val_dice_coefficient: 0.8869 - val_auc: 0.9910
# Epoch 36/50
# 47/47 [==============================] - 20s 437ms/step - loss: 0.0766 - categorical_crossentropy: 0.0766 - categorical_accuracy: 0.9210 - mean_iou: 0.4316 - dice_coefficient: 0.8857 - auc: 0.9851 - val_loss: 0.0904 - val_categorical_crossentropy: 0.0904 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4349 - val_dice_coefficient: 0.8854 - val_auc: 0.9911
# Epoch 37/50
# 47/47 [==============================] - 20s 437ms/step - loss: 0.0742 - categorical_crossentropy: 0.0742 - categorical_accuracy: 0.9210 - mean_iou: 0.4327 - dice_coefficient: 0.8878 - auc: 0.9855 - val_loss: 0.0893 - val_categorical_crossentropy: 0.0893 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4354 - val_dice_coefficient: 0.8865 - val_auc: 0.9912
# Epoch 38/50
# 47/47 [==============================] - 20s 437ms/step - loss: 0.0765 - categorical_crossentropy: 0.0765 - categorical_accuracy: 0.9210 - mean_iou: 0.4318 - dice_coefficient: 0.8859 - auc: 0.9854 - val_loss: 0.0922 - val_categorical_crossentropy: 0.0922 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4343 - val_dice_coefficient: 0.8839 - val_auc: 0.9912
# Epoch 39/50
# 47/47 [==============================] - 20s 437ms/step - loss: 0.0766 - categorical_crossentropy: 0.0766 - categorical_accuracy: 0.9210 - mean_iou: 0.4318 - dice_coefficient: 0.8858 - auc: 0.9855 - val_loss: 0.0935 - val_categorical_crossentropy: 0.0935 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4338 - val_dice_coefficient: 0.8828 - val_auc: 0.9913
# Epoch 40/50
# 47/47 [==============================] - 20s 437ms/step - loss: 0.0767 - categorical_crossentropy: 0.0767 - categorical_accuracy: 0.9210 - mean_iou: 0.4318 - dice_coefficient: 0.8857 - auc: 0.9856 - val_loss: 0.0958 - val_categorical_crossentropy: 0.0958 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4329 - val_dice_coefficient: 0.8807 - val_auc: 0.9913
# Epoch 41/50
# 47/47 [==============================] - 20s 437ms/step - loss: 0.0775 - categorical_crossentropy: 0.0775 - categorical_accuracy: 0.9210 - mean_iou: 0.4315 - dice_coefficient: 0.8850 - auc: 0.9857 - val_loss: 0.0968 - val_categorical_crossentropy: 0.0968 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4325 - val_dice_coefficient: 0.8798 - val_auc: 0.9914
# Epoch 42/50
# 47/47 [==============================] - 20s 437ms/step - loss: 0.0779 - categorical_crossentropy: 0.0779 - categorical_accuracy: 0.9210 - mean_iou: 0.4314 - dice_coefficient: 0.8847 - auc: 0.9859 - val_loss: 0.0987 - val_categorical_crossentropy: 0.0987 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4318 - val_dice_coefficient: 0.8781 - val_auc: 0.9914
# Epoch 43/50
# 47/47 [==============================] - 21s 438ms/step - loss: 0.0789 - categorical_crossentropy: 0.0789 - categorical_accuracy: 0.9210 - mean_iou: 0.4311 - dice_coefficient: 0.8839 - auc: 0.9860 - val_loss: 0.0994 - val_categorical_crossentropy: 0.0994 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4316 - val_dice_coefficient: 0.8776 - val_auc: 0.9915
# Epoch 44/50
# 47/47 [==============================] - 21s 437ms/step - loss: 0.0796 - categorical_crossentropy: 0.0796 - categorical_accuracy: 0.9210 - mean_iou: 0.4309 - dice_coefficient: 0.8833 - auc: 0.9862 - val_loss: 0.0998 - val_categorical_crossentropy: 0.0998 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4314 - val_dice_coefficient: 0.8773 - val_auc: 0.9915
# Epoch 45/50
# 47/47 [==============================] - 21s 437ms/step - loss: 0.0801 - categorical_crossentropy: 0.0801 - categorical_accuracy: 0.9210 - mean_iou: 0.4308 - dice_coefficient: 0.8828 - auc: 0.9864 - val_loss: 0.0989 - val_categorical_crossentropy: 0.0989 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4318 - val_dice_coefficient: 0.8780 - val_auc: 0.9915
# Epoch 46/50
# 47/47 [==============================] - 20s 437ms/step - loss: 0.0808 - categorical_crossentropy: 0.0808 - categorical_accuracy: 0.9210 - mean_iou: 0.4306 - dice_coefficient: 0.8822 - auc: 0.9865 - val_loss: 0.0975 - val_categorical_crossentropy: 0.0975 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4324 - val_dice_coefficient: 0.8793 - val_auc: 0.9915
# Epoch 47/50
# 47/47 [==============================] - 20s 437ms/step - loss: 0.0806 - categorical_crossentropy: 0.0806 - categorical_accuracy: 0.9210 - mean_iou: 0.4308 - dice_coefficient: 0.8824 - auc: 0.9867 - val_loss: 0.0964 - val_categorical_crossentropy: 0.0964 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4329 - val_dice_coefficient: 0.8803 - val_auc: 0.9916
# Epoch 48/50
# 47/47 [==============================] - 20s 437ms/step - loss: 0.0786 - categorical_crossentropy: 0.0786 - categorical_accuracy: 0.9210 - mean_iou: 0.4316 - dice_coefficient: 0.8841 - auc: 0.9868 - val_loss: 0.0972 - val_categorical_crossentropy: 0.0972 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4326 - val_dice_coefficient: 0.8796 - val_auc: 0.9916
# Epoch 49/50
# 47/47 [==============================] - 20s 437ms/step - loss: 0.0780 - categorical_crossentropy: 0.0780 - categorical_accuracy: 0.9210 - mean_iou: 0.4320 - dice_coefficient: 0.8847 - auc: 0.9871 - val_loss: 0.0964 - val_categorical_crossentropy: 0.0964 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4330 - val_dice_coefficient: 0.8804 - val_auc: 0.9916
# Epoch 50/50
# 47/47 [==============================] - 21s 437ms/step - loss: 0.0757 - categorical_crossentropy: 0.0757 - categorical_accuracy: 0.9210 - mean_iou: 0.4330 - dice_coefficient: 0.8867 - auc: 0.9874 - val_loss: 0.0942 - val_categorical_crossentropy: 0.0942 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4339 - val_dice_coefficient: 0.8822 - val_auc: 0.9916

# %% [markdown]
# # **Task 4**: Let's predict mitochondria in the testing data! [15 Points]

# %%
# After training, let's try the U-Net on our testing data.
#
# The code below displays the first 10 input images, the original masks by experts, 
# and the predicted masks from the U-Net.

# %%
rows = 10
fig, axs = plt.subplots(rows, 3, figsize=(8, 30))
for ax, (image, label) in zip(axs, test.take(rows).batch(1)):
  
  prediction = unet_model.predict(image)
  ax[0].matshow(image[0, :, :, 0])
  ax[1].matshow(label[0, :, :, 1], cmap="gray")
  ax[2].matshow(prediction[0].argmax(axis=-1), cmap="gray")

# %%
# 1) Question
# TODO: Why do we use the prediction[0].argmax(axis=-1) command
# to display the prediction?
# 
# TODO: YOUR ANSWER

# %% [markdown]
# prediction[0].argmax() will give the index of the maximum value in the specified axis. argmax() is used in order to understand which is the class that the network predicted for that input.

# %%
# 2) Question
# TODO: Is the quality of the segmentation good and how could we improve it?
# Hint: Think along the lines of some traditional image processing rather than
# increasing the training data size.
#
# TODO: YOUR ANSWER

# %% [markdown]
# That quality of the segmentation is not good because it is difficult to see mitochondria clearly. We can improve it by increasing the intensity of the output.

# %% [markdown]
# # **Bonus**: Compare against the state-of-the-art literature! [33 Points]

# %%
# The following paper also uses a 2D U-Net to detect mitochondria:
# 
# https://danielhaehn.com/papers/?casser2020fast

# %%
# 1) Question
#
# TODO: How many learnable parameters does your trained unet_model have?
# Hint: You can use TF's Model Summary function to answer this.

unet_model.summary()
# Out:
# Model: "unet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# inputs (InputLayer)             [(None, None, None,  0
# __________________________________________________________________________________________________
# conv_block (ConvBlock)          (None, None, None, 6 37568       inputs[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, None, None, 6 0           conv_block[0][0]
# __________________________________________________________________________________________________
# conv_block_1 (ConvBlock)        (None, None, None, 1 221440      max_pooling2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, None, None, 1 0           conv_block_1[0][0]
# __________________________________________________________________________________________________
# conv_block_2 (ConvBlock)        (None, None, None, 2 885248      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, None, None, 2 0           conv_block_2[0][0]
# __________________________________________________________________________________________________
# conv_block_3 (ConvBlock)        (None, None, None, 5 3539968     max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, None, None, 5 0           conv_block_3[0][0]
# __________________________________________________________________________________________________
# conv_block_4 (ConvBlock)        (None, None, None, 1 14157824    max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# upconv_block (UpconvBlock)      (None, None, None, 5 2097664     conv_block_4[0][0]
# __________________________________________________________________________________________________
# crop_concat_block (CropConcatBl (None, None, None, 1 0           upconv_block[0][0]
#                                                                  conv_block_3[0][0]
# __________________________________________________________________________________________________
# conv_block_5 (ConvBlock)        (None, None, None, 5 7078912     crop_concat_block[0][0]
# __________________________________________________________________________________________________
# upconv_block_1 (UpconvBlock)    (None, None, None, 2 524544      conv_block_5[0][0]
# __________________________________________________________________________________________________
# crop_concat_block_1 (CropConcat (None, None, None, 5 0           upconv_block_1[0][0]
#                                                                  conv_block_2[0][0]
# __________________________________________________________________________________________________
# conv_block_6 (ConvBlock)        (None, None, None, 2 1769984     crop_concat_block_1[0][0]
# __________________________________________________________________________________________________
# upconv_block_2 (UpconvBlock)    (None, None, None, 1 131200      conv_block_6[0][0]
# __________________________________________________________________________________________________
# crop_concat_block_2 (CropConcat (None, None, None, 2 0           upconv_block_2[0][0]
#                                                                  conv_block_1[0][0]
# __________________________________________________________________________________________________
# conv_block_7 (ConvBlock)        (None, None, None, 1 442624      crop_concat_block_2[0][0]
# __________________________________________________________________________________________________
# upconv_block_3 (UpconvBlock)    (None, None, None, 6 32832       conv_block_7[0][0]
# __________________________________________________________________________________________________
# crop_concat_block_3 (CropConcat (None, None, None, 1 0           upconv_block_3[0][0]
#                                                                  conv_block[0][0]
# __________________________________________________________________________________________________
# conv_block_8 (ConvBlock)        (None, None, None, 6 110720      crop_concat_block_3[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, None, None, 2 130         conv_block_8[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, None, None, 2 0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# outputs (Activation)            (None, None, None, 2 0           activation_22[0][0]
# ==================================================================================================
# Total params: 31,030,658
# Trainable params: 31,030,658
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# There are 31,030,658 learnable parameters in the trained unet_model!

# %%
# 2) Question
#
# TODO: How many parameters do Casser et al. use?
#

# %% [markdown]
# Casser et al. uses 1,958,533 parameters.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 3) Question
#
# TODO: How did Casser et al. reduce the parameters?
#

# %% [markdown]
# Based on experimental evaluation, Casser et al. was able to decrease the number of parameters compared to the original U-Net architecture.
#
# First, the number of convolutional filters throughout the network was reduced. They then replace transpose convolutions in the decoder with light-weight bilinear upsampling layers that require no parameters.
#
# For the encoder, they reach a parameter reduction of 94%, from 19,505,856 to 1,178,480.
#
# For the decoder, we reach a 93.6% reduction (from 12,188,545 to 780,053).

# %%
# 4) Question
#
# TODO: Why did Casser et al. reduce the parameters?
#

# %% [markdown]
# To increases the throughput by an additional 40%.

# %%
#
# You made it!!
#
#                 _ ___                /^^\ /^\  /^^\_
#     _          _@)@) \            ,,/ '` ~ `'~~ ', `\.
#   _/o\_ _ _ _/~`.`...'~\        ./~~..,'`','',.,' '  ~:
#  / `,'.~,~.~  .   , . , ~|,   ,/ .,' , ,. .. ,,.   `,  ~\_
# ( ' _' _ '_` _  '  .    , `\_/ .' ..' '  `  `   `..  `,   \_
#  ~V~ V~ V~ V~ ~\ `   ' .  '    , ' .,.,''`.,.''`.,.``. ',   \_
#   _/\ /\ /\ /\_/, . ' ,   `_/~\_ .' .,. ,, , _/~\_ `. `. '.,  \_
#  < ~ ~ '~`'~'`, .,  .   `_: ::: \_ '      `_/ ::: \_ `.,' . ',  \_
#   \ ' `_  '`_    _    ',/ _::_::_ \ _    _/ _::_::_ \   `.,'.,`., \-,-,-,_,_,
#    `'~~ `'~~ `'~~ `'~~  \(_)(_)(_)/  `~~' \(_)(_)(_)/ ~'`\_.._,._,'_;_;_;_;_;
#
