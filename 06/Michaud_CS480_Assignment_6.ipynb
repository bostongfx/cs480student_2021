# %% [markdown]
# <a href="https://colab.research.google.com/github/JamesEdMichaud/cs480student/blob/main/06/Michaud_CS480_Assignment_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![CS480_w.png](data:image/png;base64,...)
# #Assignment 6

# %%
# In this assignment, we will train a U-Net classifer to detect mitochondria
# in electron microscopy images!

# %%
### IMPORTANT ###
#
# Activate GPU support: Runtime -> Change Runtime Type
# Hardware Accelerator: GPU
#
### IMPORTANT ###

# %%
# load numpy and matplotlib
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /usr/local/lib/python3.7/dist-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['test']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
# load the unet tensorflow code
# !pip install git+https://github.com/jakeret/unet.git
# Out:
# Collecting git+https://github.com/jakeret/unet.git
#   Cloning https://github.com/jakeret/unet.git to /tmp/pip-req-build-v1_kcpxu
#   Running command git clone -q https://github.com/jakeret/unet.git /tmp/pip-req-build-v1_kcpxu
# Requirement already satisfied (use --upgrade to upgrade): unet==0.0.post0.dev81+gf557a51 from git+https://github.com/jakeret/unet.git in /usr/local/lib/python3.7/dist-packages
# Building wheels for collected packages: unet
#   Building wheel for unet (setup.py) ... done
#   Created wheel for unet: filename=unet-0.0.post0.dev81+gf557a51-py2.py3-none-any.whl size=25658 sha256=db201ea04805407bb472c48d6c2debaf3f0cb43d414f4159725638bc495b343b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ucookkdb/wheels/f5/38/c8/8f0a157cfd7616cc1a24811a52b9a669c0ee8fccc9f99d3cbc
# Successfully built unet

# %%
# .. and use it!
# Note: There are a ton of U-Net implementations but this one is easier to use!
import unet

# %% [markdown]
# **Task 1**: Study the unet circle example and learn about mitochondria! [15 Points]

# %%
# The unet package allows to train a U-Net classifier with little code.
# As discussed in class, the U-Net can be used to label/segment/annotate images.

# %%
# TODO: Please study the Circles example 
# https://github.com/jakeret/unet/blob/master/notebooks/circles.ipynb

# %%
# TODO: ... and look how the (artificial) dataset is generated
# https://github.com/jakeret/unet/blob/master/src/unet/datasets/circles.py

# %%
# 1) Question
# TODO: Please describe what the U-Net is trained to do.
#
# TODO: YOUR ANSWER
# Create a segmentation mask for noisy input images.

# %%
# 2) Question
# TODO: In circles.py, what does the following mean:
#     channels = 1
#     classes = 2
#
# TODO: YOUR ANSWER
# That the image should be treated as single-channel (grayscale?), and that
# there are two classifications for the data (background and not-background).

# %%
# 3) Question
# TODO: What are mitochondria and what is their appearance in
# electron microscopy data?
# Hint: You can validate your answer in Task 4!
#
# TODO: YOUR ANSWER
#
# The powerhouses of our cells! They produce most of the chemical energy needed
# to power reactions in our cells. They appear as irregular ovoid segments,
# often darker than their surrounding tissue and sometimes with a bit of a
# border (cell wall?).

# %% [markdown]
# **Task 2**: Setup a datagenerator for mitochondria images! [45 Points]

# %%
# TODO: 
# Download https://cs480.org/data/mito.npz to your computer.
# Then, please upload mito.npz using the file panel on the left.

# %%
# The code below is similar to the circles.py file from Task 1.
# We follow Tensorflow conventions to design a tf.data.Dataset for training
# the U-Net.
#
# TODO: Please add four different data augmentation methods in the code block
# below. (image normalization to 0..1, horizontal data flip, vertical data flip,
# rotation by 90 degrees)
#
# Hint: https://github.com/jakeret/unet/blob/master/src/unet/datasets/oxford_iiit_pet.py#L25

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow_datasets.core import DatasetInfo
from typing import Tuple, List

IMAGE_SIZE = (256, 256)
channels = 1
classes = 2

def load_data(count:int, splits:Tuple[float]=(0.7, 0.2, 0.1), **kwargs) -> List[tf.data.Dataset]:
    return [tf.data.Dataset.from_tensor_slices(_build_samples(int(split * count), **kwargs))
            for split in splits]


def _build_samples(sample_count:int, **kwargs) -> Tuple[np.array, np.array]:

    # here we load the mitochondria data
    loaded = np.load('mito.npz')
    loadedimages = loaded['arr_0'][0].copy()
    loadedmasks = loaded['arr_0'][1].copy()

    # now let's go to numpyland
    images = np.empty((sample_count, IMAGE_SIZE[0], IMAGE_SIZE[1], 1))
    labels = np.empty((sample_count, IMAGE_SIZE[0], IMAGE_SIZE[1], 2))
    for i in range(sample_count):
        image, mask = loadedimages[i], loadedmasks[i]

        image = image.reshape((IMAGE_SIZE[0], IMAGE_SIZE[1], 1)).astype(np.float)
        mask = mask.reshape((IMAGE_SIZE[0], IMAGE_SIZE[1], 1))

        #
        # TODO: Normalize the image to 0..1
        #
        # TODO: YOUR CODE
        max = image.max()
        image /= max
        # mask[mask != 0] = 1

        #
        # TODO: Use Tensorflow to flip the image horizontally
        #
        if tf.random.uniform(()) > 0.5:
            #
            # TODO: YOUR CODE
            #
            image = tf.image.flip_left_right(image)
            mask  = tf.image.flip_left_right(mask)

        #
        # TODO: Use Tensorflow to flip the image vertically
        #
        if tf.random.uniform(()) > 0.5:
            #
            # TODO: YOUR CODE
            #
            image = tf.image.flip_up_down(image)
            mask  = tf.image.flip_up_down(mask)

        #
        # TODO: Use Tensorflow to rotate the image 90 degrees
        #
        if tf.random.uniform(()) > 0.5:
            #
            # TODO: YOUR CODE
            #
            image = tf.image.rot90(image)
            mask  = tf.image.rot90(mask)


        # augmentation done, let's store the image
        images[i] = image

        # here we split the mask to background and foreground
        fg = np.zeros((IMAGE_SIZE[0], IMAGE_SIZE[1], 1), dtype=np.bool)
        fg[mask == 255] = 1
        bg = np.zeros((IMAGE_SIZE[0], IMAGE_SIZE[1], 1), dtype=np.bool)
        bg[mask == 0] = 1
        
        labels[i, :, :, 0] = bg[:,:,0]
        labels[i, :, :, 1] = fg[:,:,0]

    return images, labels

# %% [markdown]
# **Task 3**: Let's train the U-Net! [25 Points]

# %%
#
# We can now create our training, validation, and testing data by calling
# our methods from Task 2.
#
train, val, test = load_data( 660, splits=(0.7, 0.2, 0.1) )

# %%
# 1) Question
# TODO: We have in total 660 images + 660 masks. Based on the code above,
# how many images are used for training alone?
#
# TODO: YOUR ANSWER
# 660 * 0.7 = 462 images for training

# %%
#
# Let's setup the U-Net!
#
LEARNING_RATE = 1e-3

unet_model = unet.build_model(channels=channels,
                              num_classes=classes,
                              layer_depth=5,
                              filters_root=64,
                              padding="same")

unet.finalize_model(unet_model, learning_rate=LEARNING_RATE)

# %%
#
# And, let's setup the trainer...
#
trainer = unet.Trainer(checkpoint_callback=False,
                       learning_rate_scheduler=unet.SchedulerType.WARMUP_LINEAR_DECAY,
                       warmup_proportion=0.1,
                       learning_rate=LEARNING_RATE)

# %%
#
# ...and train the U-Net for 50 epochs with a batch_size of 10!
#
# TODO: Please complete the code below.
# Hint: Don't forget to use training and validation data.
# Hint 2: This will take roughly 30 minutes!
#
trainer.fit(unet_model,
            #
            # TODO: YOUR CODE
            #
            #
            train,
            val,
            epochs=50,
            batch_size=10
            )
# Out:
# Epoch 1/50
# 47/47 [==============================] - 42s 845ms/step - loss: 0.6531 - categorical_crossentropy: 0.6531 - categorical_accuracy: 0.6478 - mean_iou: 0.2936 - dice_coefficient: 0.5354 - auc_4: 0.5881 - val_loss: 0.3570 - val_categorical_crossentropy: 0.3570 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3814 - val_dice_coefficient: 0.7114 - val_auc_4: 0.9849
# Epoch 2/50
# 47/47 [==============================] - 39s 832ms/step - loss: 0.2907 - categorical_crossentropy: 0.2907 - categorical_accuracy: 0.9209 - mean_iou: 0.4544 - dice_coefficient: 0.8611 - auc_4: 0.9423 - val_loss: 0.2939 - val_categorical_crossentropy: 0.2939 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4093 - val_dice_coefficient: 0.7645 - val_auc_4: 0.9840
# Epoch 3/50
# 47/47 [==============================] - 39s 834ms/step - loss: 0.2690 - categorical_crossentropy: 0.2690 - categorical_accuracy: 0.9210 - mean_iou: 0.4574 - dice_coefficient: 0.8647 - auc_4: 0.9483 - val_loss: 0.2662 - val_categorical_crossentropy: 0.2662 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4231 - val_dice_coefficient: 0.7897 - val_auc_4: 0.9834
# Epoch 4/50
# 47/47 [==============================] - 39s 830ms/step - loss: 0.2815 - categorical_crossentropy: 0.2815 - categorical_accuracy: 0.9210 - mean_iou: 0.4502 - dice_coefficient: 0.8479 - auc_4: 0.9442 - val_loss: 0.2382 - val_categorical_crossentropy: 0.2382 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4378 - val_dice_coefficient: 0.8178 - val_auc_4: 0.9836
# Epoch 5/50
# 47/47 [==============================] - 39s 833ms/step - loss: 0.2748 - categorical_crossentropy: 0.2748 - categorical_accuracy: 0.9210 - mean_iou: 0.4522 - dice_coefficient: 0.8498 - auc_4: 0.9457 - val_loss: 0.2223 - val_categorical_crossentropy: 0.2223 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4468 - val_dice_coefficient: 0.8344 - val_auc_4: 0.9839
# Epoch 6/50
# 47/47 [==============================] - 39s 832ms/step - loss: 0.2657 - categorical_crossentropy: 0.2657 - categorical_accuracy: 0.9210 - mean_iou: 0.4563 - dice_coefficient: 0.8566 - auc_4: 0.9495 - val_loss: 0.2216 - val_categorical_crossentropy: 0.2216 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4475 - val_dice_coefficient: 0.8342 - val_auc_4: 0.9837
# Epoch 7/50
# 47/47 [==============================] - 39s 831ms/step - loss: 0.2684 - categorical_crossentropy: 0.2684 - categorical_accuracy: 0.9210 - mean_iou: 0.4563 - dice_coefficient: 0.8567 - auc_4: 0.9489 - val_loss: 0.2143 - val_categorical_crossentropy: 0.2143 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4519 - val_dice_coefficient: 0.8415 - val_auc_4: 0.9841
# Epoch 8/50
# 47/47 [==============================] - 39s 832ms/step - loss: 0.2598 - categorical_crossentropy: 0.2598 - categorical_accuracy: 0.9210 - mean_iou: 0.4579 - dice_coefficient: 0.8557 - auc_4: 0.9516 - val_loss: 0.1968 - val_categorical_crossentropy: 0.1968 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4631 - val_dice_coefficient: 0.8604 - val_auc_4: 0.9845
# Epoch 9/50
# 47/47 [==============================] - 39s 833ms/step - loss: 0.2488 - categorical_crossentropy: 0.2488 - categorical_accuracy: 0.9210 - mean_iou: 0.4625 - dice_coefficient: 0.8590 - auc_4: 0.9566 - val_loss: 0.1985 - val_categorical_crossentropy: 0.1985 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4636 - val_dice_coefficient: 0.8538 - val_auc_4: 0.9848
# Epoch 10/50
# 47/47 [==============================] - 39s 833ms/step - loss: 0.2439 - categorical_crossentropy: 0.2439 - categorical_accuracy: 0.9210 - mean_iou: 0.4660 - dice_coefficient: 0.8605 - auc_4: 0.9596 - val_loss: 0.1998 - val_categorical_crossentropy: 0.1998 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4648 - val_dice_coefficient: 0.8491 - val_auc_4: 0.9851
# Epoch 11/50
# 47/47 [==============================] - 39s 834ms/step - loss: 0.2394 - categorical_crossentropy: 0.2394 - categorical_accuracy: 0.9210 - mean_iou: 0.4693 - dice_coefficient: 0.8620 - auc_4: 0.9621 - val_loss: 0.1978 - val_categorical_crossentropy: 0.1978 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4680 - val_dice_coefficient: 0.8494 - val_auc_4: 0.9853
# Epoch 12/50
# 47/47 [==============================] - 39s 834ms/step - loss: 0.2352 - categorical_crossentropy: 0.2352 - categorical_accuracy: 0.9210 - mean_iou: 0.4723 - dice_coefficient: 0.8626 - auc_4: 0.9641 - val_loss: 0.1955 - val_categorical_crossentropy: 0.1955 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4713 - val_dice_coefficient: 0.8506 - val_auc_4: 0.9855
# Epoch 13/50
# 47/47 [==============================] - 39s 835ms/step - loss: 0.2311 - categorical_crossentropy: 0.2311 - categorical_accuracy: 0.9210 - mean_iou: 0.4754 - dice_coefficient: 0.8637 - auc_4: 0.9659 - val_loss: 0.1904 - val_categorical_crossentropy: 0.1904 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4768 - val_dice_coefficient: 0.8547 - val_auc_4: 0.9856
# Epoch 14/50
# 47/47 [==============================] - 39s 834ms/step - loss: 0.2256 - categorical_crossentropy: 0.2256 - categorical_accuracy: 0.9210 - mean_iou: 0.4797 - dice_coefficient: 0.8660 - auc_4: 0.9680 - val_loss: 0.1883 - val_categorical_crossentropy: 0.1883 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4806 - val_dice_coefficient: 0.8561 - val_auc_4: 0.9858
# Epoch 15/50
# 47/47 [==============================] - 39s 837ms/step - loss: 0.2215 - categorical_crossentropy: 0.2215 - categorical_accuracy: 0.9210 - mean_iou: 0.4834 - dice_coefficient: 0.8674 - auc_4: 0.9695 - val_loss: 0.1848 - val_categorical_crossentropy: 0.1848 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4850 - val_dice_coefficient: 0.8592 - val_auc_4: 0.9859
# Epoch 16/50
# 47/47 [==============================] - 39s 835ms/step - loss: 0.2178 - categorical_crossentropy: 0.2178 - categorical_accuracy: 0.9210 - mean_iou: 0.4870 - dice_coefficient: 0.8688 - auc_4: 0.9708 - val_loss: 0.1818 - val_categorical_crossentropy: 0.1818 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4886 - val_dice_coefficient: 0.8618 - val_auc_4: 0.9860
# Epoch 17/50
# 47/47 [==============================] - 39s 837ms/step - loss: 0.2139 - categorical_crossentropy: 0.2139 - categorical_accuracy: 0.9210 - mean_iou: 0.4902 - dice_coefficient: 0.8698 - auc_4: 0.9720 - val_loss: 0.1798 - val_categorical_crossentropy: 0.1798 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4918 - val_dice_coefficient: 0.8637 - val_auc_4: 0.9862
# Epoch 18/50
# 47/47 [==============================] - 39s 836ms/step - loss: 0.2102 - categorical_crossentropy: 0.2102 - categorical_accuracy: 0.9210 - mean_iou: 0.4938 - dice_coefficient: 0.8712 - auc_4: 0.9731 - val_loss: 0.1784 - val_categorical_crossentropy: 0.1784 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4943 - val_dice_coefficient: 0.8649 - val_auc_4: 0.9863
# Epoch 19/50
# 47/47 [==============================] - 39s 835ms/step - loss: 0.2069 - categorical_crossentropy: 0.2069 - categorical_accuracy: 0.9210 - mean_iou: 0.4968 - dice_coefficient: 0.8725 - auc_4: 0.9741 - val_loss: 0.1749 - val_categorical_crossentropy: 0.1749 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4975 - val_dice_coefficient: 0.8681 - val_auc_4: 0.9866
# Epoch 20/50
# 47/47 [==============================] - 39s 835ms/step - loss: 0.1977 - categorical_crossentropy: 0.1977 - categorical_accuracy: 0.9210 - mean_iou: 0.5016 - dice_coefficient: 0.8779 - auc_4: 0.9762 - val_loss: 0.1843 - val_categorical_crossentropy: 0.1843 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4941 - val_dice_coefficient: 0.8594 - val_auc_4: 0.9868
# Epoch 21/50
# 47/47 [==============================] - 39s 835ms/step - loss: 0.2005 - categorical_crossentropy: 0.2005 - categorical_accuracy: 0.9210 - mean_iou: 0.5025 - dice_coefficient: 0.8758 - auc_4: 0.9761 - val_loss: 0.1648 - val_categorical_crossentropy: 0.1648 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.5070 - val_dice_coefficient: 0.8787 - val_auc_4: 0.9868
# Epoch 22/50
# 47/47 [==============================] - 39s 826ms/step - loss: 0.1994 - categorical_crossentropy: 0.1994 - categorical_accuracy: 0.9210 - mean_iou: 0.5060 - dice_coefficient: 0.8779 - auc_4: 0.9760 - val_loss: 0.1691 - val_categorical_crossentropy: 0.1691 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.5038 - val_dice_coefficient: 0.8737 - val_auc_4: 0.9871
# Epoch 23/50
# 47/47 [==============================] - 39s 828ms/step - loss: 0.1979 - categorical_crossentropy: 0.1979 - categorical_accuracy: 0.9210 - mean_iou: 0.5060 - dice_coefficient: 0.8762 - auc_4: 0.9766 - val_loss: 0.1650 - val_categorical_crossentropy: 0.1650 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.5068 - val_dice_coefficient: 0.8776 - val_auc_4: 0.9873
# Epoch 24/50
# 47/47 [==============================] - 39s 830ms/step - loss: 0.1941 - categorical_crossentropy: 0.1941 - categorical_accuracy: 0.9210 - mean_iou: 0.5089 - dice_coefficient: 0.8783 - auc_4: 0.9774 - val_loss: 0.1630 - val_categorical_crossentropy: 0.1630 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.5086 - val_dice_coefficient: 0.8795 - val_auc_4: 0.9876
# Epoch 25/50
# 47/47 [==============================] - 39s 833ms/step - loss: 0.1928 - categorical_crossentropy: 0.1928 - categorical_accuracy: 0.9210 - mean_iou: 0.5104 - dice_coefficient: 0.8789 - auc_4: 0.9778 - val_loss: 0.1595 - val_categorical_crossentropy: 0.1595 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.5120 - val_dice_coefficient: 0.8829 - val_auc_4: 0.9878
# Epoch 26/50
# 47/47 [==============================] - 39s 833ms/step - loss: 0.1849 - categorical_crossentropy: 0.1849 - categorical_accuracy: 0.9210 - mean_iou: 0.5169 - dice_coefficient: 0.8847 - auc_4: 0.9794 - val_loss: 0.1681 - val_categorical_crossentropy: 0.1681 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.5069 - val_dice_coefficient: 0.8740 - val_auc_4: 0.9880
# Epoch 27/50
# 47/47 [==============================] - 39s 832ms/step - loss: 0.1930 - categorical_crossentropy: 0.1930 - categorical_accuracy: 0.9210 - mean_iou: 0.5122 - dice_coefficient: 0.8773 - auc_4: 0.9781 - val_loss: 0.1509 - val_categorical_crossentropy: 0.1509 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.5192 - val_dice_coefficient: 0.8927 - val_auc_4: 0.9879
# Epoch 28/50
# 47/47 [==============================] - 39s 831ms/step - loss: 0.1856 - categorical_crossentropy: 0.1856 - categorical_accuracy: 0.9210 - mean_iou: 0.5179 - dice_coefficient: 0.8842 - auc_4: 0.9792 - val_loss: 0.1510 - val_categorical_crossentropy: 0.1510 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.5200 - val_dice_coefficient: 0.8919 - val_auc_4: 0.9881
# Epoch 29/50
# 47/47 [==============================] - 39s 833ms/step - loss: 0.1839 - categorical_crossentropy: 0.1839 - categorical_accuracy: 0.9210 - mean_iou: 0.5199 - dice_coefficient: 0.8855 - auc_4: 0.9796 - val_loss: 0.1525 - val_categorical_crossentropy: 0.1525 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.5194 - val_dice_coefficient: 0.8900 - val_auc_4: 0.9882
# Epoch 30/50
# 47/47 [==============================] - 39s 828ms/step - loss: 0.1847 - categorical_crossentropy: 0.1847 - categorical_accuracy: 0.9210 - mean_iou: 0.5199 - dice_coefficient: 0.8838 - auc_4: 0.9795 - val_loss: 0.1467 - val_categorical_crossentropy: 0.1467 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.5250 - val_dice_coefficient: 0.8974 - val_auc_4: 0.9882
# Epoch 31/50
# 47/47 [==============================] - 39s 831ms/step - loss: 0.1809 - categorical_crossentropy: 0.1809 - categorical_accuracy: 0.9210 - mean_iou: 0.5239 - dice_coefficient: 0.8878 - auc_4: 0.9801 - val_loss: 0.1490 - val_categorical_crossentropy: 0.1490 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.5262 - val_dice_coefficient: 0.8931 - val_auc_4: 0.9887
# Epoch 32/50
# 47/47 [==============================] - 39s 827ms/step - loss: 0.1753 - categorical_crossentropy: 0.1753 - categorical_accuracy: 0.9210 - mean_iou: 0.5327 - dice_coefficient: 0.8916 - auc_4: 0.9812 - val_loss: 0.1544 - val_categorical_crossentropy: 0.1544 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.5215 - val_dice_coefficient: 0.8878 - val_auc_4: 0.9884
# Epoch 33/50
# 47/47 [==============================] - 39s 822ms/step - loss: 0.1832 - categorical_crossentropy: 0.1832 - categorical_accuracy: 0.9210 - mean_iou: 0.5232 - dice_coefficient: 0.8832 - auc_4: 0.9800 - val_loss: 0.1437 - val_categorical_crossentropy: 0.1437 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.5311 - val_dice_coefficient: 0.9018 - val_auc_4: 0.9883
# Epoch 34/50
# 47/47 [==============================] - 39s 823ms/step - loss: 0.1790 - categorical_crossentropy: 0.1790 - categorical_accuracy: 0.9210 - mean_iou: 0.5284 - dice_coefficient: 0.8895 - auc_4: 0.9803 - val_loss: 0.1435 - val_categorical_crossentropy: 0.1435 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.5330 - val_dice_coefficient: 0.9018 - val_auc_4: 0.9884
# Epoch 35/50
# 47/47 [==============================] - 39s 828ms/step - loss: 0.1781 - categorical_crossentropy: 0.1781 - categorical_accuracy: 0.9210 - mean_iou: 0.5301 - dice_coefficient: 0.8901 - auc_4: 0.9805 - val_loss: 0.1407 - val_categorical_crossentropy: 0.1407 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.5368 - val_dice_coefficient: 0.9041 - val_auc_4: 0.9887
# Epoch 36/50
# 47/47 [==============================] - 39s 828ms/step - loss: 0.1699 - categorical_crossentropy: 0.1699 - categorical_accuracy: 0.9211 - mean_iou: 0.5399 - dice_coefficient: 0.8967 - auc_4: 0.9820 - val_loss: 0.1465 - val_categorical_crossentropy: 0.1465 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.5320 - val_dice_coefficient: 0.8968 - val_auc_4: 0.9886
# Epoch 37/50
# 47/47 [==============================] - 39s 832ms/step - loss: 0.1724 - categorical_crossentropy: 0.1724 - categorical_accuracy: 0.9211 - mean_iou: 0.5358 - dice_coefficient: 0.8915 - auc_4: 0.9818 - val_loss: 0.1229 - val_categorical_crossentropy: 0.1229 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.5625 - val_dice_coefficient: 0.9137 - val_auc_4: 0.9911
# Epoch 38/50
# 47/47 [==============================] - 39s 832ms/step - loss: 0.1346 - categorical_crossentropy: 0.1346 - categorical_accuracy: 0.9213 - mean_iou: 0.5930 - dice_coefficient: 0.9190 - auc_4: 0.9875 - val_loss: 0.1209 - val_categorical_crossentropy: 0.1209 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.5665 - val_dice_coefficient: 0.9120 - val_auc_4: 0.9914
# Epoch 39/50
# 47/47 [==============================] - 39s 831ms/step - loss: 0.1275 - categorical_crossentropy: 0.1275 - categorical_accuracy: 0.9217 - mean_iou: 0.6026 - dice_coefficient: 0.9226 - auc_4: 0.9886 - val_loss: 0.1236 - val_categorical_crossentropy: 0.1236 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.5637 - val_dice_coefficient: 0.9088 - val_auc_4: 0.9911
# Epoch 40/50
# 47/47 [==============================] - 39s 831ms/step - loss: 0.1251 - categorical_crossentropy: 0.1251 - categorical_accuracy: 0.9228 - mean_iou: 0.6035 - dice_coefficient: 0.9230 - auc_4: 0.9891 - val_loss: 0.1184 - val_categorical_crossentropy: 0.1184 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.5707 - val_dice_coefficient: 0.9134 - val_auc_4: 0.9913
# Epoch 41/50
# 47/47 [==============================] - 39s 829ms/step - loss: 0.1272 - categorical_crossentropy: 0.1272 - categorical_accuracy: 0.9297 - mean_iou: 0.6020 - dice_coefficient: 0.9209 - auc_4: 0.9892 - val_loss: 0.1139 - val_categorical_crossentropy: 0.1139 - val_categorical_accuracy: 0.9355 - val_mean_iou: 0.5833 - val_dice_coefficient: 0.9181 - val_auc_4: 0.9910
# Epoch 42/50
# 47/47 [==============================] - 39s 827ms/step - loss: 0.1264 - categorical_crossentropy: 0.1264 - categorical_accuracy: 0.9452 - mean_iou: 0.6114 - dice_coefficient: 0.9215 - auc_4: 0.9898 - val_loss: 0.1182 - val_categorical_crossentropy: 0.1182 - val_categorical_accuracy: 0.9297 - val_mean_iou: 0.5942 - val_dice_coefficient: 0.9176 - val_auc_4: 0.9901
# Epoch 43/50
# 47/47 [==============================] - 39s 824ms/step - loss: 0.1302 - categorical_crossentropy: 0.1302 - categorical_accuracy: 0.9441 - mean_iou: 0.6202 - dice_coefficient: 0.9214 - auc_4: 0.9890 - val_loss: 0.1299 - val_categorical_crossentropy: 0.1299 - val_categorical_accuracy: 0.9217 - val_mean_iou: 0.5873 - val_dice_coefficient: 0.9100 - val_auc_4: 0.9882
# Epoch 44/50
# 47/47 [==============================] - 39s 826ms/step - loss: 0.1153 - categorical_crossentropy: 0.1153 - categorical_accuracy: 0.9521 - mean_iou: 0.6406 - dice_coefficient: 0.9293 - auc_4: 0.9914 - val_loss: 0.1213 - val_categorical_crossentropy: 0.1213 - val_categorical_accuracy: 0.9303 - val_mean_iou: 0.6099 - val_dice_coefficient: 0.9186 - val_auc_4: 0.9902
# Epoch 45/50
# 47/47 [==============================] - 39s 826ms/step - loss: 0.1046 - categorical_crossentropy: 0.1046 - categorical_accuracy: 0.9585 - mean_iou: 0.6655 - dice_coefficient: 0.9368 - auc_4: 0.9928 - val_loss: 0.1265 - val_categorical_crossentropy: 0.1265 - val_categorical_accuracy: 0.9291 - val_mean_iou: 0.6175 - val_dice_coefficient: 0.9185 - val_auc_4: 0.9898
# Epoch 46/50
# 47/47 [==============================] - 39s 824ms/step - loss: 0.0947 - categorical_crossentropy: 0.0947 - categorical_accuracy: 0.9641 - mean_iou: 0.6885 - dice_coefficient: 0.9429 - auc_4: 0.9941 - val_loss: 0.1168 - val_categorical_crossentropy: 0.1168 - val_categorical_accuracy: 0.9391 - val_mean_iou: 0.6379 - val_dice_coefficient: 0.9268 - val_auc_4: 0.9918
# Epoch 47/50
# 47/47 [==============================] - 39s 824ms/step - loss: 0.0857 - categorical_crossentropy: 0.0857 - categorical_accuracy: 0.9687 - mean_iou: 0.7074 - dice_coefficient: 0.9480 - auc_4: 0.9951 - val_loss: 0.1025 - val_categorical_crossentropy: 0.1025 - val_categorical_accuracy: 0.9505 - val_mean_iou: 0.6623 - val_dice_coefficient: 0.9369 - val_auc_4: 0.9938
# Epoch 48/50
# 47/47 [==============================] - 39s 822ms/step - loss: 0.0793 - categorical_crossentropy: 0.0793 - categorical_accuracy: 0.9716 - mean_iou: 0.7217 - dice_coefficient: 0.9518 - auc_4: 0.9958 - val_loss: 0.0968 - val_categorical_crossentropy: 0.0968 - val_categorical_accuracy: 0.9549 - val_mean_iou: 0.6748 - val_dice_coefficient: 0.9414 - val_auc_4: 0.9944
# Epoch 49/50
# 47/47 [==============================] - 39s 823ms/step - loss: 0.0769 - categorical_crossentropy: 0.0769 - categorical_accuracy: 0.9723 - mean_iou: 0.7278 - dice_coefficient: 0.9537 - auc_4: 0.9960 - val_loss: 0.0960 - val_categorical_crossentropy: 0.0960 - val_categorical_accuracy: 0.9559 - val_mean_iou: 0.6789 - val_dice_coefficient: 0.9425 - val_auc_4: 0.9945
# Epoch 50/50
# 47/47 [==============================] - 39s 823ms/step - loss: 0.0749 - categorical_crossentropy: 0.0749 - categorical_accuracy: 0.9731 - mean_iou: 0.7335 - dice_coefficient: 0.9554 - auc_4: 0.9961 - val_loss: 0.1136 - val_categorical_crossentropy: 0.1136 - val_categorical_accuracy: 0.9451 - val_mean_iou: 0.6607 - val_dice_coefficient: 0.9336 - val_auc_4: 0.9925

# %% [markdown]
# **Task 4**: Let's predict mitochondria in the testing data! [15 Points]

# %%
# 
# After training, let's try the U-Net on our testing data.
#
# The code below displays the first 10 input images, the original masks by experts, 
# and the predicted masks from the U-Net.

# %%
rows = 10
fig, axs = plt.subplots(rows, 3, figsize=(8, 30))
for ax, (image, label) in zip(axs, test.take(rows).batch(1)):
  
  prediction = unet_model.predict(image)
  ax[0].matshow(image[0, :, :, 0])
  ax[1].matshow(label[0, :, :, 1], cmap="gray")
  ax[2].matshow(prediction[0].argmax(axis=-1), cmap="gray")

# %%
# 1) Question
# TODO: Why do we use the prediction[0].argmax(axis=-1) command
# to display the prediction?
# 
# TODO: YOUR ANSWER

# prediction[0] is used due to the shape of the variable (1, 256, 256, 2).
# Since there is only one top level index, we must use 0.

# The argmax(axis=-1) part has the effect of turning the 2-class prediction
# which may look like [0.25, 0.75] into a binary 0 or 1. In this case it would
# turn into a 1, because index 1 has the greater value. This helps produce the
# black and white images we see above instead of prediction estimates that
# range in 0..1, like this:
plt.figure()
plt.imshow(prediction[0,:,:,1])

# %%
# 2) Question
# TODO: Is the quality of the segmentation good and how could we improve it?
# Hint: Think along the lines of some traditional image processing rather than
# increasing the training data size.
#
# TODO: YOUR ANSWER

# When you consider how little code this took, the quality is quite... fair.
# However, it should certainly be improved if this is to replace manual
# segmentation, as there are a significant number of incorrect classifications.

# It may be possible to improve performance by preprocessing the images
# differently. In particular, changing the image contrast or choosing
# a larger image size (if possible) may help. I would also be curious to see
# what kind of effect adding a very slight blur might have. 

# Additional training data could of course help, but I am further curious how
# generating additional data by inverting pixel values might improve things.

# %% [markdown]
# **Bonus**: Compare against the state-of-the-art literature! [33 Points]

# %%
#
# The following paper also uses a 2D U-Net to detect mitochondria:
# 
# https://danielhaehn.com/papers/?casser2020fast
#

# %%
# 1) Question
#
# TODO: How many learnable parameters does your trained unet_model have?
# Hint: You can use TF's Model Summary function to answer this.
#

# %%
# TODO: YOUR CODE

# How nice of you to give us reading material while the model fits. :-)
# unet_model.summary()

# There are a total of 31,030,658 trainable parameters in my model.

# %%
# 2) Question
#
# TODO: How many parameters do Casser et al. use?
#

# %%
# TODO: YOUR ANSWER
# Encoder: 1,178,480
# Decoder: 780,053
# Total: 1,958,533 (down from 31,694,401)

# %%
# 3) Question
#
# TODO: How did Casser et al. reduce the parameters?
#

# %%
# TODO: YOUR ANSWER
# This is primarily achieved through a reduction in the number of convolution
# filters used and by replacing transpose layers with bilinear upsampling layers.
# Additional speed-up was achieved by replacing a cropping step with a padding
# step.

# %%
# 4) Question
#
# TODO: Why did Casser et al. reduce the parameters?
#

# %%
# TODO: YOUR ANSWER
# Model utilization. 33.53% of the original U-Net model was wasted computations.
# Removing the superfluous layers resulted in nearly every calculation being
# a usefule one.

# %%
#
# You made it!!
#
#                 _ ___                /^^\ /^\  /^^\_
#     _          _@)@) \            ,,/ '` ~ `'~~ ', `\.
#   _/o\_ _ _ _/~`.`...'~\        ./~~..,'`','',.,' '  ~:
#  / `,'.~,~.~  .   , . , ~|,   ,/ .,' , ,. .. ,,.   `,  ~\_
# ( ' _' _ '_` _  '  .    , `\_/ .' ..' '  `  `   `..  `,   \_
#  ~V~ V~ V~ V~ ~\ `   ' .  '    , ' .,.,''`.,.''`.,.``. ',   \_
#   _/\ /\ /\ /\_/, . ' ,   `_/~\_ .' .,. ,, , _/~\_ `. `. '.,  \_
#  < ~ ~ '~`'~'`, .,  .   `_: ::: \_ '      `_/ ::: \_ `.,' . ',  \_
#   \ ' `_  '`_    _    ',/ _::_::_ \ _    _/ _::_::_ \   `.,'.,`., \-,-,-,_,_,
#    `'~~ `'~~ `'~~ `'~~  \(_)(_)(_)/  `~~' \(_)(_)(_)/ ~'`\_.._,._,'_;_;_;_;_;
#
