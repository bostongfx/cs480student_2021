# %% [markdown]
# <a href="https://colab.research.google.com/github/jessewilliamfreeman/cs480student/blob/main/06/Jesse_Freeman_CS480_Assignment_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![CS480_w.png](data:image/png;base64,...)
# #Assignment 6

# %%
# In this assignment, we will train a U-Net classifer to detect mitochondria
# in electron microscopy images!

# %%
### IMPORTANT ###
#
# Activate GPU support: Runtime -> Change Runtime Type
# Hardware Accelerator: GPU
#
### IMPORTANT ###

# %%
# load numpy and matplotlib
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# load the unet tensorflow code
# !pip install git+https://github.com/jakeret/unet.git
# Out:
# Collecting git+https://github.com/jakeret/unet.git
#   Cloning https://github.com/jakeret/unet.git to /tmp/pip-req-build-kgiz0ojf
#   Running command git clone -q https://github.com/jakeret/unet.git /tmp/pip-req-build-kgiz0ojf
# Requirement already satisfied (use --upgrade to upgrade): unet==0.0.post0.dev81+gf557a51 from git+https://github.com/jakeret/unet.git in /usr/local/lib/python3.7/dist-packages
# Building wheels for collected packages: unet
#   Building wheel for unet (setup.py) ... done
#   Created wheel for unet: filename=unet-0.0.post0.dev81+gf557a51-py2.py3-none-any.whl size=25658 sha256=3b6b9e2efc7509c8111e95f929d4d8850fefdf134cb37fc88ca2cd157aebcea6
#   Stored in directory: /tmp/pip-ephem-wheel-cache-yb4c1tyh/wheels/f5/38/c8/8f0a157cfd7616cc1a24811a52b9a669c0ee8fccc9f99d3cbc
# Successfully built unet

# %%
# .. and use it!
# Note: There are a ton of U-Net implementations but this one is easier to use!
import unet

# %% [markdown]
# **Task 1**: Study the unet circle example and learn about mitochondria! [15 Points]

# %%
# The unet package allows to train a U-Net classifier with little code.
# As discussed in class, the U-Net can be used to label/segment/annotate images.

# %%
# TODO: Please study the Circles example 
# https://github.com/jakeret/unet/blob/master/notebooks/circles.ipynb

# %%
# TODO: ... and look how the (artificial) dataset is generated
# https://github.com/jakeret/unet/blob/master/src/unet/datasets/circles.py

# %%
# 1) Question
# TODO: Please describe what the U-Net is trained to do.
#
# Its trained to detect the circles on the input image

# %%
# 2) Question
# TODO: In circles.py, what does the following mean:
#     channels = 1
#     classes = 2
#
# Each pixel of the input image has only one channel of data (its black and white)
# There are two classes that each pixel can be put in, circle or background

# %%
# 3) Question
# TODO: What are mitochondria and what is their appearance in
# electron microscopy data?
# Hint: You can validate your answer in Task 4!
#
# Mitochondia is the part of the cell that generates energy for it
# They look like circles (or often ovals)

# %% [markdown]
# **Task 2**: Setup a datagenerator for mitochondria images! [45 Points]

# %%
# TODO: 
# Download https://cs480.org/data/mito.npz to your computer.
# Then, please upload mito.npz using the file panel on the left.

# %%
# The code below is similar to the circles.py file from Task 1.
# We follow Tensorflow conventions to design a tf.data.Dataset for training
# the U-Net.
#
# TODO: Please add four different data augmentation methods in the code block
# below. (image normalization to 0..1, horizontal data flip, vertical data flip,
# rotation by 90 degrees)
#
# Hint: https://github.com/jakeret/unet/blob/master/src/unet/datasets/oxford_iiit_pet.py#L25

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow_datasets.core import DatasetInfo
from typing import Tuple, List

IMAGE_SIZE = (256, 256)
channels = 1
classes = 2

def load_data(count:int, splits:Tuple[float]=(0.7, 0.2, 0.1), **kwargs) -> List[tf.data.Dataset]:
    return [tf.data.Dataset.from_tensor_slices(_build_samples(int(split * count), **kwargs))
            for split in splits]


def _build_samples(sample_count:int, **kwargs) -> Tuple[np.array, np.array]:

    # here we load the mitochondria data
    loaded = np.load('mito.npz')
    loadedimages = loaded['arr_0'][0].copy()
    loadedmasks = loaded['arr_0'][1].copy()

    # now let's go to numpyland
    images = np.empty((sample_count, IMAGE_SIZE[0], IMAGE_SIZE[1], 1))
    labels = np.empty((sample_count, IMAGE_SIZE[0], IMAGE_SIZE[1], 2))
    for i in range(sample_count):
        image, mask = loadedimages[i], loadedmasks[i]

        image = image.reshape((IMAGE_SIZE[0], IMAGE_SIZE[1], 1)).astype(np.float)
        mask = mask.reshape((IMAGE_SIZE[0], IMAGE_SIZE[1], 1))

        #
        # TODO: Normalize the image to 0..1
        #
        # TODO: YOUR CODE
        image /= np.amax(image)

        #
        # TODO: Use Tensorflow to flip the image horizontally
        #
        if tf.random.uniform(()) > 0.5:
            #
            # TODO: YOUR CODE
            #
            image = tf.image.flip_left_right(image)
            mask  = tf.image.flip_left_right(mask)
        #
        # TODO: Use Tensorflow to flip the image vertically
        #
        if tf.random.uniform(()) > 0.5:
            #
            # TODO: YOUR CODE
            #
            image = tf.image.flip_up_down(image)
            mask  = tf.image.flip_up_down(mask)

        #
        # TODO: Use Tensorflow to rotate the image 90 degrees
        #
        if tf.random.uniform(()) > 0.5:
            #
            # TODO: YOUR CODE
            #
            image = tf.image.rot90(image)
            mask  = tf.image.rot90(mask)


        # augmentation done, let's store the image
        images[i] = image

        # here we split the mask to background and foreground
        fg = np.zeros((IMAGE_SIZE[0], IMAGE_SIZE[1], 1), dtype=np.bool)
        fg[mask == 255] = 1
        bg = np.zeros((IMAGE_SIZE[0], IMAGE_SIZE[1], 1), dtype=np.bool)
        bg[mask == 0] = 1
        
        labels[i, :, :, 0] = bg[:,:,0]
        labels[i, :, :, 1] = fg[:,:,0]

    return images, labels

# %% [markdown]
# **Task 3**: Let's train the U-Net! [25 Points]

# %%
#
# We can now create our training, validation, and testing data by calling
# our methods from Task 2.
#
train, val, test = load_data( 660, splits=(0.7, 0.2, 0.1) )

# %%
# 1) Question
# TODO: We have in total 660 images + 660 masks. Based on the code above,
# how many images are used for training alone?
#
# TODO: YOUR ANSWER

# %%
#
# Let's setup the U-Net!
#
LEARNING_RATE = 1e-3

unet_model = unet.build_model(channels=channels,
                              num_classes=classes,
                              layer_depth=5,
                              filters_root=64,
                              padding="same")

unet.finalize_model(unet_model, learning_rate=LEARNING_RATE)

# %%
#
# And, let's setup the trainer...
#
trainer = unet.Trainer(checkpoint_callback=False,
                       learning_rate_scheduler=unet.SchedulerType.WARMUP_LINEAR_DECAY,
                       warmup_proportion=0.1,
                       learning_rate=LEARNING_RATE)

# %%
#
# ...and train the U-Net for 50 epochs with a batch_size of 10!
#
# TODO: Please complete the code below.
# Hint: Don't forget to use training and validation data.
# Hint 2: This will take roughly 30 minutes!
#
trainer.fit(unet_model,
            train,
            val,
            epochs=50,
            batch_size=10)
# Out:
# Epoch 1/50
# 47/47 [==============================] - 59s 1s/step - loss: 0.6310 - categorical_crossentropy: 0.6310 - categorical_accuracy: 0.8264 - mean_iou: 0.3039 - dice_coefficient: 0.5550 - auc: 0.6548 - val_loss: 0.4008 - val_categorical_crossentropy: 0.4008 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3638 - val_dice_coefficient: 0.6776 - val_auc: 0.9830
# Epoch 2/50
# 47/47 [==============================] - 38s 811ms/step - loss: 0.3253 - categorical_crossentropy: 0.3253 - categorical_accuracy: 0.9209 - mean_iou: 0.4389 - dice_coefficient: 0.8293 - auc: 0.9323 - val_loss: 0.3326 - val_categorical_crossentropy: 0.3326 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3922 - val_dice_coefficient: 0.7306 - val_auc: 0.9830
# Epoch 3/50
# 47/47 [==============================] - 38s 819ms/step - loss: 0.2919 - categorical_crossentropy: 0.2919 - categorical_accuracy: 0.9210 - mean_iou: 0.4458 - dice_coefficient: 0.8405 - auc: 0.9413 - val_loss: 0.2148 - val_categorical_crossentropy: 0.2148 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4509 - val_dice_coefficient: 0.8474 - val_auc: 0.9836
# Epoch 4/50
# 47/47 [==============================] - 39s 825ms/step - loss: 0.2665 - categorical_crossentropy: 0.2665 - categorical_accuracy: 0.9210 - mean_iou: 0.4545 - dice_coefficient: 0.8553 - auc: 0.9460 - val_loss: 0.2215 - val_categorical_crossentropy: 0.2215 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4470 - val_dice_coefficient: 0.8369 - val_auc: 0.9838
# Epoch 5/50
# 47/47 [==============================] - 39s 829ms/step - loss: 0.2639 - categorical_crossentropy: 0.2639 - categorical_accuracy: 0.9210 - mean_iou: 0.4560 - dice_coefficient: 0.8566 - auc: 0.9488 - val_loss: 0.2374 - val_categorical_crossentropy: 0.2374 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4386 - val_dice_coefficient: 0.8173 - val_auc: 0.9840
# Epoch 6/50
# 47/47 [==============================] - 39s 834ms/step - loss: 0.2663 - categorical_crossentropy: 0.2663 - categorical_accuracy: 0.9210 - mean_iou: 0.4554 - dice_coefficient: 0.8537 - auc: 0.9492 - val_loss: 0.2236 - val_categorical_crossentropy: 0.2236 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4465 - val_dice_coefficient: 0.8310 - val_auc: 0.9842
# Epoch 7/50
# 47/47 [==============================] - 39s 838ms/step - loss: 0.2610 - categorical_crossentropy: 0.2610 - categorical_accuracy: 0.9210 - mean_iou: 0.4574 - dice_coefficient: 0.8548 - auc: 0.9511 - val_loss: 0.2091 - val_categorical_crossentropy: 0.2091 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4556 - val_dice_coefficient: 0.8456 - val_auc: 0.9844
# Epoch 8/50
# 47/47 [==============================] - 39s 840ms/step - loss: 0.2517 - categorical_crossentropy: 0.2517 - categorical_accuracy: 0.9210 - mean_iou: 0.4613 - dice_coefficient: 0.8578 - auc: 0.9553 - val_loss: 0.2082 - val_categorical_crossentropy: 0.2082 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4574 - val_dice_coefficient: 0.8437 - val_auc: 0.9846
# Epoch 9/50
# 47/47 [==============================] - 39s 842ms/step - loss: 0.2461 - categorical_crossentropy: 0.2461 - categorical_accuracy: 0.9210 - mean_iou: 0.4646 - dice_coefficient: 0.8595 - auc: 0.9584 - val_loss: 0.2080 - val_categorical_crossentropy: 0.2080 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4591 - val_dice_coefficient: 0.8414 - val_auc: 0.9849
# Epoch 10/50
# 47/47 [==============================] - 39s 841ms/step - loss: 0.2410 - categorical_crossentropy: 0.2410 - categorical_accuracy: 0.9210 - mean_iou: 0.4681 - dice_coefficient: 0.8610 - auc: 0.9612 - val_loss: 0.2054 - val_categorical_crossentropy: 0.2054 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4625 - val_dice_coefficient: 0.8422 - val_auc: 0.9852
# Epoch 11/50
# 47/47 [==============================] - 40s 843ms/step - loss: 0.2358 - categorical_crossentropy: 0.2358 - categorical_accuracy: 0.9210 - mean_iou: 0.4718 - dice_coefficient: 0.8628 - auc: 0.9637 - val_loss: 0.2028 - val_categorical_crossentropy: 0.2028 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4662 - val_dice_coefficient: 0.8434 - val_auc: 0.9854
# Epoch 12/50
# 47/47 [==============================] - 40s 847ms/step - loss: 0.2311 - categorical_crossentropy: 0.2311 - categorical_accuracy: 0.9210 - mean_iou: 0.4754 - dice_coefficient: 0.8641 - auc: 0.9658 - val_loss: 0.1990 - val_categorical_crossentropy: 0.1990 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4707 - val_dice_coefficient: 0.8463 - val_auc: 0.9856
# Epoch 13/50
# 47/47 [==============================] - 40s 846ms/step - loss: 0.2262 - categorical_crossentropy: 0.2262 - categorical_accuracy: 0.9210 - mean_iou: 0.4793 - dice_coefficient: 0.8655 - auc: 0.9678 - val_loss: 0.1947 - val_categorical_crossentropy: 0.1947 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4757 - val_dice_coefficient: 0.8499 - val_auc: 0.9857
# Epoch 14/50
# 47/47 [==============================] - 40s 849ms/step - loss: 0.2211 - categorical_crossentropy: 0.2211 - categorical_accuracy: 0.9210 - mean_iou: 0.4836 - dice_coefficient: 0.8675 - auc: 0.9696 - val_loss: 0.1939 - val_categorical_crossentropy: 0.1939 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4786 - val_dice_coefficient: 0.8502 - val_auc: 0.9859
# Epoch 15/50
# 47/47 [==============================] - 40s 846ms/step - loss: 0.2169 - categorical_crossentropy: 0.2169 - categorical_accuracy: 0.9210 - mean_iou: 0.4872 - dice_coefficient: 0.8694 - auc: 0.9711 - val_loss: 0.1925 - val_categorical_crossentropy: 0.1925 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4818 - val_dice_coefficient: 0.8513 - val_auc: 0.9861
# Epoch 16/50
# 47/47 [==============================] - 40s 846ms/step - loss: 0.2146 - categorical_crossentropy: 0.2146 - categorical_accuracy: 0.9210 - mean_iou: 0.4901 - dice_coefficient: 0.8695 - auc: 0.9719 - val_loss: 0.1857 - val_categorical_crossentropy: 0.1857 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4875 - val_dice_coefficient: 0.8578 - val_auc: 0.9862
# Epoch 17/50
# 47/47 [==============================] - 40s 847ms/step - loss: 0.2100 - categorical_crossentropy: 0.2100 - categorical_accuracy: 0.9210 - mean_iou: 0.4940 - dice_coefficient: 0.8713 - auc: 0.9732 - val_loss: 0.1838 - val_categorical_crossentropy: 0.1838 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4905 - val_dice_coefficient: 0.8596 - val_auc: 0.9864
# Epoch 18/50
# 47/47 [==============================] - 40s 847ms/step - loss: 0.2065 - categorical_crossentropy: 0.2065 - categorical_accuracy: 0.9210 - mean_iou: 0.4973 - dice_coefficient: 0.8727 - auc: 0.9742 - val_loss: 0.1826 - val_categorical_crossentropy: 0.1826 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4928 - val_dice_coefficient: 0.8607 - val_auc: 0.9865
# Epoch 19/50
# 47/47 [==============================] - 40s 847ms/step - loss: 0.2040 - categorical_crossentropy: 0.2040 - categorical_accuracy: 0.9210 - mean_iou: 0.5001 - dice_coefficient: 0.8734 - auc: 0.9750 - val_loss: 0.1808 - val_categorical_crossentropy: 0.1808 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4951 - val_dice_coefficient: 0.8623 - val_auc: 0.9868
# Epoch 20/50
# 47/47 [==============================] - 40s 847ms/step - loss: 0.2002 - categorical_crossentropy: 0.2002 - categorical_accuracy: 0.9210 - mean_iou: 0.5033 - dice_coefficient: 0.8757 - auc: 0.9760 - val_loss: 0.1816 - val_categorical_crossentropy: 0.1816 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4952 - val_dice_coefficient: 0.8616 - val_auc: 0.9869
# Epoch 21/50
# 47/47 [==============================] - 40s 847ms/step - loss: 0.2017 - categorical_crossentropy: 0.2017 - categorical_accuracy: 0.9210 - mean_iou: 0.5033 - dice_coefficient: 0.8734 - auc: 0.9758 - val_loss: 0.1680 - val_categorical_crossentropy: 0.1680 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.5045 - val_dice_coefficient: 0.8748 - val_auc: 0.9870
# Epoch 22/50
# 47/47 [==============================] - 40s 848ms/step - loss: 0.1946 - categorical_crossentropy: 0.1946 - categorical_accuracy: 0.9210 - mean_iou: 0.5087 - dice_coefficient: 0.8787 - auc: 0.9772 - val_loss: 0.1746 - val_categorical_crossentropy: 0.1746 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.5009 - val_dice_coefficient: 0.8682 - val_auc: 0.9873
# Epoch 23/50
# 47/47 [==============================] - 40s 848ms/step - loss: 0.1971 - categorical_crossentropy: 0.1971 - categorical_accuracy: 0.9210 - mean_iou: 0.5080 - dice_coefficient: 0.8758 - auc: 0.9769 - val_loss: 0.1624 - val_categorical_crossentropy: 0.1624 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.5091 - val_dice_coefficient: 0.8803 - val_auc: 0.9873
# Epoch 24/50
# 47/47 [==============================] - 40s 845ms/step - loss: 0.1912 - categorical_crossentropy: 0.1912 - categorical_accuracy: 0.9210 - mean_iou: 0.5122 - dice_coefficient: 0.8807 - auc: 0.9780 - val_loss: 0.1656 - val_categorical_crossentropy: 0.1656 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.5077 - val_dice_coefficient: 0.8768 - val_auc: 0.9876
# Epoch 25/50
# 47/47 [==============================] - 40s 845ms/step - loss: 0.1918 - categorical_crossentropy: 0.1918 - categorical_accuracy: 0.9210 - mean_iou: 0.5126 - dice_coefficient: 0.8793 - auc: 0.9780 - val_loss: 0.1584 - val_categorical_crossentropy: 0.1584 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.5131 - val_dice_coefficient: 0.8842 - val_auc: 0.9877
# Epoch 26/50
# 47/47 [==============================] - 40s 845ms/step - loss: 0.1885 - categorical_crossentropy: 0.1885 - categorical_accuracy: 0.9210 - mean_iou: 0.5149 - dice_coefficient: 0.8824 - auc: 0.9785 - val_loss: 0.1576 - val_categorical_crossentropy: 0.1576 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.5143 - val_dice_coefficient: 0.8848 - val_auc: 0.9879
# Epoch 27/50
# 47/47 [==============================] - 39s 842ms/step - loss: 0.1871 - categorical_crossentropy: 0.1871 - categorical_accuracy: 0.9210 - mean_iou: 0.5170 - dice_coefficient: 0.8829 - auc: 0.9789 - val_loss: 0.1548 - val_categorical_crossentropy: 0.1548 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.5168 - val_dice_coefficient: 0.8876 - val_auc: 0.9880
# Epoch 28/50
# 47/47 [==============================] - 40s 843ms/step - loss: 0.1852 - categorical_crossentropy: 0.1852 - categorical_accuracy: 0.9210 - mean_iou: 0.5189 - dice_coefficient: 0.8844 - auc: 0.9793 - val_loss: 0.1527 - val_categorical_crossentropy: 0.1527 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.5189 - val_dice_coefficient: 0.8897 - val_auc: 0.9882
# Epoch 29/50
# 47/47 [==============================] - 40s 843ms/step - loss: 0.1838 - categorical_crossentropy: 0.1838 - categorical_accuracy: 0.9210 - mean_iou: 0.5205 - dice_coefficient: 0.8853 - auc: 0.9796 - val_loss: 0.1506 - val_categorical_crossentropy: 0.1506 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.5211 - val_dice_coefficient: 0.8919 - val_auc: 0.9883
# Epoch 30/50
# 47/47 [==============================] - 40s 845ms/step - loss: 0.1822 - categorical_crossentropy: 0.1822 - categorical_accuracy: 0.9210 - mean_iou: 0.5223 - dice_coefficient: 0.8866 - auc: 0.9799 - val_loss: 0.1489 - val_categorical_crossentropy: 0.1489 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.5230 - val_dice_coefficient: 0.8937 - val_auc: 0.9884
# Epoch 31/50
# 47/47 [==============================] - 40s 846ms/step - loss: 0.1809 - categorical_crossentropy: 0.1809 - categorical_accuracy: 0.9210 - mean_iou: 0.5237 - dice_coefficient: 0.8877 - auc: 0.9802 - val_loss: 0.1476 - val_categorical_crossentropy: 0.1476 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.5247 - val_dice_coefficient: 0.8951 - val_auc: 0.9885
# Epoch 32/50
# 47/47 [==============================] - 40s 846ms/step - loss: 0.1796 - categorical_crossentropy: 0.1796 - categorical_accuracy: 0.9210 - mean_iou: 0.5251 - dice_coefficient: 0.8885 - auc: 0.9804 - val_loss: 0.1463 - val_categorical_crossentropy: 0.1463 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.5264 - val_dice_coefficient: 0.8965 - val_auc: 0.9886
# Epoch 33/50
# 47/47 [==============================] - 40s 847ms/step - loss: 0.1778 - categorical_crossentropy: 0.1778 - categorical_accuracy: 0.9210 - mean_iou: 0.5271 - dice_coefficient: 0.8900 - auc: 0.9808 - val_loss: 0.1470 - val_categorical_crossentropy: 0.1470 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.5265 - val_dice_coefficient: 0.8943 - val_auc: 0.9890
# Epoch 34/50
# 47/47 [==============================] - 39s 840ms/step - loss: 0.1720 - categorical_crossentropy: 0.1720 - categorical_accuracy: 0.9210 - mean_iou: 0.5335 - dice_coefficient: 0.8946 - auc: 0.9818 - val_loss: 0.1505 - val_categorical_crossentropy: 0.1505 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.5248 - val_dice_coefficient: 0.8916 - val_auc: 0.9886
# Epoch 35/50
# 47/47 [==============================] - 39s 839ms/step - loss: 0.1785 - categorical_crossentropy: 0.1785 - categorical_accuracy: 0.9210 - mean_iou: 0.5280 - dice_coefficient: 0.8871 - auc: 0.9808 - val_loss: 0.1426 - val_categorical_crossentropy: 0.1426 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.5316 - val_dice_coefficient: 0.9012 - val_auc: 0.9887
# Epoch 36/50
# 47/47 [==============================] - 40s 844ms/step - loss: 0.1751 - categorical_crossentropy: 0.1751 - categorical_accuracy: 0.9210 - mean_iou: 0.5309 - dice_coefficient: 0.8923 - auc: 0.9812 - val_loss: 0.1414 - val_categorical_crossentropy: 0.1414 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.5339 - val_dice_coefficient: 0.9011 - val_auc: 0.9891
# Epoch 37/50
# 47/47 [==============================] - 40s 849ms/step - loss: 0.1709 - categorical_crossentropy: 0.1709 - categorical_accuracy: 0.9212 - mean_iou: 0.5353 - dice_coefficient: 0.8958 - auc: 0.9819 - val_loss: 0.1449 - val_categorical_crossentropy: 0.1449 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.5331 - val_dice_coefficient: 0.8980 - val_auc: 0.9889
# Epoch 38/50
# 47/47 [==============================] - 40s 849ms/step - loss: 0.1702 - categorical_crossentropy: 0.1702 - categorical_accuracy: 0.9215 - mean_iou: 0.5364 - dice_coefficient: 0.8941 - auc: 0.9822 - val_loss: 0.1401 - val_categorical_crossentropy: 0.1401 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.5389 - val_dice_coefficient: 0.8999 - val_auc: 0.9899
# Epoch 39/50
# 47/47 [==============================] - 40s 852ms/step - loss: 0.1612 - categorical_crossentropy: 0.1612 - categorical_accuracy: 0.9237 - mean_iou: 0.5469 - dice_coefficient: 0.9011 - auc: 0.9837 - val_loss: 0.1494 - val_categorical_crossentropy: 0.1494 - val_categorical_accuracy: 0.9460 - val_mean_iou: 0.5330 - val_dice_coefficient: 0.8904 - val_auc: 0.9899
# Epoch 40/50
# 47/47 [==============================] - 40s 851ms/step - loss: 0.1572 - categorical_crossentropy: 0.1572 - categorical_accuracy: 0.9297 - mean_iou: 0.5520 - dice_coefficient: 0.9008 - auc: 0.9849 - val_loss: 0.1255 - val_categorical_crossentropy: 0.1255 - val_categorical_accuracy: 0.9463 - val_mean_iou: 0.5656 - val_dice_coefficient: 0.9097 - val_auc: 0.9921
# Epoch 41/50
# 47/47 [==============================] - 40s 847ms/step - loss: 0.1366 - categorical_crossentropy: 0.1366 - categorical_accuracy: 0.9432 - mean_iou: 0.6026 - dice_coefficient: 0.9186 - auc: 0.9883 - val_loss: 0.1154 - val_categorical_crossentropy: 0.1154 - val_categorical_accuracy: 0.9473 - val_mean_iou: 0.5920 - val_dice_coefficient: 0.9160 - val_auc: 0.9934
# Epoch 42/50
# 47/47 [==============================] - 39s 839ms/step - loss: 0.1231 - categorical_crossentropy: 0.1231 - categorical_accuracy: 0.9498 - mean_iou: 0.6280 - dice_coefficient: 0.9260 - auc: 0.9904 - val_loss: 0.0997 - val_categorical_crossentropy: 0.0997 - val_categorical_accuracy: 0.9559 - val_mean_iou: 0.6225 - val_dice_coefficient: 0.9296 - val_auc: 0.9947
# Epoch 43/50
# 47/47 [==============================] - 39s 837ms/step - loss: 0.1086 - categorical_crossentropy: 0.1086 - categorical_accuracy: 0.9564 - mean_iou: 0.6580 - dice_coefficient: 0.9347 - auc: 0.9924 - val_loss: 0.0873 - val_categorical_crossentropy: 0.0873 - val_categorical_accuracy: 0.9637 - val_mean_iou: 0.6492 - val_dice_coefficient: 0.9390 - val_auc: 0.9958
# Epoch 44/50
# 47/47 [==============================] - 39s 836ms/step - loss: 0.0962 - categorical_crossentropy: 0.0962 - categorical_accuracy: 0.9622 - mean_iou: 0.6854 - dice_coefficient: 0.9434 - auc: 0.9939 - val_loss: 0.0840 - val_categorical_crossentropy: 0.0840 - val_categorical_accuracy: 0.9656 - val_mean_iou: 0.6605 - val_dice_coefficient: 0.9409 - val_auc: 0.9962
# Epoch 45/50
# 47/47 [==============================] - 39s 837ms/step - loss: 0.0886 - categorical_crossentropy: 0.0886 - categorical_accuracy: 0.9650 - mean_iou: 0.7022 - dice_coefficient: 0.9475 - auc: 0.9948 - val_loss: 0.0845 - val_categorical_crossentropy: 0.0845 - val_categorical_accuracy: 0.9646 - val_mean_iou: 0.6653 - val_dice_coefficient: 0.9400 - val_auc: 0.9963
# Epoch 46/50
# 47/47 [==============================] - 39s 837ms/step - loss: 0.0841 - categorical_crossentropy: 0.0841 - categorical_accuracy: 0.9669 - mean_iou: 0.7154 - dice_coefficient: 0.9497 - auc: 0.9953 - val_loss: 0.0807 - val_categorical_crossentropy: 0.0807 - val_categorical_accuracy: 0.9666 - val_mean_iou: 0.6740 - val_dice_coefficient: 0.9426 - val_auc: 0.9966
# Epoch 47/50
# 47/47 [==============================] - 39s 835ms/step - loss: 0.0788 - categorical_crossentropy: 0.0788 - categorical_accuracy: 0.9688 - mean_iou: 0.7330 - dice_coefficient: 0.9531 - auc: 0.9958 - val_loss: 0.0756 - val_categorical_crossentropy: 0.0756 - val_categorical_accuracy: 0.9707 - val_mean_iou: 0.6787 - val_dice_coefficient: 0.9461 - val_auc: 0.9970
# Epoch 48/50
# 47/47 [==============================] - 39s 836ms/step - loss: 0.0743 - categorical_crossentropy: 0.0743 - categorical_accuracy: 0.9709 - mean_iou: 0.7443 - dice_coefficient: 0.9559 - auc: 0.9962 - val_loss: 0.0728 - val_categorical_crossentropy: 0.0728 - val_categorical_accuracy: 0.9731 - val_mean_iou: 0.6803 - val_dice_coefficient: 0.9482 - val_auc: 0.9973
# Epoch 49/50
# 47/47 [==============================] - 39s 836ms/step - loss: 0.0715 - categorical_crossentropy: 0.0715 - categorical_accuracy: 0.9722 - mean_iou: 0.7499 - dice_coefficient: 0.9576 - auc: 0.9965 - val_loss: 0.0703 - val_categorical_crossentropy: 0.0703 - val_categorical_accuracy: 0.9744 - val_mean_iou: 0.6854 - val_dice_coefficient: 0.9503 - val_auc: 0.9974
# Epoch 50/50
# 47/47 [==============================] - 39s 838ms/step - loss: 0.0693 - categorical_crossentropy: 0.0693 - categorical_accuracy: 0.9736 - mean_iou: 0.7529 - dice_coefficient: 0.9588 - auc: 0.9967 - val_loss: 0.0691 - val_categorical_crossentropy: 0.0691 - val_categorical_accuracy: 0.9742 - val_mean_iou: 0.6926 - val_dice_coefficient: 0.9511 - val_auc: 0.9975

# %% [markdown]
# **Task 4**: Let's predict mitochondria in the testing data! [15 Points]

# %%
# 
# After training, let's try the U-Net on our testing data.
#
# The code below displays the first 10 input images, the original masks by experts, 
# and the predicted masks from the U-Net.

# %%
rows = 10
fig, axs = plt.subplots(rows, 3, figsize=(8, 30))
for ax, (image, label) in zip(axs, test.take(rows).batch(1)):
  
  prediction = unet_model.predict(image)
  ax[0].matshow(image[0, :, :, 0])
  ax[1].matshow(label[0, :, :, 1], cmap="gray")
  ax[2].matshow(prediction[0].argmax(axis=-1), cmap="gray")

# %%
# 1) Question
# TODO: Why do we use the prediction[0].argmax(axis=-1) command
# to display the prediction?
# 
# This grabs the final axis of the prediction which is the label
# and then evaluates it to find which class has the highest prediction
# score.

# %%
# 2) Question
# TODO: Is the quality of the segmentation good and how could we improve it?
# Hint: Think along the lines of some traditional image processing rather than
# increasing the training data size.
#
# Growing then shrinking then re expanding the mitochondira area would make it 
# much smoother and also eliminate the small islands inside of the mitochondira
# and also the ones outside.

# %% [markdown]
# **Bonus**: Compare against the state-of-the-art literature! [33 Points]

# %%
#
# The following paper also uses a 2D U-Net to detect mitochondria:
# 
# https://danielhaehn.com/papers/?casser2020fast
#

# %%
# 1) Question
#
# TODO: How many learnable parameters does your trained unet_model have?
# Hint: You can use TF's Model Summary function to answer this.
#

# %%
# TODO: YOUR CODE

# %%
# 2) Question
#
# TODO: How many parameters do Casser et al. use?
#

# %%
# 1,178,480 encoder parameters
# 780,053   decoder parameters
# 1,958,533 total parameters

# %%
# 3) Question
#
# TODO: How did Casser et al. reduce the parameters?
#

# %%
# They reduced the number of convolutional filters in the network, 
# replaced transpose colvolutions in the decoder with a parameterless layer,
# and replaced the center cropping with padding to output densely at full
# resolution.

# %%
# 4) Question
#
# TODO: Why did Casser et al. reduce the parameters?
#

# %%
# Reducing the number of parameters reduces the number of opperations the 
# network needs to run, saving execution time. This is importaint when the 
# amount of data to proccess is as massive as it is in brain connectomics.

# %%
#
# You made it!!
#
#                 _ ___                /^^\ /^\  /^^\_
#     _          _@)@) \            ,,/ '` ~ `'~~ ', `\.
#   _/o\_ _ _ _/~`.`...'~\        ./~~..,'`','',.,' '  ~:
#  / `,'.~,~.~  .   , . , ~|,   ,/ .,' , ,. .. ,,.   `,  ~\_
# ( ' _' _ '_` _  '  .    , `\_/ .' ..' '  `  `   `..  `,   \_
#  ~V~ V~ V~ V~ ~\ `   ' .  '    , ' .,.,''`.,.''`.,.``. ',   \_
#   _/\ /\ /\ /\_/, . ' ,   `_/~\_ .' .,. ,, , _/~\_ `. `. '.,  \_
#  < ~ ~ '~`'~'`, .,  .   `_: ::: \_ '      `_/ ::: \_ `.,' . ',  \_
#   \ ' `_  '`_    _    ',/ _::_::_ \ _    _/ _::_::_ \   `.,'.,`., \-,-,-,_,_,
#    `'~~ `'~~ `'~~ `'~~  \(_)(_)(_)/  `~~' \(_)(_)(_)/ ~'`\_.._,._,'_;_;_;_;_;
#
