# %% [markdown]
# <a href="https://colab.research.google.com/github/anniemoriondo/cs480student/blob/main/06/Moriondo_CS480_Assignment_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![CS480_w.png](data:image/png;base64,...)
# #Assignment 6

# %%
# In this assignment, we will train a U-Net classifer to detect mitochondria
# in electron microscopy images!

# %%
### IMPORTANT ###
#
# Activate GPU support: Runtime -> Change Runtime Type
# Hardware Accelerator: GPU
# Thanks - done!
#
### IMPORTANT ###

# %%
# load numpy and matplotlib
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# load the unet tensorflow code
# !pip install git+https://github.com/jakeret/unet.git
# Out:
# Collecting git+https://github.com/jakeret/unet.git
#   Cloning https://github.com/jakeret/unet.git to /tmp/pip-req-build-a03qtg77
#   Running command git clone -q https://github.com/jakeret/unet.git /tmp/pip-req-build-a03qtg77
# Building wheels for collected packages: unet
#   Building wheel for unet (setup.py) ... done
#   Created wheel for unet: filename=unet-0.0.post0.dev81+gf557a51-py2.py3-none-any.whl size=25658 sha256=f076fb677921759504f736a7a701ad981fee5de8799776c338e98a17a77c8c59
#   Stored in directory: /tmp/pip-ephem-wheel-cache-21nxcunb/wheels/f5/38/c8/8f0a157cfd7616cc1a24811a52b9a669c0ee8fccc9f99d3cbc
# Successfully built unet
# Installing collected packages: unet
# Successfully installed unet-0.0.post0.dev81+gf557a51

# %%
# .. and use it!
# Note: There are a ton of U-Net implementations but this one is easier to use!
import unet

# %% [markdown]
# **Task 1**: Study the unet circle example and learn about mitochondria! [15 Points]

# %%
# The unet package allows to train a U-Net classifier with little code.
# As discussed in class, the U-Net can be used to label/segment/annotate images.

# %%
# TODO: Please study the Circles example 
# https://github.com/jakeret/unet/blob/master/notebooks/circles.ipynb

# %%
# TODO: ... and look how the (artificial) dataset is generated
# https://github.com/jakeret/unet/blob/master/src/unet/datasets/circles.py

# %%
# 1) Question
# TODO: Please describe what the U-Net is trained to do.
#
# TODO: YOUR ANSWER
# The U-Net is an artificial neural net which is trained on a set of source data
# and corresponding target data, until it can predict target data based on
# a fresh set of source data. In this case, the source data is randomly
# generated, noisy images of circles, and the target data is "masks" consisting
# of black-and-white regions showing the actual positions of the circles.
# The U-Net, in this case, takes noisy images and tries to predict the masks.

# %%
# 2) Question
# TODO: In circles.py, what does the following mean:
#     channels = 1
#     classes = 2
#
# TODO: YOUR ANSWER
# These are the `channels` and `classes` parameters which will be passed to
# `unet` when the U-Net is trained on the images and masks.
# As far as I can tell, channels = 1 means there's one source of data,
# namely circles.py, and classes=2 means that this channel contains two
# classes of data: source data (images) and target data(masks).

# %%
# 3) Question
# TODO: What are mitochondria and what is their appearance in
# electron microscopy data?
# Hint: You can validate your answer in Task 4!
#
# TODO: YOUR ANSWER
# Mitochondria are organelles which supply animal cells with energy. They
# appear as oval shapes with the points rounded off, in electron microscopy 
# data.

# %% [markdown]
# **Task 2**: Setup a datagenerator for mitochondria images! [45 Points]

# %%
# TODO: 
# Download https://cs480.org/data/mito.npz to your computer.
# Then, please upload mito.npz using the file panel on the left.

# %%
# The code below is similar to the circles.py file from Task 1.
# We follow Tensorflow conventions to design a tf.data.Dataset for training
# the U-Net.
#
# TODO: Please add four different data augmentation methods in the code block
# below. (image normalization to 0..1, horizontal data flip, vertical data flip,
# rotation by 90 degrees)
#
# Hint: https://github.com/jakeret/unet/blob/master/src/unet/datasets/oxford_iiit_pet.py#L25

# I also consulted the docs at https://www.tensorflow.org
# focusing on the Python API https://www.tensorflow.org/api_docs/python/

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow_datasets.core import DatasetInfo
from typing import Tuple, List

IMAGE_SIZE = (256, 256)
channels = 1
classes = 2

def load_data(count:int, splits:Tuple[float]=(0.7, 0.2, 0.1), **kwargs) -> List[tf.data.Dataset]:
    return [tf.data.Dataset.from_tensor_slices(_build_samples(int(split * count), **kwargs))
            for split in splits]


def _build_samples(sample_count:int, **kwargs) -> Tuple[np.array, np.array]:

    # here we load the mitochondria data
    loaded = np.load('mito.npz')
    loadedimages = loaded['arr_0'][0].copy()
    loadedmasks = loaded['arr_0'][1].copy()

    # now let's go to numpyland
    images = np.empty((sample_count, IMAGE_SIZE[0], IMAGE_SIZE[1], 1))
    labels = np.empty((sample_count, IMAGE_SIZE[0], IMAGE_SIZE[1], 2))
    for i in range(sample_count):
        image, mask = loadedimages[i], loadedmasks[i]

        image = image.reshape((IMAGE_SIZE[0], IMAGE_SIZE[1], 1)).astype(np.float)
        mask = mask.reshape((IMAGE_SIZE[0], IMAGE_SIZE[1], 1))

        #
        # TODO: Normalize the image to 0..1
        #

        # Change the image from a 0...255 scale to 0...1
        image = tf.cast(image, tf.float32) / 255.0
        mask -= 1

        #
        # TODO: Use Tensorflow to flip the image horizontally
        #
        if tf.random.uniform(()) > 0.5:
            image = tf.image.flip_left_right(image)
            mask = tf.image.flip_left_right(mask)

        #
        # TODO: Use Tensorflow to flip the image vertically
        #
        if tf.random.uniform(()) > 0.5:
            image = tf.image.flip_up_down(image)
            mask = tf.image.flip_up_down(mask)

        #
        # TODO: Use Tensorflow to rotate the image 90 degrees
        #
        if tf.random.uniform(()) > 0.5:
            # Specifically, a counterclockwise rotation
            image = tf.image.rot90(image)
            mask = tf.image.rot90(mask)


        # augmentation done, let's store the image
        images[i] = image

        # here we split the mask to background and foreground
        fg = np.zeros((IMAGE_SIZE[0], IMAGE_SIZE[1], 1), dtype=np.bool)
        fg[mask == 255] = 1
        bg = np.zeros((IMAGE_SIZE[0], IMAGE_SIZE[1], 1), dtype=np.bool)
        bg[mask == 0] = 1
        
        labels[i, :, :, 0] = bg[:,:,0]
        labels[i, :, :, 1] = fg[:,:,0]

    return images, labels

# %% [markdown]
# **Task 3**: Let's train the U-Net! [25 Points]

# %%
#
# We can now create our training, validation, and testing data by calling
# our methods from Task 2.
#
train, val, test = load_data( 660, splits=(0.7, 0.2, 0.1) )

# %%
# 1) Question
# TODO: We have in total 660 images + 660 masks. Based on the code above,
# how many images are used for training alone?
#
# TODO: YOUR ANSWER
print(.7 * 660)
# 462 images are used for training alone.
# Out:
# 461.99999999999994

# %%
#
# Let's setup the U-Net!
#
LEARNING_RATE = 1e-3

unet_model = unet.build_model(channels=channels,
                              num_classes=classes,
                              layer_depth=5,
                              filters_root=64,
                              padding="same")

unet.finalize_model(unet_model, learning_rate=LEARNING_RATE)

# %%
#
# And, let's setup the trainer...
#
trainer = unet.Trainer(checkpoint_callback=False,
                       learning_rate_scheduler=unet.SchedulerType.WARMUP_LINEAR_DECAY,
                       warmup_proportion=0.1,
                       learning_rate=LEARNING_RATE)

# %%
#
# ...and train the U-Net for 50 epochs with a batch_size of 10!
#
# TODO: Please complete the code below.
# Hint: Don't forget to use training and validation data.
# Hint 2: This will take roughly 30 minutes!
#
trainer.fit(unet_model, train, val, epochs=50, batch_size=10            )
# Out:
# Epoch 1/50
# 47/47 [==============================] - 59s 1s/step - loss: 0.5231 - categorical_crossentropy: 0.5231 - categorical_accuracy: 0.5014 - mean_iou: 0.2771 - dice_coefficient: 0.5598 - auc: 0.7733 - val_loss: 0.4128 - val_categorical_crossentropy: 0.4128 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3107 - val_dice_coefficient: 0.6262 - val_auc: 0.9936
# Epoch 2/50
# 47/47 [==============================] - 39s 822ms/step - loss: 0.1136 - categorical_crossentropy: 0.1136 - categorical_accuracy: 0.9210 - mean_iou: 0.4144 - dice_coefficient: 0.8525 - auc: 0.9716 - val_loss: 0.1956 - val_categorical_crossentropy: 0.1956 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3881 - val_dice_coefficient: 0.7889 - val_auc: 0.9942
# Epoch 3/50
# 47/47 [==============================] - 39s 832ms/step - loss: 0.0632 - categorical_crossentropy: 0.0632 - categorical_accuracy: 0.9210 - mean_iou: 0.4350 - dice_coefficient: 0.8968 - auc: 0.9789 - val_loss: 0.1046 - val_categorical_crossentropy: 0.1046 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4254 - val_dice_coefficient: 0.8687 - val_auc: 0.9938
# Epoch 4/50
# 47/47 [==============================] - 39s 841ms/step - loss: 0.0671 - categorical_crossentropy: 0.0671 - categorical_accuracy: 0.9210 - mean_iou: 0.4337 - dice_coefficient: 0.8936 - auc: 0.9794 - val_loss: 0.1106 - val_categorical_crossentropy: 0.1106 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4232 - val_dice_coefficient: 0.8635 - val_auc: 0.9938
# Epoch 5/50
# 47/47 [==============================] - 40s 849ms/step - loss: 0.0722 - categorical_crossentropy: 0.0722 - categorical_accuracy: 0.9210 - mean_iou: 0.4318 - dice_coefficient: 0.8891 - auc: 0.9789 - val_loss: 0.1313 - val_categorical_crossentropy: 0.1313 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4147 - val_dice_coefficient: 0.8450 - val_auc: 0.9939
# Epoch 6/50
# 47/47 [==============================] - 40s 858ms/step - loss: 0.0772 - categorical_crossentropy: 0.0772 - categorical_accuracy: 0.9210 - mean_iou: 0.4297 - dice_coefficient: 0.8845 - auc: 0.9787 - val_loss: 0.1437 - val_categorical_crossentropy: 0.1437 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4100 - val_dice_coefficient: 0.8345 - val_auc: 0.9939
# Epoch 7/50
# 47/47 [==============================] - 40s 862ms/step - loss: 0.0845 - categorical_crossentropy: 0.0845 - categorical_accuracy: 0.9210 - mean_iou: 0.4266 - dice_coefficient: 0.8779 - auc: 0.9782 - val_loss: 0.1208 - val_categorical_crossentropy: 0.1208 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4196 - val_dice_coefficient: 0.8548 - val_auc: 0.9940
# Epoch 8/50
# 47/47 [==============================] - 40s 860ms/step - loss: 0.0812 - categorical_crossentropy: 0.0812 - categorical_accuracy: 0.9210 - mean_iou: 0.4279 - dice_coefficient: 0.8807 - auc: 0.9797 - val_loss: 0.0960 - val_categorical_crossentropy: 0.0960 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4305 - val_dice_coefficient: 0.8778 - val_auc: 0.9942
# Epoch 9/50
# 47/47 [==============================] - 41s 864ms/step - loss: 0.0783 - categorical_crossentropy: 0.0783 - categorical_accuracy: 0.9210 - mean_iou: 0.4295 - dice_coefficient: 0.8833 - auc: 0.9827 - val_loss: 0.1137 - val_categorical_crossentropy: 0.1137 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4244 - val_dice_coefficient: 0.8631 - val_auc: 0.9943
# Epoch 10/50
# 47/47 [==============================] - 40s 863ms/step - loss: 0.0804 - categorical_crossentropy: 0.0804 - categorical_accuracy: 0.9210 - mean_iou: 0.4295 - dice_coefficient: 0.8820 - auc: 0.9840 - val_loss: 0.1225 - val_categorical_crossentropy: 0.1225 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4220 - val_dice_coefficient: 0.8566 - val_auc: 0.9943
# Epoch 11/50
# 47/47 [==============================] - 41s 866ms/step - loss: 0.0812 - categorical_crossentropy: 0.0812 - categorical_accuracy: 0.9210 - mean_iou: 0.4299 - dice_coefficient: 0.8819 - auc: 0.9851 - val_loss: 0.1211 - val_categorical_crossentropy: 0.1211 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4236 - val_dice_coefficient: 0.8591 - val_auc: 0.9944
# Epoch 12/50
# 47/47 [==============================] - 41s 866ms/step - loss: 0.0813 - categorical_crossentropy: 0.0813 - categorical_accuracy: 0.9210 - mean_iou: 0.4306 - dice_coefficient: 0.8824 - auc: 0.9863 - val_loss: 0.1235 - val_categorical_crossentropy: 0.1235 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4238 - val_dice_coefficient: 0.8584 - val_auc: 0.9945
# Epoch 13/50
# 47/47 [==============================] - 40s 864ms/step - loss: 0.0818 - categorical_crossentropy: 0.0818 - categorical_accuracy: 0.9210 - mean_iou: 0.4311 - dice_coefficient: 0.8826 - auc: 0.9870 - val_loss: 0.1182 - val_categorical_crossentropy: 0.1182 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4268 - val_dice_coefficient: 0.8641 - val_auc: 0.9945
# Epoch 14/50
# 47/47 [==============================] - 41s 865ms/step - loss: 0.0810 - categorical_crossentropy: 0.0810 - categorical_accuracy: 0.9210 - mean_iou: 0.4321 - dice_coefficient: 0.8837 - auc: 0.9880 - val_loss: 0.1217 - val_categorical_crossentropy: 0.1217 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4263 - val_dice_coefficient: 0.8621 - val_auc: 0.9946
# Epoch 15/50
# 47/47 [==============================] - 41s 867ms/step - loss: 0.0818 - categorical_crossentropy: 0.0818 - categorical_accuracy: 0.9210 - mean_iou: 0.4323 - dice_coefficient: 0.8835 - auc: 0.9887 - val_loss: 0.1158 - val_categorical_crossentropy: 0.1158 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4294 - val_dice_coefficient: 0.8681 - val_auc: 0.9947
# Epoch 16/50
# 47/47 [==============================] - 41s 865ms/step - loss: 0.0815 - categorical_crossentropy: 0.0815 - categorical_accuracy: 0.9210 - mean_iou: 0.4331 - dice_coefficient: 0.8843 - auc: 0.9893 - val_loss: 0.1144 - val_categorical_crossentropy: 0.1144 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4305 - val_dice_coefficient: 0.8700 - val_auc: 0.9947
# Epoch 17/50
# 47/47 [==============================] - 40s 862ms/step - loss: 0.0821 - categorical_crossentropy: 0.0821 - categorical_accuracy: 0.9210 - mean_iou: 0.4333 - dice_coefficient: 0.8842 - auc: 0.9897 - val_loss: 0.1051 - val_categorical_crossentropy: 0.1051 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4343 - val_dice_coefficient: 0.8782 - val_auc: 0.9948
# Epoch 18/50
# 47/47 [==============================] - 40s 862ms/step - loss: 0.0797 - categorical_crossentropy: 0.0797 - categorical_accuracy: 0.9210 - mean_iou: 0.4347 - dice_coefficient: 0.8864 - auc: 0.9904 - val_loss: 0.1050 - val_categorical_crossentropy: 0.1050 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4346 - val_dice_coefficient: 0.8785 - val_auc: 0.9950
# Epoch 19/50
# 47/47 [==============================] - 40s 862ms/step - loss: 0.0778 - categorical_crossentropy: 0.0778 - categorical_accuracy: 0.9210 - mean_iou: 0.4356 - dice_coefficient: 0.8882 - auc: 0.9908 - val_loss: 0.1091 - val_categorical_crossentropy: 0.1091 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4336 - val_dice_coefficient: 0.8758 - val_auc: 0.9950
# Epoch 20/50
# 47/47 [==============================] - 40s 862ms/step - loss: 0.0814 - categorical_crossentropy: 0.0814 - categorical_accuracy: 0.9210 - mean_iou: 0.4347 - dice_coefficient: 0.8856 - auc: 0.9909 - val_loss: 0.0942 - val_categorical_crossentropy: 0.0942 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4390 - val_dice_coefficient: 0.8878 - val_auc: 0.9951
# Epoch 21/50
# 47/47 [==============================] - 40s 860ms/step - loss: 0.0763 - categorical_crossentropy: 0.0763 - categorical_accuracy: 0.9210 - mean_iou: 0.4368 - dice_coefficient: 0.8898 - auc: 0.9914 - val_loss: 0.0957 - val_categorical_crossentropy: 0.0957 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4388 - val_dice_coefficient: 0.8870 - val_auc: 0.9952
# Epoch 22/50
# 47/47 [==============================] - 40s 860ms/step - loss: 0.0767 - categorical_crossentropy: 0.0767 - categorical_accuracy: 0.9210 - mean_iou: 0.4369 - dice_coefficient: 0.8897 - auc: 0.9917 - val_loss: 0.0912 - val_categorical_crossentropy: 0.0912 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4405 - val_dice_coefficient: 0.8907 - val_auc: 0.9954
# Epoch 23/50
# 47/47 [==============================] - 40s 861ms/step - loss: 0.0750 - categorical_crossentropy: 0.0750 - categorical_accuracy: 0.9210 - mean_iou: 0.4377 - dice_coefficient: 0.8912 - auc: 0.9919 - val_loss: 0.0891 - val_categorical_crossentropy: 0.0891 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4414 - val_dice_coefficient: 0.8925 - val_auc: 0.9954
# Epoch 24/50
# 47/47 [==============================] - 40s 861ms/step - loss: 0.0740 - categorical_crossentropy: 0.0740 - categorical_accuracy: 0.9210 - mean_iou: 0.4383 - dice_coefficient: 0.8922 - auc: 0.9922 - val_loss: 0.0857 - val_categorical_crossentropy: 0.0857 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4428 - val_dice_coefficient: 0.8954 - val_auc: 0.9955
# Epoch 25/50
# 47/47 [==============================] - 40s 863ms/step - loss: 0.0726 - categorical_crossentropy: 0.0726 - categorical_accuracy: 0.9210 - mean_iou: 0.4390 - dice_coefficient: 0.8935 - auc: 0.9924 - val_loss: 0.0833 - val_categorical_crossentropy: 0.0833 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4439 - val_dice_coefficient: 0.8976 - val_auc: 0.9956
# Epoch 26/50
# 47/47 [==============================] - 40s 861ms/step - loss: 0.0716 - categorical_crossentropy: 0.0716 - categorical_accuracy: 0.9210 - mean_iou: 0.4396 - dice_coefficient: 0.8944 - auc: 0.9926 - val_loss: 0.0812 - val_categorical_crossentropy: 0.0812 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4448 - val_dice_coefficient: 0.8995 - val_auc: 0.9956
# Epoch 27/50
# 47/47 [==============================] - 40s 863ms/step - loss: 0.0707 - categorical_crossentropy: 0.0707 - categorical_accuracy: 0.9210 - mean_iou: 0.4401 - dice_coefficient: 0.8953 - auc: 0.9927 - val_loss: 0.0792 - val_categorical_crossentropy: 0.0792 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4458 - val_dice_coefficient: 0.9013 - val_auc: 0.9957
# Epoch 28/50
# 47/47 [==============================] - 40s 862ms/step - loss: 0.0700 - categorical_crossentropy: 0.0700 - categorical_accuracy: 0.9210 - mean_iou: 0.4406 - dice_coefficient: 0.8960 - auc: 0.9928 - val_loss: 0.0769 - val_categorical_crossentropy: 0.0769 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4468 - val_dice_coefficient: 0.9033 - val_auc: 0.9957
# Epoch 29/50
# 47/47 [==============================] - 40s 862ms/step - loss: 0.0691 - categorical_crossentropy: 0.0691 - categorical_accuracy: 0.9210 - mean_iou: 0.4411 - dice_coefficient: 0.8969 - auc: 0.9930 - val_loss: 0.0749 - val_categorical_crossentropy: 0.0749 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4476 - val_dice_coefficient: 0.9051 - val_auc: 0.9958
# Epoch 30/50
# 47/47 [==============================] - 40s 862ms/step - loss: 0.0684 - categorical_crossentropy: 0.0684 - categorical_accuracy: 0.9210 - mean_iou: 0.4416 - dice_coefficient: 0.8976 - auc: 0.9931 - val_loss: 0.0737 - val_categorical_crossentropy: 0.0737 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4482 - val_dice_coefficient: 0.9062 - val_auc: 0.9958
# Epoch 31/50
# 47/47 [==============================] - 40s 862ms/step - loss: 0.0678 - categorical_crossentropy: 0.0678 - categorical_accuracy: 0.9210 - mean_iou: 0.4419 - dice_coefficient: 0.8982 - auc: 0.9932 - val_loss: 0.0718 - val_categorical_crossentropy: 0.0718 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4490 - val_dice_coefficient: 0.9079 - val_auc: 0.9958
# Epoch 32/50
# 47/47 [==============================] - 40s 863ms/step - loss: 0.0671 - categorical_crossentropy: 0.0671 - categorical_accuracy: 0.9210 - mean_iou: 0.4424 - dice_coefficient: 0.8989 - auc: 0.9933 - val_loss: 0.0712 - val_categorical_crossentropy: 0.0712 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4494 - val_dice_coefficient: 0.9085 - val_auc: 0.9958
# Epoch 33/50
# 47/47 [==============================] - 40s 861ms/step - loss: 0.0669 - categorical_crossentropy: 0.0669 - categorical_accuracy: 0.9210 - mean_iou: 0.4426 - dice_coefficient: 0.8992 - auc: 0.9933 - val_loss: 0.0695 - val_categorical_crossentropy: 0.0695 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4502 - val_dice_coefficient: 0.9101 - val_auc: 0.9959
# Epoch 34/50
# 47/47 [==============================] - 40s 862ms/step - loss: 0.0661 - categorical_crossentropy: 0.0661 - categorical_accuracy: 0.9210 - mean_iou: 0.4431 - dice_coefficient: 0.9000 - auc: 0.9934 - val_loss: 0.0688 - val_categorical_crossentropy: 0.0688 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4506 - val_dice_coefficient: 0.9108 - val_auc: 0.9959
# Epoch 35/50
# 47/47 [==============================] - 40s 863ms/step - loss: 0.0658 - categorical_crossentropy: 0.0658 - categorical_accuracy: 0.9212 - mean_iou: 0.4434 - dice_coefficient: 0.9004 - auc: 0.9935 - val_loss: 0.0677 - val_categorical_crossentropy: 0.0677 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4511 - val_dice_coefficient: 0.9118 - val_auc: 0.9959
# Epoch 36/50
# 47/47 [==============================] - 40s 863ms/step - loss: 0.0652 - categorical_crossentropy: 0.0652 - categorical_accuracy: 0.9215 - mean_iou: 0.4438 - dice_coefficient: 0.9010 - auc: 0.9935 - val_loss: 0.0672 - val_categorical_crossentropy: 0.0672 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4514 - val_dice_coefficient: 0.9123 - val_auc: 0.9959
# Epoch 37/50
# 47/47 [==============================] - 40s 863ms/step - loss: 0.0648 - categorical_crossentropy: 0.0648 - categorical_accuracy: 0.9221 - mean_iou: 0.4440 - dice_coefficient: 0.9015 - auc: 0.9935 - val_loss: 0.0664 - val_categorical_crossentropy: 0.0664 - val_categorical_accuracy: 0.9436 - val_mean_iou: 0.4518 - val_dice_coefficient: 0.9131 - val_auc: 0.9959
# Epoch 38/50
# 47/47 [==============================] - 40s 864ms/step - loss: 0.0640 - categorical_crossentropy: 0.0640 - categorical_accuracy: 0.9227 - mean_iou: 0.4444 - dice_coefficient: 0.9021 - auc: 0.9936 - val_loss: 0.0663 - val_categorical_crossentropy: 0.0663 - val_categorical_accuracy: 0.9439 - val_mean_iou: 0.4520 - val_dice_coefficient: 0.9132 - val_auc: 0.9959
# Epoch 39/50
# 47/47 [==============================] - 40s 860ms/step - loss: 0.0636 - categorical_crossentropy: 0.0636 - categorical_accuracy: 0.9233 - mean_iou: 0.4447 - dice_coefficient: 0.9026 - auc: 0.9936 - val_loss: 0.0661 - val_categorical_crossentropy: 0.0661 - val_categorical_accuracy: 0.9440 - val_mean_iou: 0.4521 - val_dice_coefficient: 0.9134 - val_auc: 0.9959
# Epoch 40/50
# 47/47 [==============================] - 40s 863ms/step - loss: 0.0631 - categorical_crossentropy: 0.0631 - categorical_accuracy: 0.9238 - mean_iou: 0.4449 - dice_coefficient: 0.9030 - auc: 0.9937 - val_loss: 0.0668 - val_categorical_crossentropy: 0.0668 - val_categorical_accuracy: 0.9440 - val_mean_iou: 0.4519 - val_dice_coefficient: 0.9130 - val_auc: 0.9959
# Epoch 41/50
# 47/47 [==============================] - 40s 862ms/step - loss: 0.0629 - categorical_crossentropy: 0.0629 - categorical_accuracy: 0.9242 - mean_iou: 0.4450 - dice_coefficient: 0.9033 - auc: 0.9937 - val_loss: 0.0678 - val_categorical_crossentropy: 0.0678 - val_categorical_accuracy: 0.9440 - val_mean_iou: 0.4516 - val_dice_coefficient: 0.9121 - val_auc: 0.9959
# Epoch 42/50
# 47/47 [==============================] - 40s 862ms/step - loss: 0.0628 - categorical_crossentropy: 0.0628 - categorical_accuracy: 0.9245 - mean_iou: 0.4451 - dice_coefficient: 0.9033 - auc: 0.9937 - val_loss: 0.0698 - val_categorical_crossentropy: 0.0698 - val_categorical_accuracy: 0.9439 - val_mean_iou: 0.4511 - val_dice_coefficient: 0.9106 - val_auc: 0.9959
# Epoch 43/50
# 47/47 [==============================] - 40s 862ms/step - loss: 0.0634 - categorical_crossentropy: 0.0634 - categorical_accuracy: 0.9247 - mean_iou: 0.4450 - dice_coefficient: 0.9029 - auc: 0.9938 - val_loss: 0.0718 - val_categorical_crossentropy: 0.0718 - val_categorical_accuracy: 0.9438 - val_mean_iou: 0.4504 - val_dice_coefficient: 0.9091 - val_auc: 0.9959
# Epoch 44/50
# 47/47 [==============================] - 40s 863ms/step - loss: 0.0640 - categorical_crossentropy: 0.0640 - categorical_accuracy: 0.9250 - mean_iou: 0.4449 - dice_coefficient: 0.9025 - auc: 0.9938 - val_loss: 0.0739 - val_categorical_crossentropy: 0.0739 - val_categorical_accuracy: 0.9436 - val_mean_iou: 0.4497 - val_dice_coefficient: 0.9074 - val_auc: 0.9958
# Epoch 45/50
# 47/47 [==============================] - 40s 861ms/step - loss: 0.0651 - categorical_crossentropy: 0.0651 - categorical_accuracy: 0.9252 - mean_iou: 0.4446 - dice_coefficient: 0.9016 - auc: 0.9939 - val_loss: 0.0753 - val_categorical_crossentropy: 0.0753 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4493 - val_dice_coefficient: 0.9063 - val_auc: 0.9958
# Epoch 46/50
# 47/47 [==============================] - 40s 862ms/step - loss: 0.0663 - categorical_crossentropy: 0.0663 - categorical_accuracy: 0.9253 - mean_iou: 0.4442 - dice_coefficient: 0.9006 - auc: 0.9939 - val_loss: 0.0757 - val_categorical_crossentropy: 0.0757 - val_categorical_accuracy: 0.9432 - val_mean_iou: 0.4492 - val_dice_coefficient: 0.9060 - val_auc: 0.9958
# Epoch 47/50
# 47/47 [==============================] - 40s 863ms/step - loss: 0.0671 - categorical_crossentropy: 0.0671 - categorical_accuracy: 0.9257 - mean_iou: 0.4441 - dice_coefficient: 0.9000 - auc: 0.9940 - val_loss: 0.0753 - val_categorical_crossentropy: 0.0753 - val_categorical_accuracy: 0.9432 - val_mean_iou: 0.4493 - val_dice_coefficient: 0.9063 - val_auc: 0.9958
# Epoch 48/50
# 47/47 [==============================] - 40s 862ms/step - loss: 0.0678 - categorical_crossentropy: 0.0678 - categorical_accuracy: 0.9259 - mean_iou: 0.4439 - dice_coefficient: 0.8994 - auc: 0.9941 - val_loss: 0.0742 - val_categorical_crossentropy: 0.0742 - val_categorical_accuracy: 0.9433 - val_mean_iou: 0.4498 - val_dice_coefficient: 0.9072 - val_auc: 0.9958
# Epoch 49/50
# 47/47 [==============================] - 40s 864ms/step - loss: 0.0681 - categorical_crossentropy: 0.0681 - categorical_accuracy: 0.9262 - mean_iou: 0.4439 - dice_coefficient: 0.8992 - auc: 0.9941 - val_loss: 0.0727 - val_categorical_crossentropy: 0.0727 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4503 - val_dice_coefficient: 0.9085 - val_auc: 0.9958
# Epoch 50/50
# 47/47 [==============================] - 40s 861ms/step - loss: 0.0681 - categorical_crossentropy: 0.0681 - categorical_accuracy: 0.9265 - mean_iou: 0.4439 - dice_coefficient: 0.8992 - auc: 0.9942 - val_loss: 0.0710 - val_categorical_crossentropy: 0.0710 - val_categorical_accuracy: 0.9436 - val_mean_iou: 0.4508 - val_dice_coefficient: 0.9097 - val_auc: 0.9958

# %% [markdown]
# **Task 4**: Let's predict mitochondria in the testing data! [15 Points]

# %%
# 
# After training, let's try the U-Net on our testing data.
#
# The code below displays the first 10 input images, the original masks by experts, 
# and the predicted masks from the U-Net.

# %%
rows = 10
fig, axs = plt.subplots(rows, 3, figsize=(8, 30))
for ax, (image, label) in zip(axs, test.take(rows).batch(1)):
  
  prediction = unet_model.predict(image)
  ax[0].matshow(image[0, :, :, 0])
  ax[1].matshow(label[0, :, :, 1], cmap="gray")
  # No argmax - very different
  #ax[2].matshow(prediction[0, :, :, 1], cmap="gray")
  ax[2].matshow(prediction[0].argmax(axis=-1), cmap="gray")

# %%
# 1) Question
# TODO: Why do we use the prediction[0].argmax(axis=-1) command
# to display the prediction?
# 
# TODO: YOUR ANSWER
# Displaying the prediction without argmax (as in the commented-out code above)
# shows grayscale interstitial regions in the form of lines - which seem to line
# up with where the membranes in the original images to be.
# Calling argmax() on the predictions leaves only the regions in black - that
# is, the regions which were predicted with most confidence
# to be mitochondria, based on comparison to actual maps.

# %%
# 2) Question
# TODO: Is the quality of the segmentation good and how could we improve it?
# Hint: Think along the lines of some traditional image processing rather than
# increasing the training data size.
#
# TODO: YOUR ANSWER
# No, the quality is not great - the images do not come out with rounded edges.
# One way to improve the image segmentation might be to boost the contrast
# on the imput image data sets, and/or dial down the green in the images leaving
# the red and blue channels intact. That seems to me like it would show the
# mitochondria more clearly.

# %% [markdown]
# **Bonus**: Compare against the state-of-the-art literature! [33 Points]

# %%
#
# The following paper also uses a 2D U-Net to detect mitochondria:
# 
# https://danielhaehn.com/papers/?casser2020fast
#

# %%
# 1) Question
#
# TODO: How many learnable parameters does your trained unet_model have?
# Hint: You can use TF's Model Summary function to answer this.
#

# %%
# TODO: YOUR CODE
unet_model.summary()
# Out:
# Model: "unet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# inputs (InputLayer)             [(None, None, None,  0
# __________________________________________________________________________________________________
# conv_block (ConvBlock)          (None, None, None, 6 37568       inputs[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, None, None, 6 0           conv_block[0][0]
# __________________________________________________________________________________________________
# conv_block_1 (ConvBlock)        (None, None, None, 1 221440      max_pooling2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, None, None, 1 0           conv_block_1[0][0]
# __________________________________________________________________________________________________
# conv_block_2 (ConvBlock)        (None, None, None, 2 885248      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, None, None, 2 0           conv_block_2[0][0]
# __________________________________________________________________________________________________
# conv_block_3 (ConvBlock)        (None, None, None, 5 3539968     max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, None, None, 5 0           conv_block_3[0][0]
# __________________________________________________________________________________________________
# conv_block_4 (ConvBlock)        (None, None, None, 1 14157824    max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# upconv_block (UpconvBlock)      (None, None, None, 5 2097664     conv_block_4[0][0]
# __________________________________________________________________________________________________
# crop_concat_block (CropConcatBl (None, None, None, 1 0           upconv_block[0][0]
#                                                                  conv_block_3[0][0]
# __________________________________________________________________________________________________
# conv_block_5 (ConvBlock)        (None, None, None, 5 7078912     crop_concat_block[0][0]
# __________________________________________________________________________________________________
# upconv_block_1 (UpconvBlock)    (None, None, None, 2 524544      conv_block_5[0][0]
# __________________________________________________________________________________________________
# crop_concat_block_1 (CropConcat (None, None, None, 5 0           upconv_block_1[0][0]
#                                                                  conv_block_2[0][0]
# __________________________________________________________________________________________________
# conv_block_6 (ConvBlock)        (None, None, None, 2 1769984     crop_concat_block_1[0][0]
# __________________________________________________________________________________________________
# upconv_block_2 (UpconvBlock)    (None, None, None, 1 131200      conv_block_6[0][0]
# __________________________________________________________________________________________________
# crop_concat_block_2 (CropConcat (None, None, None, 2 0           upconv_block_2[0][0]
#                                                                  conv_block_1[0][0]
# __________________________________________________________________________________________________
# conv_block_7 (ConvBlock)        (None, None, None, 1 442624      crop_concat_block_2[0][0]
# __________________________________________________________________________________________________
# upconv_block_3 (UpconvBlock)    (None, None, None, 6 32832       conv_block_7[0][0]
# __________________________________________________________________________________________________
# crop_concat_block_3 (CropConcat (None, None, None, 1 0           upconv_block_3[0][0]
#                                                                  conv_block[0][0]
# __________________________________________________________________________________________________
# conv_block_8 (ConvBlock)        (None, None, None, 6 110720      crop_concat_block_3[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, None, None, 2 130         conv_block_8[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, None, None, 2 0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# outputs (Activation)            (None, None, None, 2 0           activation_22[0][0]
# ==================================================================================================
# Total params: 31,030,658
# Trainable params: 31,030,658
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Our unet model has a total of 31,030,658 trainable parameters.

# %%
# 2) Question
#
# TODO: How many parameters do Casser et al. use?
#
print(1178480 + 780053)
# Out:
# 1958533

# %%
# TODO: YOUR ANSWER
# Casser et al. use 1,178,480 parameters for encoding and 780,053 for decoding,
# for a total of 1,958,533 trainable parameters.

# %%
# 3) Question
#
# TODO: How did Casser et al. reduce the parameters?
#

# %%
# TODO: YOUR ANSWER
# They reduced the use of convolution, which required parameters to train the
# filters. For decoding, they used upsampling layers instead, which did not
# rely on trainable parameters.

# %%
# 4) Question
#
# TODO: Why did Casser et al. reduce the parameters?
#

# %%
# TODO: YOUR ANSWER
# Training that many parameters is computationally expensive. It will take
# much less time to calculate losses if you can achieve a 20x reduction in the
# number of parameters, as the team did.

# %%
#
# You made it!!
#
#                 _ ___                /^^\ /^\  /^^\_
#     _          _@)@) \            ,,/ '` ~ `'~~ ', `\.
#   _/o\_ _ _ _/~`.`...'~\        ./~~..,'`','',.,' '  ~:
#  / `,'.~,~.~  .   , . , ~|,   ,/ .,' , ,. .. ,,.   `,  ~\_
# ( ' _' _ '_` _  '  .    , `\_/ .' ..' '  `  `   `..  `,   \_
#  ~V~ V~ V~ V~ ~\ `   ' .  '    , ' .,.,''`.,.''`.,.``. ',   \_
#   _/\ /\ /\ /\_/, . ' ,   `_/~\_ .' .,. ,, , _/~\_ `. `. '.,  \_
#  < ~ ~ '~`'~'`, .,  .   `_: ::: \_ '      `_/ ::: \_ `.,' . ',  \_
#   \ ' `_  '`_    _    ',/ _::_::_ \ _    _/ _::_::_ \   `.,'.,`., \-,-,-,_,_,
#    `'~~ `'~~ `'~~ `'~~  \(_)(_)(_)/  `~~' \(_)(_)(_)/ ~'`\_.._,._,'_;_;_;_;_;
#
